# %%
from obspy import read
import pandas as pd
import numpy as np
from pathlib import Path
from scipy.stats import mode, skew, kurtosis, zscore

# Function to sanitize file names
def sanitize_filename(name):
    return name.replace(".", "").replace(":", "").replace("-", "").replace("_", "")

# Function to convert ADX355 counts to acceleration
def convert_adx355_counts_to_acceleration(counts, scale_factor=256000):
    acceleration_g = counts / scale_factor  # Convert counts to g
    acceleration_m_s2 = acceleration_g * 9.81  # Convert g to m/s²
    return acceleration_g, acceleration_m_s2

def compute_mer(signal, window_size=50):
    energy = np.convolve(signal**2, np.ones(window_size), mode='valid')
    mer = np.zeros(len(signal))
    mer[window_size - 1: window_size - 1 + len(energy)] = energy
    return mer

# Function to compute STA/LTA ratio
def compute_sta_lta(signal, sta_window=50, lta_window=200):
    sta = np.convolve(signal, np.ones(sta_window) / sta_window, mode="valid")
    lta = np.convolve(signal, np.ones(lta_window) / lta_window, mode="valid")

    sta_lta_ratio = np.zeros(len(signal))
    valid_length = min(len(sta), len(lta))
    sta_lta_ratio[lta_window - 1: lta_window - 1 + valid_length] = sta[:valid_length] / (lta[:valid_length] + 1e-10)

    return sta_lta_ratio

# Directories
mseed_dir = "miniSEED_files"
output_csv = "acceleration_stats_1.5sec_windows_separated_28columns.csv"

# Number of samples per window
sampling_rate = 250  # 250 Hz means 250 samples per second
num_samples_before = sampling_rate  # 1 second window (Before)
num_samples_after = 125  # 0.5 second window (After)

# STA/LTA window lengths
sta_window_before = 50  # Short-term average window for before
lta_window_before = 200  # Long-term average window for before

sta_window_after = 25  # Short-term average window for after
lta_window_after = 100  # Long-term average window for after

# Store results
results = []

# Stats headers
stats_headers = ["Mean", "Median", "Mode", "Std Dev", "Skewness", "Kurtosis", "Variance", "Max", "Min", "Z-Score", 
                 "Mean STA/LTA", "Max STA/LTA", "Mean MER", "Max MER"]

# Create column headers
columns = ["File", "Trace ID", "Window Start (sec)"]

# Add columns for each of the stats for "Before" and "After" windows
for sample in ["Before", "After"]:
    columns.extend([f"{sample} {stat}" for stat in stats_headers])

# Loop through miniSEED files
for file_path in Path(mseed_dir).glob("*.MSEED"):
    mseed_name = sanitize_filename(file_path.name.strip())

    print(f"Processing: {file_path.name}")

    # Read miniSEED file
    stream = read(file_path)

    for trace in stream:
        print(f"Processing trace: {trace.id}")

        total_samples = len(trace.data)

        try:
            # Convert counts to acceleration
            _, accel_m_s2 = convert_adx355_counts_to_acceleration(trace.data)
        except Exception as e:
            print(f"Error converting counts for {trace.id}: {e}")
            continue

        # Get time array
        times = np.linspace(trace.stats.starttime.timestamp, trace.stats.endtime.timestamp, total_samples)

        # Compute STA/LTA ratio for both before and after
        sta_lta_ratio_before = compute_sta_lta(accel_m_s2, sta_window=sta_window_before, lta_window=lta_window_before)
        sta_lta_ratio_after = compute_sta_lta(accel_m_s2, sta_window=sta_window_after, lta_window=lta_window_after)

        # Loop for each 1.5 second window (1 second before, 0.5 second after) with 1-second overlap
        for window_start in range(0, total_samples - num_samples_before - num_samples_after, num_samples_before):  # Shift by 1 sec for overlap
            # Define the indices for the current window
            start_idx_before = window_start
            end_idx_before = start_idx_before + num_samples_before

            start_idx_after = window_start + num_samples_before
            end_idx_after = start_idx_after + num_samples_after

            # Extract segments for before and after windows
            segment_before = accel_m_s2[start_idx_before:end_idx_before]
            segment_after = accel_m_s2[start_idx_after:end_idx_after]
            sta_lta_segment_before = sta_lta_ratio_before[start_idx_before:end_idx_before]
            sta_lta_segment_after = sta_lta_ratio_after[start_idx_after:end_idx_after]
            mer_segment_before = compute_mer(segment_before)  # Compute MER for the before segment
            mer_segment_after = compute_mer(segment_after)  # Compute MER for the after segment

            # Compute statistics for before window
            mean_before = np.mean(segment_before)
            median_before = np.median(segment_before)
            mode_before = mode(segment_before, keepdims=True).mode[0]
            std_before = np.std(segment_before)
            skewness_before = skew(segment_before)
            kurtosis_before = kurtosis(segment_before)
            variance_before = np.var(segment_before)
            max_before = np.max(segment_before)
            min_before = np.min(segment_before)
            z_scores_before = np.mean(zscore(segment_before))
            mean_sta_lta_before = np.mean(sta_lta_segment_before)
            max_sta_lta_before = np.max(sta_lta_segment_before)
            mean_mer_before = np.mean(mer_segment_before)
            max_mer_before = np.max(mer_segment_before)

            # Compute statistics for after window
            mean_after = np.mean(segment_after)
            median_after = np.median(segment_after)
            mode_after = mode(segment_after, keepdims=True).mode[0]
            std_after = np.std(segment_after)
            skewness_after = skew(segment_after)
            kurtosis_after = kurtosis(segment_after)
            variance_after = np.var(segment_after)
            max_after = np.max(segment_after)
            min_after = np.min(segment_after)
            z_scores_after = np.mean(zscore(segment_after))
            mean_sta_lta_after = np.mean(sta_lta_segment_after)
            max_sta_lta_after = np.max(sta_lta_segment_after)
            mean_mer_after = np.mean(mer_segment_after)
            max_mer_after = np.max(mer_segment_after)

            # Append stats for both before and after windows
            results.append([file_path.name, trace.id, window_start, 
                            mean_before, median_before, mode_before, std_before, 
                            skewness_before, kurtosis_before, variance_before, 
                            max_before, min_before, z_scores_before, mean_sta_lta_before, 
                            max_sta_lta_before, mean_mer_before, max_mer_before, 
                            mean_after, median_after, mode_after, std_after, 
                            skewness_after, kurtosis_after, variance_after, 
                            max_after, min_after, z_scores_after, mean_sta_lta_after, 
                            max_sta_lta_after, mean_mer_after, max_mer_after])

# Save results to Excel
df_results = pd.DataFrame(results, columns=columns)
df_results.to_csv(output_csv, index=False)
print(f"Acceleration statistics with STA/LTA and MER saved to {output_csv}")
# Out:
# Processing: 34161341_2023-02-21T00.07.00.489723Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# Processing: 34161341_2023-02-21T00.07.00.489723Z_WS.POZA.S5.DN2.MSEED
# Processing trace: WS.POZA.S5.DN2
# Processing: 34161341_2023-02-21T00.07.00.489723Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# Processing: 34161341_2023-02-21T00.07.00.490024Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# Processing: 34161341_2023-02-21T00.07.00.490024Z_WS.POZA.S3.DN2.MSEED
# Processing trace: WS.POZA.S3.DN2
# Processing: 34161341_2023-02-21T00.07.00.490024Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# Processing: 34161341_2023-02-21T00.07.00.490032Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# Processing: 34161341_2023-02-21T00.07.00.490032Z_WS.POZA.S2.DN2.MSEED
# Processing trace: WS.POZA.S2.DN2
# Processing: 34161341_2023-02-21T00.07.00.490032Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# Processing: 34161341_2023-02-21T00.07.00.490708Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# Processing: 34161341_2023-02-21T00.07.00.490708Z_WS.POZA.S4.DN2.MSEED
# Processing trace: WS.POZA.S4.DN2
# Processing: 34161341_2023-02-21T00.07.00.490708Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# Processing: 34161341_2023-02-21T00.07.00.493150Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# Processing: 34161341_2023-02-21T00.07.00.493150Z_WS.POZA.S6.DN2.MSEED
# Processing trace: WS.POZA.S6.DN2
# Processing: 34161341_2023-02-21T00.07.00.493150Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# Processing: 34161511_2023-02-21T00.12.34.317723Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# Processing: 34161511_2023-02-21T00.12.34.317723Z_WS.POZA.S5.DN2.MSEED
# Processing trace: WS.POZA.S5.DN2
# Processing: 34161511_2023-02-21T00.12.34.317723Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# Processing: 34161511_2023-02-21T00.12.34.318024Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# Processing: 34161511_2023-02-21T00.12.34.318024Z_WS.POZA.S3.DN2.MSEED
# Processing trace: WS.POZA.S3.DN2
# Processing: 34161511_2023-02-21T00.12.34.318024Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# Processing: 34161511_2023-02-21T00.12.34.318032Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# Processing: 34161511_2023-02-21T00.12.34.318032Z_WS.POZA.S2.DN2.MSEED
# Processing trace: WS.POZA.S2.DN2
# Processing: 34161511_2023-02-21T00.12.34.318032Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# Processing: 34161511_2023-02-21T00.12.34.318708Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# Processing: 34161511_2023-02-21T00.12.34.318708Z_WS.POZA.S4.DN2.MSEED
# Processing trace: WS.POZA.S4.DN2
# Processing: 34161511_2023-02-21T00.12.34.318708Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# Processing: 34161511_2023-02-21T00.12.34.321150Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# Processing: 34161511_2023-02-21T00.12.34.321150Z_WS.POZA.S6.DN2.MSEED
# Processing trace: WS.POZA.S6.DN2
# Processing: 34161511_2023-02-21T00.12.34.321150Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# Processing: 34161571_2023-02-21T00.14.39.009723Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# Processing: 34161571_2023-02-21T00.14.39.009723Z_WS.POZA.S5.DN2.MSEED
# Processing trace: WS.POZA.S5.DN2
# Processing: 34161571_2023-02-21T00.14.39.009723Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# Processing: 34161571_2023-02-21T00.14.39.010024Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# Processing: 34161571_2023-02-21T00.14.39.010024Z_WS.POZA.S3.DN2.MSEED
# Processing trace: WS.POZA.S3.DN2
# Processing: 34161571_2023-02-21T00.14.39.010024Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# Processing: 34161571_2023-02-21T00.14.39.010032Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# Processing: 34161571_2023-02-21T00.14.39.010032Z_WS.POZA.S2.DN2.MSEED
# Processing trace: WS.POZA.S2.DN2
# Processing: 34161571_2023-02-21T00.14.39.010032Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# Processing: 34161571_2023-02-21T00.14.39.010708Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# Processing: 34161571_2023-02-21T00.14.39.010708Z_WS.POZA.S4.DN2.MSEED
# Processing trace: WS.POZA.S4.DN2
# Processing: 34161571_2023-02-21T00.14.39.010708Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# Processing: 34161571_2023-02-21T00.14.39.013150Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# Processing: 34161571_2023-02-21T00.14.39.013150Z_WS.POZA.S6.DN2.MSEED
# Processing trace: WS.POZA.S6.DN2
# Processing: 34161571_2023-02-21T00.14.39.013150Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# Processing: 34161621_2023-02-21T00.18.41.857723Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# Processing: 34161621_2023-02-21T00.18.41.857723Z_WS.POZA.S5.DN2.MSEED
# Processing trace: WS.POZA.S5.DN2
# Processing: 34161621_2023-02-21T00.18.41.857723Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# Processing: 34161621_2023-02-21T00.18.41.858024Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# Processing: 34161621_2023-02-21T00.18.41.858024Z_WS.POZA.S3.DN2.MSEED
# Processing trace: WS.POZA.S3.DN2
# Processing: 34161621_2023-02-21T00.18.41.858024Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# Processing: 34161621_2023-02-21T00.18.41.858032Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# Processing: 34161621_2023-02-21T00.18.41.858032Z_WS.POZA.S2.DN2.MSEED
# Processing trace: WS.POZA.S2.DN2
# Processing: 34161621_2023-02-21T00.18.41.858032Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# Processing: 34161621_2023-02-21T00.18.41.858708Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# Processing: 34161621_2023-02-21T00.18.41.858708Z_WS.POZA.S4.DN2.MSEED
# Processing trace: WS.POZA.S4.DN2
# Processing: 34161621_2023-02-21T00.18.41.858708Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# Processing: 34161621_2023-02-21T00.18.41.861150Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# Processing: 34161621_2023-02-21T00.18.41.861150Z_WS.POZA.S6.DN2.MSEED
# Processing trace: WS.POZA.S6.DN2
# Processing: 34161621_2023-02-21T00.18.41.861150Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# Processing: 34161791_2023-02-21T00.40.23.069600Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# Processing: 34161791_2023-02-21T00.40.23.069600Z_WS.POZA.S5.DN2.MSEED
# Processing trace: WS.POZA.S5.DN2
# Processing: 34161791_2023-02-21T00.40.23.069600Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# Processing: 34161791_2023-02-21T00.40.23.070024Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# Processing: 34161791_2023-02-21T00.40.23.070024Z_WS.POZA.S3.DN2.MSEED
# Processing trace: WS.POZA.S3.DN2
# Processing: 34161791_2023-02-21T00.40.23.070024Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# Processing: 34161791_2023-02-21T00.40.23.070032Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# Processing: 34161791_2023-02-21T00.40.23.070032Z_WS.POZA.S2.DN2.MSEED
# Processing trace: WS.POZA.S2.DN2
# Processing: 34161791_2023-02-21T00.40.23.070032Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# Processing: 34161791_2023-02-21T00.40.23.070708Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# Processing: 34161791_2023-02-21T00.40.23.070708Z_WS.POZA.S4.DN2.MSEED
# Processing trace: WS.POZA.S4.DN2
# Processing: 34161791_2023-02-21T00.40.23.070708Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# Processing: 34161791_2023-02-21T00.40.23.072380Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# Processing: 34161791_2023-02-21T00.40.23.072380Z_WS.POZA.S6.DN2.MSEED
# Processing trace: WS.POZA.S6.DN2
# Processing: 34161791_2023-02-21T00.40.23.072380Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# Processing: 34162021_2023-02-21T00.56.56.517600Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# Processing: 34162021_2023-02-21T00.56.56.517600Z_WS.POZA.S5.DN2.MSEED
# Processing trace: WS.POZA.S5.DN2
# Processing: 34162021_2023-02-21T00.56.56.517600Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# Processing: 34162021_2023-02-21T00.56.56.518032Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# Processing: 34162021_2023-02-21T00.56.56.518032Z_WS.POZA.S2.DN2.MSEED
# Processing trace: WS.POZA.S2.DN2
# Processing: 34162021_2023-02-21T00.56.56.518032Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# Processing: 34162021_2023-02-21T00.56.56.519238Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# Processing: 34162021_2023-02-21T00.56.56.519238Z_WS.POZA.S3.DN2.MSEED
# Processing trace: WS.POZA.S3.DN2
# Processing: 34162021_2023-02-21T00.56.56.519238Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# Processing: 34162021_2023-02-21T00.56.56.520384Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# Processing: 34162021_2023-02-21T00.56.56.520384Z_WS.POZA.S6.DN2.MSEED
# Processing trace: WS.POZA.S6.DN2
# Processing: 34162021_2023-02-21T00.56.56.520384Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# Processing: 34162021_2023-02-21T00.56.56.521079Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# Processing: 34162021_2023-02-21T00.56.56.521079Z_WS.POZA.S4.DN2.MSEED
# Processing trace: WS.POZA.S4.DN2
# Processing: 34162021_2023-02-21T00.56.56.521079Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# Processing: 34162111_2023-02-21T01.02.21.829562Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# Processing: 34162111_2023-02-21T01.02.21.829562Z_WS.POZA.S5.DN2.MSEED
# Processing trace: WS.POZA.S5.DN2
# Processing: 34162111_2023-02-21T01.02.21.829562Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# Processing: 34162111_2023-02-21T01.02.21.831238Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# Processing: 34162111_2023-02-21T01.02.21.831238Z_WS.POZA.S3.DN2.MSEED
# Processing trace: WS.POZA.S3.DN2
# Processing: 34162111_2023-02-21T01.02.21.831238Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# Processing: 34162111_2023-02-21T01.02.21.832384Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# Processing: 34162111_2023-02-21T01.02.21.832384Z_WS.POZA.S6.DN2.MSEED
# Processing trace: WS.POZA.S6.DN2
# Processing: 34162111_2023-02-21T01.02.21.832384Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# Processing: 34162111_2023-02-21T01.02.21.832647Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# Processing: 34162111_2023-02-21T01.02.21.832647Z_WS.POZA.S2.DN2.MSEED
# Processing trace: WS.POZA.S2.DN2
# Processing: 34162111_2023-02-21T01.02.21.832647Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# Processing: 34162111_2023-02-21T01.02.21.833079Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# Processing: 34162111_2023-02-21T01.02.21.833079Z_WS.POZA.S4.DN2.MSEED
# Processing trace: WS.POZA.S4.DN2
# Processing: 34162111_2023-02-21T01.02.21.833079Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# Processing: 34162221_2023-02-21T01.06.56.697562Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# Processing: 34162221_2023-02-21T01.06.56.697562Z_WS.POZA.S5.DN2.MSEED
# Processing trace: WS.POZA.S5.DN2
# Processing: 34162221_2023-02-21T01.06.56.697562Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# Processing: 34162221_2023-02-21T01.06.56.698149Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# Processing: 34162221_2023-02-21T01.06.56.698149Z_WS.POZA.S6.DN2.MSEED
# Processing trace: WS.POZA.S6.DN2
# Processing: 34162221_2023-02-21T01.06.56.698149Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# Processing: 34162221_2023-02-21T01.06.56.699238Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# Processing: 34162221_2023-02-21T01.06.56.699238Z_WS.POZA.S3.DN2.MSEED
# Processing trace: WS.POZA.S3.DN2
# Processing: 34162221_2023-02-21T01.06.56.699238Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# Processing: 34162221_2023-02-21T01.06.56.700647Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# Processing: 34162221_2023-02-21T01.06.56.700647Z_WS.POZA.S2.DN2.MSEED
# Processing trace: WS.POZA.S2.DN2
# Processing: 34162221_2023-02-21T01.06.56.700647Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# Processing: 34162221_2023-02-21T01.06.56.701079Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# Processing: 34162221_2023-02-21T01.06.56.701079Z_WS.POZA.S4.DN2.MSEED
# Processing trace: WS.POZA.S4.DN2
# Processing: 34162221_2023-02-21T01.06.56.701079Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# Processing: 34162311_2023-02-21T01.15.19.397562Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# Processing: 34162311_2023-02-21T01.15.19.397562Z_WS.POZA.S5.DN2.MSEED
# Processing trace: WS.POZA.S5.DN2
# Processing: 34162311_2023-02-21T01.15.19.397562Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# Processing: 34162311_2023-02-21T01.15.19.398149Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# Processing: 34162311_2023-02-21T01.15.19.398149Z_WS.POZA.S6.DN2.MSEED
# Processing trace: WS.POZA.S6.DN2
# Processing: 34162311_2023-02-21T01.15.19.398149Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# Processing: 34162311_2023-02-21T01.15.19.399238Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# Processing: 34162311_2023-02-21T01.15.19.399238Z_WS.POZA.S3.DN2.MSEED
# Processing trace: WS.POZA.S3.DN2
# Processing: 34162311_2023-02-21T01.15.19.399238Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# Processing: 34162311_2023-02-21T01.15.19.400647Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# Processing: 34162311_2023-02-21T01.15.19.400647Z_WS.POZA.S2.DN2.MSEED
# Processing trace: WS.POZA.S2.DN2
# Processing: 34162311_2023-02-21T01.15.19.400647Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# Processing: 34162311_2023-02-21T01.15.19.401079Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# Processing: 34162311_2023-02-21T01.15.19.401079Z_WS.POZA.S4.DN2.MSEED
# Processing trace: WS.POZA.S4.DN2
# Processing: 34162311_2023-02-21T01.15.19.401079Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# Processing: 34162371_2023-02-21T01.31.01.417675Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# Processing: 34162371_2023-02-21T01.31.01.417675Z_WS.POZA.S5.DN2.MSEED
# Processing trace: WS.POZA.S5.DN2
# Processing: 34162371_2023-02-21T01.31.01.417675Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# Processing: 34162371_2023-02-21T01.31.01.417936Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# Processing: 34162371_2023-02-21T01.31.01.417936Z_WS.POZA.S6.DN2.MSEED
# Processing trace: WS.POZA.S6.DN2
# Processing: 34162371_2023-02-21T01.31.01.417936Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# Processing: 34162371_2023-02-21T01.31.01.419238Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# Processing: 34162371_2023-02-21T01.31.01.419238Z_WS.POZA.S3.DN2.MSEED
# Processing trace: WS.POZA.S3.DN2
# Processing: 34162371_2023-02-21T01.31.01.419238Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# Processing: 34162371_2023-02-21T01.31.01.420647Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# Processing: 34162371_2023-02-21T01.31.01.420647Z_WS.POZA.S2.DN2.MSEED
# Processing trace: WS.POZA.S2.DN2
# Processing: 34162371_2023-02-21T01.31.01.420647Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# Processing: 34162371_2023-02-21T01.31.01.421079Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# Processing: 34162371_2023-02-21T01.31.01.421079Z_WS.POZA.S4.DN2.MSEED
# Processing trace: WS.POZA.S4.DN2
# Processing: 34162371_2023-02-21T01.31.01.421079Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# Processing: 34162431_2023-02-21T01.31.15.097675Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# Processing: 34162431_2023-02-21T01.31.15.097675Z_WS.POZA.S5.DN2.MSEED
# Processing trace: WS.POZA.S5.DN2
# Processing: 34162431_2023-02-21T01.31.15.097675Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# Processing: 34162431_2023-02-21T01.31.15.097936Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# Processing: 34162431_2023-02-21T01.31.15.097936Z_WS.POZA.S6.DN2.MSEED
# Processing trace: WS.POZA.S6.DN2
# Processing: 34162431_2023-02-21T01.31.15.097936Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# Processing: 34162431_2023-02-21T01.31.15.099238Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# Processing: 34162431_2023-02-21T01.31.15.099238Z_WS.POZA.S3.DN2.MSEED
# Processing trace: WS.POZA.S3.DN2
# Processing: 34162431_2023-02-21T01.31.15.099238Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# Processing: 34162431_2023-02-21T01.31.15.100647Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# Processing: 34162431_2023-02-21T01.31.15.100647Z_WS.POZA.S2.DN2.MSEED
# Processing trace: WS.POZA.S2.DN2
# Processing: 34162431_2023-02-21T01.31.15.100647Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# Processing: 34162431_2023-02-21T01.31.15.101079Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# Processing: 34162431_2023-02-21T01.31.15.101079Z_WS.POZA.S4.DN2.MSEED
# Processing trace: WS.POZA.S4.DN2
# Processing: 34162431_2023-02-21T01.31.15.101079Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# Processing: 34162501_2023-02-21T02.02.38.097936Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# Processing: 34162501_2023-02-21T02.02.38.097936Z_WS.POZA.S6.DN2.MSEED
# Processing trace: WS.POZA.S6.DN2
# Processing: 34162501_2023-02-21T02.02.38.097936Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# Processing: 34162501_2023-02-21T02.02.38.098562Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# Processing: 34162501_2023-02-21T02.02.38.098562Z_WS.POZA.S2.DN2.MSEED
# Processing trace: WS.POZA.S2.DN2
# Processing: 34162501_2023-02-21T02.02.38.098562Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# Processing: 34162501_2023-02-21T02.02.38.098588Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# Processing: 34162501_2023-02-21T02.02.38.098588Z_WS.POZA.S5.DN2.MSEED
# Processing trace: WS.POZA.S5.DN2
# Processing: 34162501_2023-02-21T02.02.38.098588Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# Processing: 34162501_2023-02-21T02.02.38.098725Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# Processing: 34162501_2023-02-21T02.02.38.098725Z_WS.POZA.S4.DN2.MSEED
# Processing trace: WS.POZA.S4.DN2
# Processing: 34162501_2023-02-21T02.02.38.098725Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# Processing: 34162501_2023-02-21T02.02.38.100243Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# Processing: 34162501_2023-02-21T02.02.38.100243Z_WS.POZA.S3.DN2.MSEED
# Processing trace: WS.POZA.S3.DN2
# Processing: 34162501_2023-02-21T02.02.38.100243Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# Processing: 34162511_2023-02-21T02.06.02.977755Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# Processing: 34162511_2023-02-21T02.06.02.977755Z_WS.POZA.S6.DN2.MSEED
# Processing trace: WS.POZA.S6.DN2
# Processing: 34162511_2023-02-21T02.06.02.977755Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# Processing: 34162511_2023-02-21T02.06.02.978562Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# Processing: 34162511_2023-02-21T02.06.02.978562Z_WS.POZA.S2.DN2.MSEED
# Processing trace: WS.POZA.S2.DN2
# Processing: 34162511_2023-02-21T02.06.02.978562Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# Processing: 34162511_2023-02-21T02.06.02.978588Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# Processing: 34162511_2023-02-21T02.06.02.978588Z_WS.POZA.S5.DN2.MSEED
# Processing trace: WS.POZA.S5.DN2
# Processing: 34162511_2023-02-21T02.06.02.978588Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# Processing: 34162511_2023-02-21T02.06.02.978725Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# Processing: 34162511_2023-02-21T02.06.02.978725Z_WS.POZA.S4.DN2.MSEED
# Processing trace: WS.POZA.S4.DN2
# Processing: 34162511_2023-02-21T02.06.02.978725Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# Processing: 34162511_2023-02-21T02.06.02.980243Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# Processing: 34162511_2023-02-21T02.06.02.980243Z_WS.POZA.S3.DN2.MSEED
# Processing trace: WS.POZA.S3.DN2
# Processing: 34162511_2023-02-21T02.06.02.980243Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# Processing: 34162741_2023-02-21T02.39.54.850587Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# Processing: 34162741_2023-02-21T02.39.54.850587Z_WS.POZA.S5.DN2.MSEED
# Processing trace: WS.POZA.S5.DN2
# Processing: 34162741_2023-02-21T02.39.54.850587Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# Processing: 34162741_2023-02-21T02.39.54.850647Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# Processing: 34162741_2023-02-21T02.39.54.850647Z_WS.POZA.S4.DN2.MSEED
# Processing trace: WS.POZA.S4.DN2
# Processing: 34162741_2023-02-21T02.39.54.850647Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# Processing: 34162741_2023-02-21T02.39.54.850725Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# Processing: 34162741_2023-02-21T02.39.54.850725Z_WS.POZA.S2.DN2.MSEED
# Processing trace: WS.POZA.S2.DN2
# Processing: 34162741_2023-02-21T02.39.54.850725Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# Processing: 34162741_2023-02-21T02.39.54.852047Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# Processing: 34162741_2023-02-21T02.39.54.852047Z_WS.POZA.S3.DN2.MSEED
# Processing trace: WS.POZA.S3.DN2
# Processing: 34162741_2023-02-21T02.39.54.852047Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# Processing: 34162741_2023-02-21T02.39.54.853537Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# Processing: 34162741_2023-02-21T02.39.54.853537Z_WS.POZA.S6.DN2.MSEED
# Processing trace: WS.POZA.S6.DN2
# Processing: 34162741_2023-02-21T02.39.54.853537Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# Processing: 34163011_2023-02-21T03.32.30.490319Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# Processing: 34163011_2023-02-21T03.32.30.490319Z_WS.POZA.S3.DN2.MSEED
# Processing trace: WS.POZA.S3.DN2
# Processing: 34163011_2023-02-21T03.32.30.490319Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# Processing: 34163011_2023-02-21T03.32.30.492143Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# Processing: 34163011_2023-02-21T03.32.30.492143Z_WS.POZA.S5.DN2.MSEED
# Processing trace: WS.POZA.S5.DN2
# Processing: 34163011_2023-02-21T03.32.30.492143Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# Processing: 34163011_2023-02-21T03.32.30.492276Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# Processing: 34163011_2023-02-21T03.32.30.492276Z_WS.POZA.S4.DN2.MSEED
# Processing trace: WS.POZA.S4.DN2
# Processing: 34163011_2023-02-21T03.32.30.492276Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# Processing: 34163011_2023-02-21T03.32.30.492397Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# Processing: 34163011_2023-02-21T03.32.30.492397Z_WS.POZA.S2.DN2.MSEED
# Processing trace: WS.POZA.S2.DN2
# Processing: 34163011_2023-02-21T03.32.30.492397Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# Processing: 34163011_2023-02-21T03.32.30.493482Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# Processing: 34163011_2023-02-21T03.32.30.493482Z_WS.POZA.S6.DN2.MSEED
# Processing trace: WS.POZA.S6.DN2
# Processing: 34163011_2023-02-21T03.32.30.493482Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# Processing: 34163051_2023-02-21T03.41.55.050319Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# Processing: 34163051_2023-02-21T03.41.55.050319Z_WS.POZA.S3.DN2.MSEED
# Processing trace: WS.POZA.S3.DN2
# Processing: 34163051_2023-02-21T03.41.55.050319Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# Processing: 34163051_2023-02-21T03.41.55.052143Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# Processing: 34163051_2023-02-21T03.41.55.052143Z_WS.POZA.S5.DN2.MSEED
# Processing trace: WS.POZA.S5.DN2
# Processing: 34163051_2023-02-21T03.41.55.052143Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# Processing: 34163051_2023-02-21T03.41.55.052276Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# Processing: 34163051_2023-02-21T03.41.55.052276Z_WS.POZA.S4.DN2.MSEED
# Processing trace: WS.POZA.S4.DN2
# Processing: 34163051_2023-02-21T03.41.55.052276Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# Processing: 34163051_2023-02-21T03.41.55.052397Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# Processing: 34163051_2023-02-21T03.41.55.052397Z_WS.POZA.S2.DN2.MSEED
# Processing trace: WS.POZA.S2.DN2
# Processing: 34163051_2023-02-21T03.41.55.052397Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# Processing: 34163051_2023-02-21T03.41.55.053482Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# Processing: 34163051_2023-02-21T03.41.55.053482Z_WS.POZA.S6.DN2.MSEED
# Processing trace: WS.POZA.S6.DN2
# Processing: 34163051_2023-02-21T03.41.55.053482Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# Processing: 34163411_2023-02-21T04.49.09.159092Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# Processing: 34163411_2023-02-21T04.49.09.159092Z_WS.POZA.S4.DN2.MSEED
# Processing trace: WS.POZA.S4.DN2
# Processing: 34163411_2023-02-21T04.49.09.159092Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# Processing: 34163411_2023-02-21T04.49.09.159201Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# Processing: 34163411_2023-02-21T04.49.09.159201Z_WS.POZA.S5.DN2.MSEED
# Processing trace: WS.POZA.S5.DN2
# Processing: 34163411_2023-02-21T04.49.09.159201Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# Processing: 34163411_2023-02-21T04.49.09.160249Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# Processing: 34163411_2023-02-21T04.49.09.160249Z_WS.POZA.S6.DN2.MSEED
# Processing trace: WS.POZA.S6.DN2
# Processing: 34163411_2023-02-21T04.49.09.160249Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# Processing: 34163411_2023-02-21T04.49.09.161007Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# Processing: 34163411_2023-02-21T04.49.09.161007Z_WS.POZA.S3.DN2.MSEED
# Processing trace: WS.POZA.S3.DN2
# Processing: 34163411_2023-02-21T04.49.09.161007Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# Processing: 34163411_2023-02-21T04.49.09.161225Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# Processing: 34163411_2023-02-21T04.49.09.161225Z_WS.POZA.S2.DN2.MSEED
# Processing trace: WS.POZA.S2.DN2
# Processing: 34163411_2023-02-21T04.49.09.161225Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# Processing: 34163481_2023-02-21T05.15.35.189899Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# Processing: 34163481_2023-02-21T05.15.35.189899Z_WS.POZA.S4.DN2.MSEED
# Processing trace: WS.POZA.S4.DN2
# Processing: 34163481_2023-02-21T05.15.35.189899Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# Processing: 34163481_2023-02-21T05.15.35.190426Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# Processing: 34163481_2023-02-21T05.15.35.190426Z_WS.POZA.S6.DN2.MSEED
# Processing trace: WS.POZA.S6.DN2
# Processing: 34163481_2023-02-21T05.15.35.190426Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# Processing: 34163481_2023-02-21T05.15.35.191097Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# Processing: 34163481_2023-02-21T05.15.35.191097Z_WS.POZA.S2.DN2.MSEED
# Processing trace: WS.POZA.S2.DN2
# Processing: 34163481_2023-02-21T05.15.35.191097Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# Processing: 34163481_2023-02-21T05.15.35.191190Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# Processing: 34163481_2023-02-21T05.15.35.191190Z_WS.POZA.S5.DN2.MSEED
# Processing trace: WS.POZA.S5.DN2
# Processing: 34163481_2023-02-21T05.15.35.191190Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# Processing: 34163481_2023-02-21T05.15.35.193431Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# Processing: 34163481_2023-02-21T05.15.35.193431Z_WS.POZA.S3.DN2.MSEED
# Processing trace: WS.POZA.S3.DN2
# Processing: 34163481_2023-02-21T05.15.35.193431Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# Processing: 34163561_2023-02-21T05.33.59.897899Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# Processing: 34163561_2023-02-21T05.33.59.897899Z_WS.POZA.S4.DN2.MSEED
# Processing trace: WS.POZA.S4.DN2
# Processing: 34163561_2023-02-21T05.33.59.897899Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# Processing: 34163561_2023-02-21T05.33.59.898424Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# Processing: 34163561_2023-02-21T05.33.59.898424Z_WS.POZA.S6.DN2.MSEED
# Processing trace: WS.POZA.S6.DN2
# Processing: 34163561_2023-02-21T05.33.59.898424Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# Processing: 34163561_2023-02-21T05.33.59.899097Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# Processing: 34163561_2023-02-21T05.33.59.899097Z_WS.POZA.S2.DN2.MSEED
# Processing trace: WS.POZA.S2.DN2
# Processing: 34163561_2023-02-21T05.33.59.899097Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# Processing: 34163561_2023-02-21T05.33.59.899190Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# Processing: 34163561_2023-02-21T05.33.59.899190Z_WS.POZA.S5.DN2.MSEED
# Processing trace: WS.POZA.S5.DN2
# Processing: 34163561_2023-02-21T05.33.59.899190Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# Processing: 34163561_2023-02-21T05.33.59.901431Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# Processing: 34163561_2023-02-21T05.33.59.901431Z_WS.POZA.S3.DN2.MSEED
# Processing trace: WS.POZA.S3.DN2
# Processing: 34163561_2023-02-21T05.33.59.901431Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# Processing: 34163931_2023-02-21T06.38.57.057885Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# Processing: 34163931_2023-02-21T06.38.57.057885Z_WS.POZA.S6.DN2.MSEED
# Processing trace: WS.POZA.S6.DN2
# Processing: 34163931_2023-02-21T06.38.57.057885Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# Processing: 34163931_2023-02-21T06.38.57.058077Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# Processing: 34163931_2023-02-21T06.38.57.058077Z_WS.POZA.S3.DN2.MSEED
# Processing trace: WS.POZA.S3.DN2
# Processing: 34163931_2023-02-21T06.38.57.058077Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# Processing: 34163931_2023-02-21T06.38.57.058640Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# Processing: 34163931_2023-02-21T06.38.57.058640Z_WS.POZA.S2.DN2.MSEED
# Processing trace: WS.POZA.S2.DN2
# Processing: 34163931_2023-02-21T06.38.57.058640Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# Processing: 34163931_2023-02-21T06.38.57.059081Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# Processing: 34163931_2023-02-21T06.38.57.059081Z_WS.POZA.S5.DN2.MSEED
# Processing trace: WS.POZA.S5.DN2
# Processing: 34163931_2023-02-21T06.38.57.059081Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# Processing: 34163931_2023-02-21T06.38.57.059276Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# Processing: 34163931_2023-02-21T06.38.57.059276Z_WS.POZA.S4.DN2.MSEED
# Processing trace: WS.POZA.S4.DN2
# Processing: 34163931_2023-02-21T06.38.57.059276Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# Processing: 34164401_2023-02-21T07.13.34.330804Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# Processing: 34164401_2023-02-21T07.13.34.330804Z_WS.POZA.S4.DN2.MSEED
# Processing trace: WS.POZA.S4.DN2
# Processing: 34164401_2023-02-21T07.13.34.330804Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# Processing: 34164401_2023-02-21T07.13.34.331170Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# Processing: 34164401_2023-02-21T07.13.34.331170Z_WS.POZA.S5.DN2.MSEED
# Processing trace: WS.POZA.S5.DN2
# Processing: 34164401_2023-02-21T07.13.34.331170Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# Processing: 34164401_2023-02-21T07.13.34.331365Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# Processing: 34164401_2023-02-21T07.13.34.331365Z_WS.POZA.S2.DN2.MSEED
# Processing trace: WS.POZA.S2.DN2
# Processing: 34164401_2023-02-21T07.13.34.331365Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# Processing: 34164401_2023-02-21T07.13.34.332303Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# Processing: 34164401_2023-02-21T07.13.34.332303Z_WS.POZA.S6.DN2.MSEED
# Processing trace: WS.POZA.S6.DN2
# Processing: 34164401_2023-02-21T07.13.34.332303Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# Processing: 34164401_2023-02-21T07.13.34.333420Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# Processing: 34164401_2023-02-21T07.13.34.333420Z_WS.POZA.S3.DN2.MSEED
# Processing trace: WS.POZA.S3.DN2
# Processing: 34164401_2023-02-21T07.13.34.333420Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# Processing: 34164891_2023-02-21T08.19.39.829964Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# Processing: 34164891_2023-02-21T08.19.39.829964Z_WS.POZA.S6.DN2.MSEED
# Processing trace: WS.POZA.S6.DN2
# Processing: 34164891_2023-02-21T08.19.39.829964Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# Processing: 34164891_2023-02-21T08.19.39.830367Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# Processing: 34164891_2023-02-21T08.19.39.830367Z_WS.POZA.S3.DN2.MSEED
# Processing trace: WS.POZA.S3.DN2
# Processing: 34164891_2023-02-21T08.19.39.830367Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# Processing: 34164891_2023-02-21T08.19.39.830757Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# Processing: 34164891_2023-02-21T08.19.39.830757Z_WS.POZA.S2.DN2.MSEED
# Processing trace: WS.POZA.S2.DN2
# Processing: 34164891_2023-02-21T08.19.39.830757Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# Processing: 34164891_2023-02-21T08.19.39.831473Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# Processing: 34164891_2023-02-21T08.19.39.831473Z_WS.POZA.S5.DN2.MSEED
# Processing trace: WS.POZA.S5.DN2
# Processing: 34164891_2023-02-21T08.19.39.831473Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# Processing: 34164891_2023-02-21T08.19.39.832827Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# Processing: 34164891_2023-02-21T08.19.39.832827Z_WS.POZA.S4.DN2.MSEED
# Processing trace: WS.POZA.S4.DN2
# Processing: 34164891_2023-02-21T08.19.39.832827Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# Processing: 34165791_2023-02-21T10.36.27.750661Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# Processing: 34165791_2023-02-21T10.36.27.750661Z_WS.POZA.S6.DN2.MSEED
# Processing trace: WS.POZA.S6.DN2
# Processing: 34165791_2023-02-21T10.36.27.750661Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# Processing: 34165791_2023-02-21T10.36.27.751693Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# Processing: 34165791_2023-02-21T10.36.27.751693Z_WS.POZA.S4.DN2.MSEED
# Processing trace: WS.POZA.S4.DN2
# Processing: 34165791_2023-02-21T10.36.27.751693Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# Processing: 34165791_2023-02-21T10.36.27.751736Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# Processing: 34165791_2023-02-21T10.36.27.751736Z_WS.POZA.S3.DN2.MSEED
# Processing trace: WS.POZA.S3.DN2
# Processing: 34165791_2023-02-21T10.36.27.751736Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# Processing: 34165791_2023-02-21T10.36.27.751945Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# Processing: 34165791_2023-02-21T10.36.27.751945Z_WS.POZA.S5.DN2.MSEED
# Processing trace: WS.POZA.S5.DN2
# Processing: 34165791_2023-02-21T10.36.27.751945Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# Processing: 34165791_2023-02-21T10.36.27.752007Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# Processing: 34165791_2023-02-21T10.36.27.752007Z_WS.POZA.S2.DN2.MSEED
# Processing trace: WS.POZA.S2.DN2
# Processing: 34165791_2023-02-21T10.36.27.752007Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# Processing: 34166831_2023-02-21T12.48.34.238879Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# Processing: 34166831_2023-02-21T12.48.34.238879Z_WS.POZA.S3.DN2.MSEED
# Processing trace: WS.POZA.S3.DN2
# Processing: 34166831_2023-02-21T12.48.34.238879Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# Processing: 34166831_2023-02-21T12.48.34.239476Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# Processing: 34166831_2023-02-21T12.48.34.239476Z_WS.POZA.S6.DN2.MSEED
# Processing trace: WS.POZA.S6.DN2
# Processing: 34166831_2023-02-21T12.48.34.239476Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# Processing: 34166831_2023-02-21T12.48.34.239517Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# Processing: 34166831_2023-02-21T12.48.34.239517Z_WS.POZA.S2.DN2.MSEED
# Processing trace: WS.POZA.S2.DN2
# Processing: 34166831_2023-02-21T12.48.34.239517Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# Processing: 34166831_2023-02-21T12.48.34.239983Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# Processing: 34166831_2023-02-21T12.48.34.239983Z_WS.POZA.S5.DN2.MSEED
# Processing trace: WS.POZA.S5.DN2
# Processing: 34166831_2023-02-21T12.48.34.239983Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# Processing: 34166831_2023-02-21T12.48.34.240879Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# Processing: 34166831_2023-02-21T12.48.34.240879Z_WS.POZA.S4.DN2.MSEED
# Processing trace: WS.POZA.S4.DN2
# Processing: 34166831_2023-02-21T12.48.34.240879Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# Processing: 34167831_2023-02-21T15.08.01.278424Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# Processing: 34167831_2023-02-21T15.08.01.278424Z_WS.POZA.S6.DN2.MSEED
# Processing trace: WS.POZA.S6.DN2
# Processing: 34167831_2023-02-21T15.08.01.278424Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# Processing: 34167831_2023-02-21T15.08.01.279429Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# Processing: 34167831_2023-02-21T15.08.01.279429Z_WS.POZA.S3.DN2.MSEED
# Processing trace: WS.POZA.S3.DN2
# Processing: 34167831_2023-02-21T15.08.01.279429Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# Processing: 34167831_2023-02-21T15.08.01.279469Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# Processing: 34167831_2023-02-21T15.08.01.279469Z_WS.POZA.S4.DN2.MSEED
# Processing trace: WS.POZA.S4.DN2
# Processing: 34167831_2023-02-21T15.08.01.279469Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# Processing: 