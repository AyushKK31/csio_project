# %%
import random
from obspy import read
import pandas as pd
import numpy as np
from pathlib import Path
from scipy.stats import mode, skew, kurtosis, zscore

# Function to sanitize file names
def sanitize_filename(name):
    return name.replace(".", "").replace(":", "").replace("-", "").replace("_", "")

# Function to convert ADX355 counts to acceleration
def convert_adx355_counts_to_acceleration(counts, scale_factor=256000):
    acceleration_g = counts / scale_factor  # Convert counts to g
    acceleration_m_s2 = acceleration_g * 9.81  # Convert g to m/s²
    return acceleration_g, acceleration_m_s2

# Directories
mseed_noise_dir = "miniSEED_files_noise"
output_noise_csv = "noise_acceleration_stats_250_samples.csv"

# Number of samples per window
num_samples = 250  # 250 samples for each random window

# Store results
noise_results = []

# Loop through noise miniSEED files
for file_path in Path(mseed_noise_dir).glob("*.MSEED"):
    mseed_name = file_path.stem  # Use stem to avoid sanitizing

    print(f"Processing noise file: {file_path.name}")

    # Read miniSEED file
    stream = read(file_path)

    for trace in stream:
        print(f"Processing trace: {trace.id}")

        sampling_rate = trace.stats.sampling_rate
        total_samples = len(trace.data)

        try:
            # Convert counts to acceleration
            _, accel_m_s2 = convert_adx355_counts_to_acceleration(trace.data)
        except Exception as e:
            print(f"Error converting counts for {trace.id}: {e}")
            continue

        # Extract statistics for three random windows
        stats_per_file = [file_path.name, trace.id]  # First columns

        for _ in range(3):  # Generate 3 random windows
            # Select random start index for the window
            start_idx = random.randint(0, total_samples - num_samples)
            end_idx = start_idx + num_samples

            segment = accel_m_s2[start_idx:end_idx]

            # Compute statistics
            mean_val = np.mean(segment)
            median_val = np.median(segment)
            mode_val = mode(segment, keepdims=True).mode[0]
            std_val = np.std(segment)
            skewness_val = skew(segment)
            kurtosis_val = kurtosis(segment)
            variance_val = np.var(segment)
            max_val = np.max(segment)
            min_val = np.min(segment)
            z_scores = np.mean(zscore(segment))

            # Append stats to the row
            stats_per_file.extend([mean_val, median_val, mode_val, std_val, 
                                   skewness_val, kurtosis_val, variance_val, 
                                   max_val, min_val, z_scores])

        noise_results.append(stats_per_file)

# Define column headers
columns = ["File", "Trace ID"]
stats_headers = ["Mean", "Median", "Mode", "Std Dev", "Skewness", "Kurtosis", "Variance", "Max", "Min", "Z-Score"]

# Repeat headers for S1, S2, S3 (for random windows)
for sample in ["S1", "S2", "S3"]:
    columns.extend([f"{sample} {stat}" for stat in stats_headers])

# Save results to CSV
df_noise_results = pd.DataFrame(noise_results, columns=columns)
df_noise_results.to_csv(output_noise_csv, index=False)
print(f"Noise acceleration statistics saved to {output_noise_csv}")
# Out:
# Processing noise file: noise_2023-02-21T01_07_00.489562Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# Processing noise file: noise_2023-02-21T01_07_00.489562Z_WS.POZA.S5.DN2.MSEED
# Processing trace: WS.POZA.S5.DN2
# Processing noise file: noise_2023-02-21T01_07_00.489562Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# Processing noise file: noise_2023-02-21T01_07_00.490149Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# Processing noise file: noise_2023-02-21T01_07_00.490149Z_WS.POZA.S6.DN2.MSEED
# Processing trace: WS.POZA.S6.DN2
# Processing noise file: noise_2023-02-21T01_07_00.490149Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# Processing noise file: noise_2023-02-21T01_07_00.491238Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# Processing noise file: noise_2023-02-21T01_07_00.491238Z_WS.POZA.S3.DN2.MSEED
# Processing trace: WS.POZA.S3.DN2
# Processing noise file: noise_2023-02-21T01_07_00.491238Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# Processing noise file: noise_2023-02-21T01_07_00.492647Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# Processing noise file: noise_2023-02-21T01_07_00.492647Z_WS.POZA.S2.DN2.MSEED
# Processing trace: WS.POZA.S2.DN2
# Processing noise file: noise_2023-02-21T01_07_00.492647Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# Processing noise file: noise_2023-02-21T01_07_00.493079Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# Processing noise file: noise_2023-02-21T01_07_00.493079Z_WS.POZA.S4.DN2.MSEED
# Processing trace: WS.POZA.S4.DN2
# Processing noise file: noise_2023-02-21T01_07_00.493079Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# Processing noise file: noise_2023-02-21T20_07_00.489606Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# Processing noise file: noise_2023
z_WS.POZA.S6.DN2.MSEED
# Processing trace: WS.POZA.S6.DN2
# Processing noise file: noise_2023-03-10T05_20_27.820891Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# Processing noise file: noise_2023-03-10T05_20_27.821082Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# Processing noise file: noise_2023-03-10T05_20_27.821082Z_WS.POZA.S2.DN2.MSEED
# Processing trace: WS.POZA.S2.DN2
# Processing noise file: noise_2023-03-10T05_20_27.821082Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# Processing noise file: noise_2023-04-28T08_08_16.707897Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# Processing noise file: noise_2023-04-28T08_08_16.707897Z_WS.POZA.S2.DN2.MSEED
# Processing trace: WS.POZA.S2.DN2
# Processing noise file: noise_2023-04-28T08_08_16.707897Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# Processing noise file: noise_2023-04-28T08_08_16.708092Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# Processing noise file: noise_2023-04-28T08_08_16.708092Z_WS.POZA.S3.DN2.MSEED
# Processing trace: WS.POZA.S3.DN2
# Processing noise file: noise_2023-04-28T08_08_16.708092Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# Processing noise file: noise_2023-04-28T08_08_16.710394Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# Processing noise file: noise_2023-04-28T08_08_16.710394Z_WS.POZA.S5.DN2.MSEED
# Processing trace: WS.POZA.S5.DN2
# Processing noise file: noise_2023-04-28T08_08_16.710394Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# Processing noise file: noise_2023-04-28T08_08_16.710864Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# Processing noise file: noise_2023-04-28T08_08_16.710864Z_WS.POZA.S6.DN2.MSEED
# Processing trace: WS.POZA.S6.DN2
# Processing noise file: noise_2023-04-28T08_08_16.710864Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# Processing noise file: noise_2023-04-28T08_08_16.711406Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# Processing noise file: noise_2023-04-28T08_08_16.711406Z_WS.POZA.S4.DN2.MSEED
# Processing trace: WS.POZA.S4.DN2
# Processing noise file: noise_2023-04-28T08_08_16.711406Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# Processing noise file: noise_2023-04-28T21_50_39.467995Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# Processing noise file: noise_2023-04-28T21_50_39.467995Z_WS.POZA.S6.DN2.MSEED
# Processing trace: WS.POZA.S6.DN2
# Processing noise file: noise_2023-04-28T21_50_39.467995Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# Processing noise file: noise_2023-04-28T21_50_39.468683Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# Processing noise file: noise_2023-04-28T21_50_39.468683Z_WS.POZA.S3.DN2.MSEED
# Processing trace: WS.POZA.S3.DN2
# Processing noise file: noise_2023-04-28T21_50_39.468683Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# Processing noise file: noise_2023-04-28T21_50_39.469035Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# Processing noise file: noise_2023-04-28T21_50_39.469035Z_WS.POZA.S2.DN2.MSEED
# Processing trace: WS.POZA.S2.DN2
# Processing noise file: noise_2023-04-28T21_50_39.469035Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# Processing noise file: noise_2023-04-28T21_50_39.469607Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# Processing noise file: noise_2023-04-28T21_50_39.469607Z_WS.POZA.S5.DN2.MSEED
# Processing trace: WS.POZA.S5.DN2
# Processing noise file: noise_2023-04-28T21_50_39.469607Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# Processing noise file: noise_2023-04-28T21_50_39.470039Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# Processing noise file: noise_2023-04-28T21_50_39.470039Z_WS.POZA.S4.DN2.MSEED
# Processing trace: WS.POZA.S4.DN2
# Processing noise file: noise_2023-04-28T21_50_39.470039Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# Processing noise file: noise_2023-12-16T00_16_29.216875Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# Processing noise file: noise_2023-12-16T00_16_29.216875Z_WS.POZA.S3.DN2.MSEED
# Processing trace: WS.POZA.S3.DN2
# Processing noise file: noise_2023-12-16T00_16_29.216875Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# Processing noise file: noise_2023-12-16T00_16_29.218116Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# Processing noise file: noise_2023-12-16T00_16_29.218116Z_WS.POZA.S2.DN2.MSEED
# Processing trace: WS.POZA.S2.DN2
# Processing noise file: noise_2023-12-16T00_16_29.218116Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# Processing noise file: noise_2023-12-16T00_16_29.218219Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# Processing noise file: noise_2023-12-16T00_16_29.218219Z_WS.POZA.S5.DN2.MSEED
# Processing trace: WS.POZA.S5.DN2
# Processing noise file: noise_2023-12-16T00_16_29.218219Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# Processing noise file: noise_2023-12-16T00_16_29.218749Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# Processing noise file: noise_2023-12-16T00_16_29.218749Z_WS.POZA.S6.DN2.MSEED
# Processing trace: WS.POZA.S6.DN2
# Processing noise file: noise_2023-12-16T00_16_29.218749Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# Processing noise file: noise_2023-12-16T21_16_29.216650Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# Processing noise file: noise_2023-12-16T21_16_29.216650Z_WS.POZA.S3.DN2.MSEED
# Processing trace: WS.POZA.S3.DN2
# Processing noise file: noise_2023-12-16T21_16_29.216650Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# Processing noise file: noise_2023-12-16T21_16_29.217000Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# Processing noise file: noise_2023-12-16T21_16_29.217000Z_WS.POZA.S6.DN2.MSEED
# Processing trace: WS.POZA.S6.DN2
# Processing noise file: noise_2023-12-16T21_16_29.217000Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# Processing noise file: noise_2023-12-16T21_16_29.217923Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# Processing noise file: noise_2023-12-16T21_16_29.217923Z_WS.POZA.S2.DN2.MSEED
# Processing trace: WS.POZA.S2.DN2
# Processing noise file: noise_2023-12-16T21_16_29.217923Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# Processing noise file: noise_2023-12-16T21_16_29.219692Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# Processing noise file: noise_2023-12-16T21_16_29.219692Z_WS.POZA.S5.DN2.MSEED
# Processing trace: WS.POZA.S5.DN2
# Processing noise file: noise_2023-12-16T21_16_29.219692Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# Noise acceleration statistics saved to noise_acceleration_stats_250_samples.csv

# %% [markdown]
# So this is for the sample of 1sec pair 3 times

# %%
import random
from obspy import read
import pandas as pd
import numpy as np
from pathlib import Path
from scipy.stats import mode, skew, kurtosis, zscore

# Function to sanitize file names
def sanitize_filename(name):
    return name.replace(".", "").replace(":", "").replace("-", "").replace("_", "")

# Function to convert ADX355 counts to acceleration
def convert_adx355_counts_to_acceleration(counts, scale_factor=256000):
    acceleration_g = counts / scale_factor  # Convert counts to g
    acceleration_m_s2 = acceleration_g * 9.81  # Convert g to m/s²
    return acceleration_g, acceleration_m_s2

# Directories
mseed_noise_dir = "miniSEED_files_noise"
output_noise_csv = "noise_acceleration_stats_6sample_samples.csv"

# Number of samples per window
num_samples = 250  # 250 samples for each random window

# Store results
noise_results = []

# Loop through noise miniSEED files
for file_path in Path(mseed_noise_dir).glob("*.MSEED"):
    mseed_name = file_path.stem  # Use stem to avoid sanitizing

    print(f"Processing noise file: {file_path.name}")

    # Read miniSEED file
    stream = read(file_path)

    for trace in stream:
        print(f"Processing trace: {trace.id}")

        sampling_rate = trace.stats.sampling_rate
        total_samples = len(trace.data)

        try:
            # Convert counts to acceleration
            _, accel_m_s2 = convert_adx355_counts_to_acceleration(trace.data)
        except Exception as e:
            print(f"Error converting counts for {trace.id}: {e}")
            continue

        # Extract statistics for three random windows
        stats_per_file = [file_path.name, trace.id]  # First columns

        for _ in range(6):  # Generate 3 random windows
            # Select random start index for the window
            start_idx = random.randint(0, total_samples - num_samples)
            end_idx = start_idx + num_samples

            segment = accel_m_s2[start_idx:end_idx]

            # Compute statistics
            mean_val = np.mean(segment)
            median_val = np.median(segment)
            mode_val = mode(segment, keepdims=True).mode[0]
            std_val = np.std(segment)
            skewness_val = skew(segment)
            kurtosis_val = kurtosis(segment)
            variance_val = np.var(segment)
            max_val = np.max(segment)
            min_val = np.min(segment)
            z_scores = np.mean(zscore(segment))

            # Append stats to the row
            stats_per_file.extend([mean_val, median_val, mode_val, std_val, 
                                   skewness_val, kurtosis_val, variance_val, 
                                   max_val, min_val, z_scores])

        noise_results.append(stats_per_file)

# Define column headers
columns = ["File", "Trace ID"]
stats_headers = ["Mean", "Median", "Mode", "Std Dev", "Skewness", "Kurtosis", "Variance", "Max", "Min", "Z-Score"]

# Repeat headers for S1, S2, S3 (for random windows)
for sample in ["S1", "S2", "S3","S4","S5","S6"]:
    columns.extend([f"{sample} {stat}" for stat in stats_headers])

# Save results to CSV
df_noise_results = pd.DataFrame(noise_results, columns=columns)
df_noise_results.to_csv(output_noise_csv, index=False)
print(f"Noise acceleration statistics saved to {output_noise_csv}")
# Out:
# Processing noise file: noise_2023-02-21T01_07_00.489562Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# Processing noise file: noise_2023-02-21T01_07_00.489562Z_WS.POZA.S5.DN2.MSEED
# Processing trace: WS.POZA.S5.DN2
# Processing noise file: noise_2023-02-21T01_07_00.489562Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# Processing noise file: noise_2023-02-21T01_07_00.490149Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# Processing noise file: noise_2023-02-21T01_07_00.490149Z_WS.POZA.S6.DN2.MSEED
# Processing trace: WS.POZA.S6.DN2
# Processing noise file: noise_2023-02-21T01_07_00.490149Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# Processing noise file: noise_2023-02-21T01_07_00.491238Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# Processing noise file: noise_2023-02-21T01_07_00.491238Z_WS.POZA.S3.DN2.MSEED
# Processing trace: WS.POZA.S3.DN2
# Processing noise file: noise_2023-02-21T01_07_00.491238Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# Processing noise file: noise_2023-02-21T01_07_00.492647Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# Processing noise file: noise_2023-02-21T01_07_00.492647Z_WS.POZA.S2.DN2.MSEED
# Processing trace: WS.POZA.S2.DN2
# Processing noise file: noise_2023-02-21T01_07_00.492647Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# Processing noise file: noise_2023-02-21T01_07_00.493079Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# Processing noise file: noise_2023-02-21T01_07_00.493079Z_WS.POZA.S4.DN2.MSEED
# Processing trace: WS.POZA.S4.DN2
# Processing noise file: noise_2023-02-21T01_07_00.493079Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# Processing noise file: noise_2023-02-21T20_07_00.489606Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# Processing noise file: noise_2023-02-21T20_07_00.489606Z_WS.POZA.S5.DN2.MSEED
# Processing trace: WS.POZA.S5.DN2
# Processing noise file: noise_2023-02-21T20_07_00.489606Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# Processing noise file: noise_2023-02-21T20_07_00.489985Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# Processing noise file: noise_2023-02-21T20_07_00.489985Z_WS.POZA.S4.DN2.MSEED
# Processing trace: WS.POZA.S4.DN2
# Processing noise file: noise_2023-02-21T20_07_00.489985Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# Processing noise file: noise_2023-02-21T20_07_00.490689Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# Processing noise file: noise_2023
z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# Processing noise file: noise_2023-04-28T08_08_16.711406Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# Processing noise file: noise_2023-04-28T08_08_16.711406Z_WS.POZA.S4.DN2.MSEED
# Processing trace: WS.POZA.S4.DN2
# Processing noise file: noise_2023-04-28T08_08_16.711406Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# Processing noise file: noise_2023-04-28T21_50_39.467995Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# Processing noise file: noise_2023-04-28T21_50_39.467995Z_WS.POZA.S6.DN2.MSEED
# Processing trace: WS.POZA.S6.DN2
# Processing noise file: noise_2023-04-28T21_50_39.467995Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# Processing noise file: noise_2023-04-28T21_50_39.468683Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# Processing noise file: noise_2023-04-28T21_50_39.468683Z_WS.POZA.S3.DN2.MSEED
# Processing trace: WS.POZA.S3.DN2
# Processing noise file: noise_2023-04-28T21_50_39.468683Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# Processing noise file: noise_2023-04-28T21_50_39.469035Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# Processing noise file: noise_2023-04-28T21_50_39.469035Z_WS.POZA.S2.DN2.MSEED
# Processing trace: WS.POZA.S2.DN2
# Processing noise file: noise_2023-04-28T21_50_39.469035Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# Processing noise file: noise_2023-04-28T21_50_39.469607Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# Processing noise file: noise_2023-04-28T21_50_39.469607Z_WS.POZA.S5.DN2.MSEED
# Processing trace: WS.POZA.S5.DN2
# Processing noise file: noise_2023-04-28T21_50_39.469607Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# Processing noise file: noise_2023-04-28T21_50_39.470039Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# Processing noise file: noise_2023-04-28T21_50_39.470039Z_WS.POZA.S4.DN2.MSEED
# Processing trace: WS.POZA.S4.DN2
# Processing noise file: noise_2023-04-28T21_50_39.470039Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# Processing noise file: noise_2023-12-16T00_16_29.216875Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# Processing noise file: noise_2023-12-16T00_16_29.216875Z_WS.POZA.S3.DN2.MSEED
# Processing trace: WS.POZA.S3.DN2
# Processing noise file: noise_2023-12-16T00_16_29.216875Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# Processing noise file: noise_2023-12-16T00_16_29.218116Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# Processing noise file: noise_2023-12-16T00_16_29.218116Z_WS.POZA.S2.DN2.MSEED
# Processing trace: WS.POZA.S2.DN2
# Processing noise file: noise_2023-12-16T00_16_29.218116Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# Processing noise file: noise_2023-12-16T00_16_29.218219Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# Processing noise file: noise_2023-12-16T00_16_29.218219Z_WS.POZA.S5.DN2.MSEED
# Processing trace: WS.POZA.S5.DN2
# Processing noise file: noise_2023-12-16T00_16_29.218219Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# Processing noise file: noise_2023-12-16T00_16_29.218749Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# Processing noise file: noise_2023-12-16T00_16_29.218749Z_WS.POZA.S6.DN2.MSEED
# Processing trace: WS.POZA.S6.DN2
# Processing noise file: noise_2023-12-16T00_16_29.218749Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# Processing noise file: noise_2023-12-16T21_16_29.216650Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# Processing noise file: noise_2023-12-16T21_16_29.216650Z_WS.POZA.S3.DN2.MSEED
# Processing trace: WS.POZA.S3.DN2
# Processing noise file: noise_2023-12-16T21_16_29.216650Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# Processing noise file: noise_2023-12-16T21_16_29.217000Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# Processing noise file: noise_2023-12-16T21_16_29.217000Z_WS.POZA.S6.DN2.MSEED
# Processing trace: WS.POZA.S6.DN2
# Processing noise file: noise_2023-12-16T21_16_29.217000Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# Processing noise file: noise_2023-12-16T21_16_29.217923Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# Processing noise file: noise_2023-12-16T21_16_29.217923Z_WS.POZA.S2.DN2.MSEED
# Processing trace: WS.POZA.S2.DN2
# Processing noise file: noise_2023-12-16T21_16_29.217923Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# Processing noise file: noise_2023-12-16T21_16_29.219692Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# Processing noise file: noise_2023-12-16T21_16_29.219692Z_WS.POZA.S5.DN2.MSEED
# Processing trace: WS.POZA.S5.DN2
# Processing noise file: noise_2023-12-16T21_16_29.219692Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# Noise acceleration statistics saved to noise_acceleration_stats_6sample_samples.csv

# %%
import random
from obspy import read
import pandas as pd
import numpy as np
from pathlib import Path
from scipy.stats import mode, skew, kurtosis, zscore

# Function to convert ADX355 counts to acceleration
def convert_adx355_counts_to_acceleration(counts, scale_factor=256000):
    acceleration_g = counts / scale_factor  # Convert counts to g
    acceleration_m_s2 = acceleration_g * 9.81  # Convert g to m/s²
    return acceleration_g, acceleration_m_s2

# Directories
mseed_noise_dir = "miniSEED_files_noise"
output_noise_csv = "noise_acceleration_stats_1sec_samples.csv"

# Number of samples per window
sampling_rate = 250  # 250 Hz means 250 samples per second
num_samples = sampling_rate  # 1 second window

# Store results
noise_results = []

# Loop through noise miniSEED files
for file_path in Path(mseed_noise_dir).glob("*.MSEED"):
    print(f"Processing noise file: {file_path.name}")

    # Read miniSEED file
    stream = read(file_path)

    for trace in stream:
        print(f"Processing trace: {trace.id}")

        total_samples = len(trace.data)

        try:
            # Convert counts to acceleration
            _, accel_m_s2 = convert_adx355_counts_to_acceleration(trace.data)
        except Exception as e:
            print(f"Error converting counts for {trace.id}: {e}")
            continue

        # Extract statistics for three pairs of random 1-second windows
        for _ in range(3):  # Repeat 3 times per file
            stats_per_file = [file_path.name, trace.id]
            
            for _ in range(2):  # Two random 1-second samples per pair
                start_idx = random.randint(0, total_samples - num_samples)
                end_idx = start_idx + num_samples
                segment = accel_m_s2[start_idx:end_idx]

                # Compute statistics
                mean_val = np.mean(segment)
                median_val = np.median(segment)
                mode_val = mode(segment, keepdims=True).mode[0]
                std_val = np.std(segment)
                skewness_val = skew(segment)
                kurtosis_val = kurtosis(segment)
                variance_val = np.var(segment)
                max_val = np.max(segment)
                min_val = np.min(segment)
                z_scores = np.mean(zscore(segment))

                # Append stats to the row
                stats_per_file.extend([mean_val, median_val, mode_val, std_val, 
                                       skewness_val, kurtosis_val, variance_val, 
                                       max_val, min_val, z_scores])

            noise_results.append(stats_per_file)

# Define column headers
columns = ["File", "Trace ID"]
stats_headers = ["Mean", "Median", "Mode", "Std Dev", "Skewness", "Kurtosis", "Variance", "Max", "Min", "Z-Score"]

# Repeat headers for three pairs of random 1-second samples
for pair in ["Pair1", "Pair2", "Pair3"]:
    for sample in ["Sample1", "Sample2"]:
        columns.extend([f"{pair} {sample} {stat}" for stat in stats_headers])

# Save results to CSV
df_noise_results = pd.DataFrame(noise_results, columns=columns)
df_noise_results.to_csv(output_noise_csv, index=False)
print(f"Noise acceleration statistics saved to {output_noise_csv}")
# Out:
# Processing noise file: noise_2023-02-21T01_07_00.489562Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# Processing noise file: noise_2023-02-21T01_07_00.489562Z_WS.POZA.S5.DN2.MSEED
# Processing trace: WS.POZA.S5.DN2
# Processing noise file: noise_2023-02-21T01_07_00.489562Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# Processing noise file: noise_2023-02-21T01_07_00.490149Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# Processing noise file: noise_2023-02-21T01_07_00.490149Z_WS.POZA.S6.DN2.MSEED
# Processing trace: WS.POZA.S6.DN2
# Processing noise file: noise_2023-02-21T01_07_00.490149Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# Processing noise file: noise_2023-02-21T01_07_00.491238Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# Processing noise file: noise_2023-02-21T01_07_00.491238Z_WS.POZA.S3.DN2.MSEED
# Processing trace: WS.POZA.S3.DN2
# Processing noise file: noise_2023-02-21T01_07_00.491238Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# Processing noise file: noise_2023-02-21T01_07_00.492647Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# Processing noise file: noise_2023-02-21T01_07_00.492647Z_WS.POZA.S2.DN2.MSEED
# Processing trace: WS.POZA.S2.DN2
# Processing noise file: noise_2023-02-21T01_07_00.492647Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# Processing noise file: noise_2023-02-21T01_07_00.493079Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# Processing noise file: noise_2023-02-21T01_07_00.493079Z_WS.POZA.S4.DN2.MSEED
# Processing trace: WS.POZA.S4.DN2
# Processing noise file: noise_2023-02-21T01_07_00.493079Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# Processing noise file: noise_2023-02-21T20_07_00.489606Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# Processing noise file: noise_2023-02-21T20_07_00.489606Z_WS.POZA.S5.DN2.MSEED
# Processing trace: WS.POZA.S5.DN2
# Processing noise file: noise_2023-02-21T20_07_00.489606Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# Processing noise file: noise_2023-02-21T20_07_00.489985Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# Processing noise file: noise_2023-02-21T20_07_00.489985Z_WS.POZA.S4.DN2.MSEED
# Processing trace: WS.POZA.S4.DN2
# Processing noise file: noise_2023-02-21T20_07_00.489985Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# Processing noise file: noise_2023-02-21T20_07_00.490689Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# Processing noise file: noise_2023-02-21T20_07_00.490689Z_WS.POZA.S6.DN2.MSEED
# Processing trace: WS.POZA.S6.DN2
# Processing noise file: noise_2023-02-21T20_07_00.490689Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# Processing noise file: noise_2023-02-21T20_07_00.490809Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# Processing noise file: noise_2023-02-21T20_07_00.490809Z_WS.POZA.S3.DN2.MSEED
# Processing trace: WS.POZA.S3.DN2
# Processing noise file: noise_2023-02-21T20_07_00.490809Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# Processing noise file: noise_2023-02-21T20_07_00.493184Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# Processing noise file: noise_2023-02-21T20_07_00.493184Z_WS.POZA.S2.DN2.MSEED
# Processing trace: WS.POZA.S2.DN2
# Processing noise file: noise_2023-02-21T20_07_00.493184Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# Processing noise file: noise_2023-03-10T03_12_24.010169Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# Processing noise file: noise_2023-03-10T03_12_24.010169Z_WS.POZA.S6.DN2.MSEED
# Processing trace: WS.POZA.S6.DN2
# Processing noise file: noise_2023-03-10T03_12_24.010169Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# Processing noise file: noise_2023-03-10T03_12_24.010523Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# Processing noise file: noise_2023-03-10T03_12_24.010523Z_WS.POZA.S3.DN2.MSEED
# Processing trace: WS.POZA.S3.DN2
# Processing noise file: noise_2023-03-10T03_12_24.010523Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# Processing noise file: noise_2023-03-10T03_12_24.010607Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# Processing noise file: noise_2023-03-10T03_12_24.010607Z_WS.POZA.S4.DN2.MSEED
# Processing trace: WS.POZA.S4.DN2
# Processing noise file: noise_2023-03-10T03_12_24.010607Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# Processing noise file: noise_2023-03-10T03_12_24.012432Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# Processing noise file: noise_2023
z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# Processing noise file: noise_2023-04-28T21_50_39.470039Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# Processing noise file: noise_2023-04-28T21_50_39.470039Z_WS.POZA.S4.DN2.MSEED
# Processing trace: WS.POZA.S4.DN2
# Processing noise file: noise_2023-04-28T21_50_39.470039Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# Processing noise file: noise_2023-12-16T00_16_29.216875Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# Processing noise file: noise_2023-12-16T00_16_29.216875Z_WS.POZA.S3.DN2.MSEED
# Processing trace: WS.POZA.S3.DN2
# Processing noise file: noise_2023-12-16T00_16_29.216875Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# Processing noise file: noise_2023-12-16T00_16_29.218116Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# Processing noise file: noise_2023-12-16T00_16_29.218116Z_WS.POZA.S2.DN2.MSEED
# Processing trace: WS.POZA.S2.DN2
# Processing noise file: noise_2023-12-16T00_16_29.218116Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# Processing noise file: noise_2023-12-16T00_16_29.218219Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# Processing noise file: noise_2023-12-16T00_16_29.218219Z_WS.POZA.S5.DN2.MSEED
# Processing trace: WS.POZA.S5.DN2
# Processing noise file: noise_2023-12-16T00_16_29.218219Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# Processing noise file: noise_2023-12-16T00_16_29.218749Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# Processing noise file: noise_2023-12-16T00_16_29.218749Z_WS.POZA.S6.DN2.MSEED
# Processing trace: WS.POZA.S6.DN2
# Processing noise file: noise_2023-12-16T00_16_29.218749Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# Processing noise file: noise_2023-12-16T21_16_29.216650Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# Processing noise file: noise_2023-12-16T21_16_29.216650Z_WS.POZA.S3.DN2.MSEED
# Processing trace: WS.POZA.S3.DN2
# Processing noise file: noise_2023-12-16T21_16_29.216650Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# Processing noise file: noise_2023-12-16T21_16_29.217000Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# Processing noise file: noise_2023-12-16T21_16_29.217000Z_WS.POZA.S6.DN2.MSEED
# Processing trace: WS.POZA.S6.DN2
# Processing noise file: noise_2023-12-16T21_16_29.217000Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# Processing noise file: noise_2023-12-16T21_16_29.217923Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# Processing noise file: noise_2023-12-16T21_16_29.217923Z_WS.POZA.S2.DN2.MSEED
# Processing trace: WS.POZA.S2.DN2
# Processing noise file: noise_2023-12-16T21_16_29.217923Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# Processing noise file: noise_2023-12-16T21_16_29.219692Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# Processing noise file: noise_2023-12-16T21_16_29.219692Z_WS.POZA.S5.DN2.MSEED
# Processing trace: WS.POZA.S5.DN2
# Processing noise file: noise_2023-12-16T21_16_29.219692Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File c:\Users\Ayush_trainee\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:939, in _finalize_columns_and_data(content, columns, dtype)
#     938 try:
# --> 939     columns = _validate_or_indexify_columns(contents, columns)
#     940 except AssertionError as err:
#     941     # GH#26429 do not raise user-facing AssertionError
#
# File c:\Users\Ayush_trainee\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:986, in _validate_or_indexify_columns(content, columns)
#     984 if not is_mi_list and len(columns) != len(content):  # pragma: no cover
#     985     # caller's responsibility to check for this...
# --> 986     raise AssertionError(
#     987         f"{len(columns)} columns passed, passed data had "
#     988         f"{len(content)} columns"
#     989     )
#     990 if is_mi_list:
#     991     # check if nested list column, length of each sub-list should be equal
#
# AssertionError: 62 columns passed, passed data had 22 columns
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 82
#      79         columns.extend([f"{pair} {sample} {stat}" for stat in stats_headers])
#      81 # Save results to CSV
# ---> 82 df_noise_results = pd.DataFrame(noise_results, columns=columns)
#      83 df_noise_results.to_csv(output_noise_csv, index=False)
#      84 print(f"Noise acceleration statistics saved to {output_noise_csv}")
#
# File c:\Users\Ayush_trainee\anaconda3\Lib\site-packages\pandas\core\frame.py:851, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     849     if columns is not None:
#     850         columns = ensure_index(columns)
# --> 851     arrays, columns, index = nested_data_to_arrays(
#     852         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     853         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#     854         data,
#     855         columns,
#     856         index,  # type: ignore[arg-type]
#     857         dtype,
#     858     )
#     859     mgr = arrays_to_mgr(
#     860         arrays,
#     861         columns,
#    (...)
#     864         typ=manager,
#     865     )
#     866 else:
#
# File c:\Users\Ayush_trainee\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:520, in nested_data_to_arrays(data, columns, index, dtype)
#     517 if is_named_tuple(data[0]) and columns is None:
#     518     columns = ensure_index(data[0]._fields)
# --> 520 arrays, columns = to_arrays(data, columns, dtype=dtype)
#     521 columns = ensure_index(columns)
#     523 if index is None:
#
# File c:\Users\Ayush_trainee\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:845, in to_arrays(data, columns, dtype)
#     842     data = [tuple(x) for x in data]
#     843     arr = _list_to_arrays(data)
# --> 845 content, columns = _finalize_columns_and_data(arr, columns, dtype)
#     846 return content, columns
#
# File c:\Users\Ayush_trainee\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:942, in _finalize_columns_and_data(content, columns, dtype)
#     939     columns = _validate_or_indexify_columns(contents, columns)
#     940 except AssertionError as err:
#     941     # GH#26429 do not raise user-facing AssertionError
# --> 942     raise ValueError(err) from err
#     944 if len(contents) and contents[0].dtype == np.object_:
#     945     contents = convert_object_array(contents, dtype=dtype)
#
# ValueError: 62 columns passed, passed data had 22 columns
