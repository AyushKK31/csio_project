# %%
from obspy import read, UTCDateTime
import pandas as pd
import numpy as np
from pathlib import Path
from scipy.stats import mode, skew, kurtosis, zscore

# Load pick data
pick_data = pd.read_csv(
    "dataset_earthquakes/metadata.csv", 
    usecols=['trace_name_original_Z', 'trace_p_pick_time']
)

# Function to sanitize file names
def sanitize_filename(name):
    return name.replace(".", "").replace(":", "").replace("-", "").replace("_", "")

# Function to convert ADX355 counts to acceleration
def convert_adx355_counts_to_acceleration(counts, scale_factor=256000):
    acceleration_g = counts / scale_factor  # Convert counts to g
    acceleration_m_s2 = acceleration_g * 9.81  # Convert g to m/s²
    return acceleration_g, acceleration_m_s2

# Directories
mseed_dir = "miniSEED_files"
output_csv = "acceleration_stats_250_samples.csv"

# Number of samples per window
num_samples = 250  # Adjusted to 250 samples per window

# Store results
results = []

# Loop through miniSEED files
for file_path in Path(mseed_dir).glob("*.MSEED"):
    mseed_name = sanitize_filename(file_path.name.strip())

    # Find matching metadata row
    matched_row = None
    for _, row in pick_data.iterrows():
        if sanitize_filename(row['trace_name_original_Z']) == mseed_name:
            matched_row = row
            break

    if matched_row is None:
        print(f"No match found for file: {file_path.name}")
        continue

    print(f"Processing: {file_path.name}")

    # Extract P-pick time
    try:
        p_pick = UTCDateTime(matched_row['trace_p_pick_time'])
    except Exception as e:
        print(f"Error parsing P-pick time for {file_path.name}: {e}")
        continue

    # Read miniSEED file
    stream = read(file_path)

    for trace in stream:
        print(f"Processing trace: {trace.id}")

        sampling_rate = trace.stats.sampling_rate
        total_samples = len(trace.data)

        try:
            # Convert counts to acceleration
            _, accel_m_s2 = convert_adx355_counts_to_acceleration(trace.data)
        except Exception as e:
            print(f"Error converting counts for {trace.id}: {e}")
            continue

        # Get time array
        times = np.linspace(trace.stats.starttime.timestamp, trace.stats.endtime.timestamp, total_samples)

        # Find P-pick index
        closest_idx = np.argmin(np.abs(times - p_pick.timestamp))

        # Extract statistics for three windows:
        stats_per_file = [file_path.name, trace.id, str(p_pick)]  # First columns

        for offset in [-num_samples, 0, num_samples]:  # Before, At, After
            start_idx = closest_idx + offset
            end_idx = start_idx + num_samples

            # Ensure indices are within bounds
            if start_idx < 0 or end_idx > total_samples:
                print(f"Skipping window for {trace.id} due to insufficient data.")
                stats_per_file.extend(["N/A"] * 10)  # Append empty stats if data is missing
                continue

            segment = accel_m_s2[start_idx:end_idx]

            # Compute statistics
            mean_val = np.mean(segment)
            median_val = np.median(segment)
            mode_val = mode(segment, keepdims=True).mode[0]
            std_val = np.std(segment)
            skewness_val = skew(segment)
            kurtosis_val = kurtosis(segment)
            variance_val = np.var(segment)
            max_val = np.max(segment)
            min_val = np.min(segment)
            z_scores = np.mean(zscore(segment))

            # Append stats to the row
            stats_per_file.extend([mean_val, median_val, mode_val, std_val, 
                                   skewness_val, kurtosis_val, variance_val, 
                                   max_val, min_val, z_scores])

        results.append(stats_per_file)

# Define column headers
columns = ["File", "Trace ID", "P-Pick Time"]
stats_headers = ["Mean", "Median", "Mode", "Std Dev", "Skewness", "Kurtosis", "Variance", "Max", "Min", "Z-Score"]

# Repeat headers for S1, S2, S3
for sample in ["S1", "S2", "S3"]:
    columns.extend([f"{sample} {stat}" for stat in stats_headers])

# Save results to CSV
df_results = pd.DataFrame(results, columns=columns)
df_results.to_csv(output_csv, index=False)
print(f"Acceleration statistics saved to {output_csv}")
# Out:
# No match found for file: 34161341_2023-02-21T00.07.00.489723Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34161341_2023-02-21T00.07.00.489723Z_WS.POZA.S5.DN2.MSEED
# Processing: 34161341_2023-02-21T00.07.00.489723Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# No match found for file: 34161341_2023-02-21T00.07.00.490024Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34161341_2023-02-21T00.07.00.490024Z_WS.POZA.S3.DN2.MSEED
# Processing: 34161341_2023-02-21T00.07.00.490024Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# No match found for file: 34161341_2023-02-21T00.07.00.490032Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34161341_2023-02-21T00.07.00.490032Z_WS.POZA.S2.DN2.MSEED
# Processing: 34161341_2023-02-21T00.07.00.490032Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# No match found for file: 34161341_2023-02-21T00.07.00.490708Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34161341_2023-02-21T00.07.00.490708Z_WS.POZA.S4.DN2.MSEED
# Processing: 34161341_2023-02-21T00.07.00.490708Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# No match found for file: 34161341_2023-02-21T00.07.00.493150Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34161341_2023-02-21T00.07.00.493150Z_WS.POZA.S6.DN2.MSEED
# Processing: 34161341_2023-02-21T00.07.00.493150Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# No match found for file: 34161511_2023-02-21T00.12.34.317723Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34161511_2023-02-21T00.12.34.317723Z_WS.POZA.S5.DN2.MSEED
# Processing: 34161511_2023-02-21T00.12.34.317723Z_WS.POZA.S5.DNZ.MSEED
# Error parsing P-pick time for 34161511_2023-02-21T00.12.34.317723Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161511_2023-02-21T00.12.34.318024Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34161511_2023-02-21T00.12.34.318024Z_WS.POZA.S3.DN2.MSEED
# Processing: 34161511_2023-02-21T00.12.34.318024Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# No match found for file: 34161511_2023-02-21T00.12.34.318032Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34161511_2023-02-21T00.12.34.318032Z_WS.POZA.S2.DN2.MSEED
# Processing: 34161511_2023-02-21T00.12.34.318032Z_WS.POZA.S2.DNZ.MSEED
# Error parsing P-pick time for 34161511_2023-02-21T00.12.34.318032Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161511_2023-02-21T00.12.34.318708Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34161511_2023-02-21T00.12.34.318708Z_WS.POZA.S4.DN2.MSEED
# Processing: 34161511_2023-02-21T00.12.34.318708Z_WS.POZA.S4.DNZ.MSEED
# Error parsing P-pick time for 34161511_2023-02-21T00.12.34.318708Z_WS.POZA.S4.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161511_2023-02-21T00.12.34.321150Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34161511_2023-02-21T00.12.34.321150Z_WS.POZA.S6.DN2.MSEED
# Processing: 34161511_2023-02-21T00.12.34.321150Z_WS.POZA.S6.DNZ.MSEED
# Error parsing P-pick time for 34161511_2023-02-21T00.12.34.321150Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161571_2023-02-21T00.14.39.009723Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34161571_2023-02-21T00.14.39.009723Z_WS.POZA.S5.DN2.MSEED
# Processing: 34161571_2023-02-21T00.14.39.009723Z_WS.POZA.S5.DNZ.MSEED
# Error parsing P-pick time for 34161571_2023-02-21T00.14.39.009723Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161571_2023-02-21T00.14.39.010024Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34161571_2023-02-21T00.14.39.010024Z_WS.POZA.S3.DN2.MSEED
# Processing: 34161571_2023-02-21T00.14.39.010024Z_WS.POZA.S3.DNZ.MSEED
# Error parsing P-pick time for 34161571_2023-02-21T00.14.39.010024Z_WS.POZA.S3.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161571_2023-02-21T00.14.39.010032Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34161571_2023-02-21T00.14.39.010032Z_WS.POZA.S2.DN2.MSEED
# Processing: 34161571_2023-02-21T00.14.39.010032Z_WS.POZA.S2.DNZ.MSEED
# Error parsing P-pick time for 34161571_2023-02-21T00.14.39.010032Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161571_2023-02-21T00.14.39.010708Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34161571_2023-02-21T00.14.39.010708Z_WS.POZA.S4.DN2.MSEED
# Processing: 34161571_2023-02-21T00.14.39.010708Z_WS.POZA.S4.DNZ.MSEED
# Error parsing P-pick time for 34161571_2023-02-21T00.14.39.010708Z_WS.POZA.S4.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161571_2023-02-21T00.14.39.013150Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34161571_2023-02-21T00.14.39.013150Z_WS.POZA.S6.DN2.MSEED
# Processing: 34161571_2023-02-21T00.14.39.013150Z_WS.POZA.S6.DNZ.MSEED
# Error parsing P-pick time for 34161571_2023-02-21T00.14.39.013150Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161621_2023-02-21T00.18.41.857723Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34161621_2023-02-21T00.18.41.857723Z_WS.POZA.S5.DN2.MSEED
# Processing: 34161621_2023-02-21T00.18.41.857723Z_WS.POZA.S5.DNZ.MSEED
# Error parsing P-pick time for 34161621_2023-02-21T00.18.41.857723Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161621_2023-02-21T00.18.41.858024Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34161621_2023-02-21T00.18.41.858024Z_WS.POZA.S3.DN2.MSEED
# Processing: 34161621_2023-02-21T00.18.41.858024Z_WS.POZA.S3.DNZ.MSEED
# Error parsing P-pick time for 34161621_2023-02-21T00.18.41.858024Z_WS.POZA.S3.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161621_2023-02-21T00.18.41.858032Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34161621_2023-02-21T00.18.41.858032Z_WS.POZA.S2.DN2.MSEED
# Processing: 34161621_2023-02-21T00.18.41.858032Z_WS.POZA.S2.DNZ.MSEED
# Error parsing P-pick time for 34161621_2023-02-21T00.18.41.858032Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161621_2023-02-21T00.18.41.858708Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34161621_2023-02-21T00.18.41.858708Z_WS.POZA.S4.DN2.MSEED
# Processing: 34161621_2023-02-21T00.18.41.858708Z_WS.POZA.S4.DNZ.MSEED
# Error parsing P-pick time for 34161621_2023-02-21T00.18.41.858708Z_WS.POZA.S4.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161621_2023-02-21T00.18.41.861150Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34161621_2023-02-21T00.18.41.861150Z_WS.POZA.S6.DN2.MSEED
# Processing: 34161621_2023-02-21T00.18.41.861150Z_WS.POZA.S6.DNZ.MSEED
# Error parsing P-pick time for 34161621_2023-02-21T00.18.41.861150Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161791_2023-02-21T00.40.23.069600Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34161791_2023-02-21T00.40.23.069600Z_WS.POZA.S5.DN2.MSEED
# Processing: 34161791_2023-02-21T00.40.23.069600Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# No match found for file: 34161791_2023-02-21T00.40.23.070024Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34161791_2023-02-21T00.40.23.070024Z_WS.POZA.S3.DN2.MSEED
# Processing: 34161791_2023-02-21T00.40.23.070024Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# No match found for file: 34161791_2023-02-21T00.40.23.070032Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34161791_2023-02-21T00.40.23.070032Z_WS.POZA.S2.DN2.MSEED
# Processing: 34161791_2023-02-21T00.40.23.070032Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# No match found for file: 34161791_2023-02-21T00.40.23.070708Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34161791_2023-02-21T00.40.23.070708Z_WS.POZA.S4.DN2.MSEED
# Processing: 34161791_2023-02-21T00.40.23.070708Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# No match found for file: 34161791_2023-02-21T00.40.23.072380Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34161791_2023-02-21T00.40.23.072380Z_WS.POZA.S6.DN2.MSEED
# Processing: 34161791_2023-02-21T00.40.23.072380Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# No match found for file: 34162021_2023-02-21T00.56.56.517600Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34162021_2023-02-21T00.56.56.517600Z_WS.POZA.S5.DN2.MSEED
# Processing: 34162021_2023-02-21T00.56.56.517600Z_WS.POZA.S5.DNZ.MSEED
# Error parsing P-pick time for 34162021_2023-02-21T00.56.56.517600Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162021_2023-02-21T00.56.56.518032Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34162021_2023-02-21T00.56.56.518032Z_WS.POZA.S2.DN2.MSEED
# Processing: 34162021_2023-02-21T00.56.56.518032Z_WS.POZA.S2.DNZ.MSEED
# Error parsing P-pick time for 34162021_2023-02-21T00.56.56.518032Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162021_2023-02-21T00.56.56.519238Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34162021_2023-02-21T00.56.56.519238Z_WS.POZA.S3.DN2.MSEED
# Processing: 34162021_2023-02-21T00.56.56.519238Z_WS.POZA.S3.DNZ.MSEED
# Error parsing P-pick time for 34162021_2023-02-21T00.56.56.519238Z_WS.POZA.S3.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162021_2023-02-21T00.56.56.520384Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34162021_2023-02-21T00.56.56.520384Z_WS.POZA.S6.DN2.MSEED
# Processing: 34162021_2023-02-21T00.56.56.520384Z_WS.POZA.S6.DNZ.MSEED
# Error parsing P-pick time for 34162021_2023-02-21T00.56.56.520384Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162021_2023-02-21T00.56.56.521079Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34162021_2023-02-21T00.56.56.521079Z_WS.POZA.S4.DN2.MSEED
# Processing: 34162021_2023-02-21T00.56.56.521079Z_WS.POZA.S4.DNZ.MSEED
# Error parsing P-pick time for 34162021_2023-02-21T00.56.56.521079Z_WS.POZA.S4.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162111_2023-02-21T01.02.21.829562Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34162111_2023-02-21T01.02.21.829562Z_WS.POZA.S5.DN2.MSEED
# Processing: 34162111_2023-02-21T01.02.21.829562Z_WS.POZA.S5.DNZ.MSEED
# Error parsing P-pick time for 34162111_2023-02-21T01.02.21.829562Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162111_2023-02-21T01.02.21.831238Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34162111_2023-02-21T01.02.21.831238Z_WS.POZA.S3.DN2.MSEED
# Processing: 34162111_2023-02-21T01.02.21.831238Z_WS.POZA.S3.DNZ.MSEED
# Error parsing P-pick time for 34162111_2023-02-21T01.02.21.831238Z_WS.POZA.S3.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162111_2023-02-21T01.02.21.832384Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34162111_2023-02-21T01.02.21.832384Z_WS.POZA.S6.DN2.MSEED
# Processing: 34162111_2023-02-21T01.02.21.832384Z_WS.POZA.S6.DNZ.MSEED
# Error parsing P-pick time for 34162111_2023-02-21T01.02.21.832384Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162111_2023-02-21T01.02.21.832647Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34162111_2023-02-21T01.02.21.832647Z_WS.POZA.S2.DN2.MSEED
# Processing: 34162111_2023-02-21T01.02.21.832647Z_WS.POZA.S2.DNZ.MSEED
# Error parsing P-pick time for 34162111_2023-02-21T01.02.21.832647Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162111_2023-02-21T01.02.21.833079Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34162111_2023-02-21T01.02.21.833079Z_WS.POZA.S4.DN2.MSEED
# Processing: 34162111_2023-02-21T01.02.21.833079Z_WS.POZA.S4.DNZ.MSEED
# Error parsing P-pick time for 34162111_2023-02-21T01.02.21.833079Z_WS.POZA.S4.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162221_2023-02-21T01.06.56.697562Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34162221_2023-02-21T01.06.56.697562Z_WS.POZA.S5.DN2.MSEED
# Processing: 34162221_2023-02-21T01.06.56.697562Z_WS.POZA.S5.DNZ.MSEED
# Error parsing P-pick time for 34162221_2023-02-21T01.06.56.697562Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162221_2023-02-21T01.06.56.698149Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34162221_2023-02-21T01.06.56.698149Z_WS.POZA.S6.DN2.MSEED
# Processing: 34162221_2023-02-21T01.06.56.698149Z_WS.POZA.S6.DNZ.MSEED
# Error parsing P-pick time for 34162221_2023-02-21T01.06.56.698149Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162221_2023-02-21T01.06.56.699238Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34162221_2023-02-21T01.06.56.699238Z_WS.POZA.S3.DN2.MSEED
# Processing: 34162221_2023-02-21T01.06.56.699238Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# No match found for file: 34162221_2023-02-21T01.06.56.700647Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34162221_2023-02-21T01.06.56.700647Z_WS.POZA.S2.DN2.MSEED
# Processing: 34162221_2023-02-21T01.06.56.700647Z_WS.POZA.S2.DNZ.MSEED
# Error parsing P-pick time for 34162221_2023-02-21T01.06.56.700647Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162221_2023-02-21T01.06.56.701079Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34162221_2023-02-21T01.06.56.701079Z_WS.POZA.S4.DN2.MSEED
# Processing: 34162221_2023-02-21T01.06.56.701079Z_WS.POZA.S4.DNZ.MSEED
# Error parsing P-pick time for 34162221_2023-02-21T01.06.56.701079Z_WS.POZA.S4.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162311_2023-02-21T01.15.19.397562Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34162311_2023-02-21T01.15.19.397562Z_WS.POZA.S5.DN2.MSEED
# Processing: 34162311_2023-02-21T01.15.19.397562Z_WS.POZA.S5.DNZ.MSEED
# Error parsing P-pick time for 34162311_2023-02-21T01.15.19.397562Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162311_2023-02-21T01.15.19.398149Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34162311_2023-02-21T01.15.19.398149Z_WS.POZA.S6.DN2.MSEED
# Processing: 34162311_2023-02-21T01.15.19.398149Z_WS.POZA.S6.DNZ.MSEED
# Error parsing P-pick time for 34162311_2023-02-21T01.15.19.398149Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162311_2023-02-21T01.15.19.399238Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34162311_2023-02-21T01.15.19.399238Z_WS.POZA.S3.DN2.MSEED
# Processing: 34162311_2023-02-21T01.15.19.399238Z_WS.POZA.S3.DNZ.MSEED
# Error parsing P-pick time for 34162311_2023-02-21T01.15.19.399238Z_WS.POZA.S3.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162311_2023-02-21T01.15.19.400647Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34162311_2023-02-21T01.15.19.400647Z_WS.POZA.S2.DN2.MSEED
# Processing: 34162311_2023-02-21T01.15.19.400647Z_WS.POZA.S2.DNZ.MSEED
# Error parsing P-pick time for 34162311_2023-02-21T01.15.19.400647Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162311_2023-02-21T01.15.19.401079Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34162311_2023-02-21T01.15.19.401079Z_WS.POZA.S4.DN2.MSEED
# Processing: 34162311_2023-02-21T01.15.19.401079Z_WS.POZA.S4.DNZ.MSEED
# Error parsing P-pick time for 34162311_2023-02-21T01.15.19.401079Z_WS.POZA.S4.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162371_2023-02-21T01.31.01.417675Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34162371_2023-02-21T01.31.01.417675Z_WS.POZA.S5.DN2.MSEED
# Processing: 34162371_2023-02-21T01.31.01.417675Z_WS.POZA.S5.DNZ.MSEED
# Error parsing P-pick time for 34162371_2023-02-21T01.31.01.417675Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162371_2023-02-21T01.31.01.417936Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34162371_2023-02-21T01.31.01.417936Z_WS.POZA.S6.DN2.MSEED
# Processing: 34162371_2023-02-21T01.31.01.417936Z_WS.POZA.S6.DNZ.MSEED
# Error parsing P-pick time for 34162371_2023-02-21T01.31.01.417936Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162371_2023-02-21T01.31.01.419238Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34162371_2023-02-21T01.31.01.419238Z_WS.POZA.S3.DN2.MSEED
# Processing: 34162371_2023-02-21T01.31.01.419238Z_WS.POZA.S3.DNZ.MSEED
# Error parsing P-pick time for 34162371_2023-02-21T01.31.01.419238Z_WS.POZA.S3.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162371_2023-02-21T01.31.01.420647Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34162371_2023-02-21T01.31.01.420647Z_WS.POZA.S2.DN2.MSEED
# Processing: 34162371_2023-02-21T01.31.01.420647Z_WS.POZA.S2.DNZ.MSEED
# Error parsing P-pick time for 34162371_2023-02-21T01.31.01.420647Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162371_2023-02-21T01.31.01.421079Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34162371_2023-02-21T01.31.01.421079Z_WS.POZA.S4.DN2.MSEED
# Processing: 34162371_2023-02-21T01.31.01.421079Z_WS.POZA.S4.DNZ.MSEED
# Error parsing P-pick time for 34162371_2023-02-21T01.31.01.421079Z_WS.POZA.S4.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162431_2023-02-21T01.31.15.097675Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34162431_2023-02-21T01.31.15.097675Z_WS.POZA.S5.DN2.MSEED
# Processing: 34162431_2023-02-21T01.31.15.097675Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# No match found for file: 34162431_2023-02-21T01.31.15.097936Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34162431_2023-02-21T01.31.15.097936Z_WS.POZA.S6.DN2.MSEED
# Processing: 34162431_2023-02-21T01.31.15.097936Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# No match found for file: 34162431_2023-02-21T01.31.15.099238Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34162431_2023-02-21T01.31.15.099238Z_WS.POZA.S3.DN2.MSEED
# Processing: 34162431_2023-02-21T01.31.15.099238Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# No match found for file: 34162431_2023-02-21T01.31.15.100647Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34162431_2023-02-21T01.31.15.100647Z_WS.POZA.S2.DN2.MSEED
# Processing: 34162431_2023-02-21T01.31.15.100647Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# No match found for file: 34162431_2023-02-21T01.31.15.101079Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34162431_2023-02-21T01.31.15.101079Z_WS.POZA.S4.DN2.MSEED
# Processing: 34162431_2023-02-21T01.31.15.101079Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# No match found for file: 34162501_2023-02-21T02.02.38.097936Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34162501_2023-02-21T02.02.38.097936Z_WS.POZA.S6.DN2.MSEED
# Processing: 34162501_2023-02-21T02.02.38.097936Z_WS.POZA.S6.DNZ.MSEED
# Error parsing P-pick time for 34162501_2023-02-21T02.02.38.097936Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162501_2023-02-21T02.02.38.098562Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34162501_2023-02-21T02.02.38.098562Z_WS.POZA.S2.DN2.MSEED
# Processing: 34162501_2023-02-21T02.02.38.098562Z_WS.POZA.S2.DNZ.MSEED
# Error parsing P-pick time for 34162501_2023-02-21T02.02.38.098562Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162501_2023-02-21T02.02.38.098588Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34162501_2023-02-21T02.02.38.098588Z_WS.POZA.S5.DN2.MSEED
# Processing: 34162501_2023-02-21T02.02.38.098588Z_WS.POZA.S5.DNZ.MSEED
# Error parsing P-pick time for 34162501_2023-02-21T02.02.38.098588Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162501_2023-02-21T02.02.38.098725Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34162501_2023-02-21T02.02.38.098725Z_WS.POZA.S4.DN2.MSEED
# Processing: 34162501_2023-02-21T02.02.38.098725Z_WS.POZA.S4.DNZ.MSEED
# Error parsing P-pick time for 34162501_2023-02-21T02.02.38.098725Z_WS.POZA.S4.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162501_2023-02-21T02.02.38.100243Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34162501_2023-02-21T02.02.38.100243Z_WS.POZA.S3.DN2.MSEED
# Processing: 34162501_2023-02-21T02.02.38.100243Z_WS.POZA.S3.DNZ.MSEED
# Error parsing P-pick time for 34162501_2023-02-21T02.02.38.100243Z_WS.POZA.S3.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162511_2023-02-21T02.06.02.977755Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34162511_2023-02-21T02.06.02.977755Z_WS.POZA.S6.DN2.MSEED
# Processing: 34162511_2023-02-21T02.06.02.977755Z_WS.POZA.S6.DNZ.MSEED
# Error parsing P-pick time for 34162511_2023-02-21T02.06.02.977755Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162511_2023-02-21T02.06.02.978562Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34162511_2023-02-21T02.06.02.978562Z_WS.POZA.S2.DN2.MSEED
# Processing: 34162511_2023-02-21T02.06.02.978562Z_WS.POZA.S2.DNZ.MSEED
# Error parsing P-pick time for 34162511_2023-02-21T02.06.02.978562Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162511_2023-02-21T02.06.02.978588Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34162511_2023-02-21T02.06.02.978588Z_WS.POZA.S5.DN2.MSEED
# Processing: 34162511_2023-02-21T02.06.02.978588Z_WS.POZA.S5.DNZ.MSEED
# Error parsing P-pick time for 34162511_2023-02-21T02.06.02.978588Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162511_2023-02-21T02.06.02.978725Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34162511_2023-02-21T02.06.02.978725Z_WS.POZA.S4.DN2.MSEED
# Processing: 34162511_2023-02-21T02.06.02.978725Z_WS.POZA.S4.DNZ.MSEED
# Error parsing P-pick time for 34162511_2023-02-21T02.06.02.978725Z_WS.POZA.S4.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162511_2023-02-21T02.06.02.980243Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34162511_2023-02-21T02.06.02.980243Z_WS.POZA.S3.DN2.MSEED
# Processing: 34162511_2023-02-21T02.06.02.980243Z_WS.POZA.S3.DNZ.MSEED
# Error parsing P-pick time for 34162511_2023-02-21T02.06.02.980243Z_WS.POZA.S3.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162741_2023-02-21T02.39.54.850587Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34162741_2023-02-21T02.39.54.850587Z_WS.POZA.S5.DN2.MSEED
# Processing: 34162741_2023-02-21T02.39.54.850587Z_WS.POZA.S5.DNZ.MSEED
# Error parsing P-pick time for 34162741_2023-02-21T02.39.54.850587Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162741_2023-02-21T02.39.54.850647Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34162741_2023-02-21T02.39.54.850647Z_WS.POZA.S4.DN2.MSEED
# Processing: 34162741_2023-02-21T02.39.54.850647Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# No match found for file: 34162741_2023-02-21T02.39.54.850725Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34162741_2023-02-21T02.39.54.850725Z_WS.POZA.S2.DN2.MSEED
# Processing: 34162741_2023-02-21T02.39.54.850725Z_WS.POZA.S2.DNZ.MSEED
# Error parsing P-pick time for 34162741_2023-02-21T02.39.54.850725Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162741_2023-02-21T02.39.54.852047Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34162741_2023-02-21T02.39.54.852047Z_WS.POZA.S3.DN2.MSEED
# Processing: 34162741_2023-02-21T02.39.54.852047Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# No match found for file: 34162741_2023-02-21T02.39.54.853537Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34162741_2023-02-21T02.39.54.853537Z_WS.POZA.S6.DN2.MSEED
# Processing: 34162741_2023-02-21T02.39.54.853537Z_WS.POZA.S6.DNZ.MSEED
# Error parsing P-pick time for 34162741_2023-02-21T02.39.54.853537Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34163011_2023-02-21T03.32.30.490319Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34163011_2023-02-21T03.32.30.490319Z_WS.POZA.S3.DN2.MSEED
# Processing: 34163011_2023-02-21T03.32.30.490319Z_WS.POZA.S3.DNZ.MSEED
# Error parsing P-pick time for 34163011_2023-02-21T03.32.30.490319Z_WS.POZA.S3.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34163011_2023-02-21T03.32.30.492143Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34163011_2023-02-21T03.32.30.492143Z_WS.POZA.S5.DN2.MSEED
# Processing: 34163011_2023-02-21T03.32.30.492143Z_WS.POZA.S5.DNZ.MSEED
# Error parsing P-pick time for 34163011_2023-02-21T03.32.30.492143Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34163011_2023-02-21T03.32.30.492276Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34163011_2023-02-21T03.32.30.492276Z_WS.POZA.S4.DN2.MSEED
# Processing: 34163011_2023-02-21T03.32.30.492276Z_WS.POZA.S4.DNZ.MSEED
# Error parsing P-pick time for 34163011_2023-02-21T03.32.30.492276Z_WS.POZA.S4.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34163011_2023-02-21T03.32.30.492397Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34163011_2023-02-21T03.32.30.492397Z_WS.POZA.S2.DN2.MSEED
# Processing: 34163011_2023-02-21T03.32.30.492397Z_WS.POZA.S2.DNZ.MSEED
# Error parsing P-pick time for 34163011_2023-02-21T03.32.30.492397Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34163011_2023-02-21T03.32.30.493482Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34163011_2023-02-21T03.32.30.493482Z_WS.POZA.S6.DN2.MSEED
# Processing: 34163011_2023-02-21T03.32.30.493482Z_WS.POZA.S6.DNZ.MSEED
# Error parsing P-pick time for 34163011_2023-02-21T03.32.30.493482Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34163051_2023-02-21T03.41.55.050319Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34163051_2023-02-21T03.41.55.050319Z_WS.POZA.S3.DN2.MSEED
# Processing: 34163051_2023-02-21T03.41.55.050319Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# No match found for file: 34163051_2023-02-21T03.41.55.052143Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34163051_2023-02-21T03.41.55.052143Z_WS.POZA.S5.DN2.MSEED
# Processing: 34163051_2023-02-21T03.41.55.052143Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# No match found for file: 34163051_2023-02-21T03.41.55.052276Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34163051_2023-02-21T03.41.55.052276Z_WS.POZA.S4.DN2.MSEED
# Processing: 34163051_2023-02-21T03.41.55.052276Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# No match found for file: 34163051_2023-02-21T03.41.55.052397Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34163051_2023-02-21T03.41.55.052397Z_WS.POZA.S2.DN2.MSEED
# Processing: 34163051_2023-02-21T03.41.55.052397Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# No match found for file: 34163051_2023-02-21T03.41.55.053482Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34163051_2023-02-21T03.41.55.053482Z_WS.POZA.S6.DN2.MSEED
# Processing: 34163051_2023-02-21T03.41.55.053482Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# No match found for file: 34163411_2023-02-21T04.49.09.159092Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34163411_2023-02-21T04.49.09.159092Z_WS.POZA.S4.DN2.MSEED
# Processing: 34163411_2023-02-21T04.49.09.159092Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# No match found for file: 34163411_2023-02-21T04.49.09.159201Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34163411_2023-02-21T04.49.09.159201Z_WS.POZA.S5.DN2.MSEED
# Processing: 34163411_2023-02-21T04.49.09.159201Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# No match found for file: 34163411_2023-02-21T04.49.09.160249Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34163411_2023-02-21T04.49.09.160249Z_WS.POZA.S6.DN2.MSEED
# Processing: 34163411_2023-02-21T04.49.09.160249Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# No match found for file: 34163411_2023-02-21T04.49.09.161007Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34163411_2023-02-21T04.49.09.161007Z_WS.POZA.S3.DN2.MSEED
# Processing: 34163411_2023-02-21T04.49.09.161007Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# No match found for file: 34163411_2023-02-21T04.49.09.161225Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34163411_2023-02-21T04.49.09.161225Z_WS.POZA.S2.DN2.MSEED
# Processing: 34163411_2023-02-21T04.49.09.161225Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# No match found for file: 34163481_2023-02-21T05.15.35.189899Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34163481_2023-02-21T05.15.35.189899Z_WS.POZA.S4.DN2.MSEED
# Processing: 34163481_2023-02-21T05.15.35.189899Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# No match found for file: 34163481_2023-02-21T05.15.35.190426Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34163481_2023-02-21T05.15.35.190426Z_WS.POZA.S6.DN2.MSEED
# Processing: 34163481_2023-02-21T05.15.35.190426Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# No match found for file: 34163481_2023-02-21T05.15.35.191097Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34163481_2023-02-21T05.15.35.191097Z_WS.POZA.S2.DN2.MSEED
# Processing: 34163481_2023-02-21T05.15.35.191097Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# No match found for file: 34163481_2023-02-21T05.15.35.191190Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34163481_2023-02-21T05.15.35.191190Z_WS.POZA.S5.DN2.MSEED
# Processing: 34163481_2023-02-21T05.15.35.191190Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# No match found for file: 34163481_2023-02-21T05.15.35.193431Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34163481_2023-02-21T05.15.35.193431Z_WS.POZA.S3.DN2.MSEED
# Processing: 34163481_2023-02-21T05.15.35.193431Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# No match found for file: 34163561_2023-02-21T05.33.59.897899Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34163561_2023-02-21T05.33.59.897899Z_WS.POZA.S4.DN2.MSEED
# Processing: 34163561_2023-02-21T05.33.59.897899Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# No match found for file: 34163561_2023-02-21T05.33.59.898424Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34163561_2023-02-21T05.33.59.898424Z_WS.POZA.S6.DN2.MSEED
# Processing: 34163561_2023-02-21T05.33.59.898424Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# No match found for file: 34163561_2023-02-21T05.33.59.899097Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34163561_2023-02-21T05.33.59.899097Z_WS.POZA.S2.DN2.MSEED
# Processing: 34163561_2023-02-21T05.33.59.899097Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# No match found for file: 34163561_2023-02-21T05.33.59.899190Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34163561_2023-02-21T05.33.59.899190Z_WS.POZA.S5.DN2.MSEED
# Processing: 34163561_2023-02-21T05.33.59.899190Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# No match found for file: 34163561_2023-02-21T05.33.59.901431Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34163561_2023-02-21T05.33.59.901431Z_WS.POZA.S3.DN2.MSEED
# Processing: 34163561_2023-02-21T05.33.59.901431Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# No match found for file: 34163931_2023-02-21T06.38.57.057885Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34163931_2023-02-21T06.38.57.057885Z_WS.POZA.S6.DN2.MSEED
# Processing: 34163931_2023-02-21T06.38.57.057885Z_WS.POZA.S6.DNZ.MSEED
# Error parsing P-pick time for 34163931_2023-02-21T06.38.57.057885Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34163931_2023-02-21T06.38.57.058077Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34163931_2023-02-21T06.38.57.058077Z_WS.POZA.S3.DN2.MSEED
# Processing: 34163931_2023-02-21T06.38.57.058077Z_WS.POZA.S3.DNZ.MSEED
# Error parsing P-pick time for 34163931_2023-02-21T06.38.57.058077Z_WS.POZA.S3.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34163931_2023-02-21T06.38.57.058640Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34163931_2023-02-21T06.38.57.058640Z_WS.POZA.S2.DN2.MSEED
# Processing: 34163931_2023-02-21T06.38.57.058640Z_WS.POZA.S2.DNZ.MSEED
# Error parsing P-pick time for 34163931_2023-02-21T06.38.57.058640Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34163931_2023-02-21T06.38.57.059081Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34163931_2023-02-21T06.38.57.059081Z_WS.POZA.S5.DN2.MSEED
# Processing: 34163931_2023-02-21T06.38.57.059081Z_WS.POZA.S5.DNZ.MSEED
# Error parsing P-pick time for 34163931_2023-02-21T06.38.57.059081Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34163931_2023-02-21T06.38.57.059276Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34163931_2023-02-21T06.38.57.059276Z_WS.POZA.S4.DN2.MSEED
# Processing: 34163931_2023-02-21T06.38.57.059276Z_WS.POZA.S4.DNZ.MSEED
# Error parsing P-pick time for 34163931_2023-02-21T06.38.57.059276Z_WS.POZA.S4.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34164401_2023-02-21T07.13.34.330804Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34164401_2023-02-21T07.13.34.330804Z_WS.POZA.S4.DN2.MSEED
# Processing: 34164401_2023-02-21T07.13.34.330804Z_WS.POZA.S4.DNZ.MSEED
# Error parsing P-pick time for 34164401_2023-02-21T07.13.34.330804Z_WS.POZA.S4.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34164401_2023-02-21T07.13.34.331170Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34164401_2023-02-21T07.13.34.331170Z_WS.POZA.S5.DN2.MSEED
# Processing: 34164401_2023-02-21T07.13.34.331170Z_WS.POZA.S5.DNZ.MSEED
# Error parsing P-pick time for 34164401_2023-02-21T07.13.34.331170Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34164401_2023-02-21T07.13.34.331365Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34164401_2023-02-21T07.13.34.331365Z_WS.POZA.S2.DN2.MSEED
# Processing: 34164401_2023-02-21T07.13.34.331365Z_WS.POZA.S2.DNZ.MSEED
# Error parsing P-pick time for 34164401_2023-02-21T07.13.34.331365Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34164401_2023-02-21T07.13.34.332303Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34164401_2023-02-21T07.13.34.332303Z_WS.POZA.S6.DN2.MSEED
# Processing: 34164401_2023-02-21T07.13.34.332303Z_WS.POZA.S6.DNZ.MSEED
# Error parsing P-pick time for 34164401_2023-02-21T07.13.34.332303Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34164401_2023-02-21T07.13.34.333420Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34164401_2023-02-21T07.13.34.333420Z_WS.POZA.S3.DN2.MSEED
# Processing: 34164401_2023-02-21T07.13.34.333420Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# No match found for file: 34164891_2023-02-21T08.19.39.829964Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34164891_2023-02-21T08.19.39.829964Z_WS.POZA.S6.DN2.MSEED
# Processing: 34164891_2023-02-21T08.19.39.829964Z_WS.POZA.S6.DNZ.MSEED
# Error parsing P-pick time for 34164891_2023-02-21T08.19.39.829964Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34164891_2023-02-21T08.19.39.830367Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34164891_2023-02-21T08.19.39.830367Z_WS.POZA.S3.DN2.MSEED
# Processing: 34164891_2023-02-21T08.19.39.830367Z_WS.POZA.S3.DNZ.MSEED
# Error parsing P-pick time for 34164891_2023-02-21T08.19.39.830367Z_WS.POZA.S3.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34164891_2023-02-21T08.19.39.830757Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34164891_2023-02-21T08.19.39.830757Z_WS.POZA.S2.DN2.MSEED
# Processing: 34164891_2023-02-21T08.19.39.830757Z_WS.POZA.S2.DNZ.MSEED
# Error parsing P-pick time for 34164891_2023-02-21T08.19.39.830757Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34164891_2023-02-21T08.19.39.831473Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34164891_2023-02-21T08.19.39.831473Z_WS.POZA.S5.DN2.MSEED
# Processing: 34164891_2023-02-21T08.19.39.831473Z_WS.POZA.S5.DNZ.MSEED
# Error parsing P-pick time for 34164891_2023-02-21T08.19.39.831473Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34164891_2023-02-21T08.19.39.832827Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34164891_2023-02-21T08.19.39.832827Z_WS.POZA.S4.DN2.MSEED
# Processing: 34164891_2023-02-21T08.19.39.832827Z_WS.POZA.S4.DNZ.MSEED
# Error parsing P-pick time for 34164891_2023-02-21T08.19.39.832827Z_WS.POZA.S4.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34165791_2023-02-21T10.36.27.750661Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34165791_2023-02-21T10.36.27.750661Z_WS.POZA.S6.D
z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34168201_2023-02-21T16.15.27.912761Z_WS.POZA.S6.DN2.MSEED
# Processing: 34168201_2023-02-21T16.15.27.912761Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# No match found for file: 34168371_2023-02-21T16.48.57.010539Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34168371_2023-02-21T16.48.57.010539Z_WS.POZA.S4.DN2.MSEED
# Processing: 34168371_2023-02-21T16.48.57.010539Z_WS.POZA.S4.DNZ.MSEED
# Error parsing P-pick time for 34168371_2023-02-21T16.48.57.010539Z_WS.POZA.S4.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34168371_2023-02-21T16.48.57.010736Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34168371_2023-02-21T16.48.57.010736Z_WS.POZA.S2.DN2.MSEED
# Processing: 34168371_2023-02-21T16.48.57.010736Z_WS.POZA.S2.DNZ.MSEED
# ...
# Error parsing P-pick time for 34469021_2023-03-26T11.53.56.207428Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34469021_2023-03-26T11.53.56.208154Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34469021_2023-03-26T11.53.56.208154Z_WS.POZA.S2.DN2.MSEED
# Processing: 34469021_2023-03-26T11.53.56.208154Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# No match found for file: 34469021_2023-03-26T11.53.56.208288Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34469021_2023-03-26T11.53.56.208288Z_WS.POZA.S5.DN2.MSEED
# Processing: 34469021_2023-03-26T11.53.56.208288Z_WS.POZA.S5.DNZ.MSEED
# Error parsing P-pick time for 34469021_2023-03-26T11.53.56.208288Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34469021_2023-03-26T11.53.56.208769Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34469021_2023-03-26T11.53.56.208769Z_WS.POZA.S3.DN2.MSEED
# Processing: 34469021_2023-03-26T11.53.56.208769Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# No match found for file: 34491411_2023-03-28T03.31.54.128271Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34491411_2023-03-28T03.31.54.128271Z_WS.POZA.S5.DN2.MSEED
# Processing: 34491411_2023-03-28T03.31.54.128271Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# No match found for file: 34491411_2023-03-28T03.31.54.128524Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34491411_2023-03-28T03.31.54.128524Z_WS.POZA.S6.DN2.MSEED
# Processing: 34491411_2023-03-28T03.31.54.128524Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# No match found for file: 34491411_2023-03-28T03.31.54.129354Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34491411_2023-03-28T03.31.54.129354Z_WS.POZA.S2.DN2.MSEED
# Processing: 34491411_2023-03-28T03.31.54.129354Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# No match found for file: 34491411_2023-03-28T03.31.54.130204Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34491411_2023-03-28T03.31.54.130204Z_WS.POZA.S3.DN2.MSEED
# Processing: 34491411_2023-03-28T03.31.54.130204Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# No match found for file: 34547561_2023-04-02T22.57.18.570053Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34547561_2023-04-02T22.57.18.570053Z_WS.POZA.S5.DN2.MSEED
# Processing: 34547561_2023-04-02T22.57.18.570053Z_WS.POZA.S5.DNZ.MSEED
# Error parsing P-pick time for 34547561_2023-04-02T22.57.18.570053Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34547561_2023-04-02T22.57.18.573150Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34547561_2023-04-02T22.57.18.573150Z_WS.POZA.S6.DN2.MSEED
# Processing: 34547561_2023-04-02T22.57.18.573150Z_WS.POZA.S6.DNZ.MSEED
# Error parsing P-pick time for 34547561_2023-04-02T22.57.18.573150Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34547561_2023-04-02T22.57.18.573506Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34547561_2023-04-02T22.57.18.573506Z_WS.POZA.S2.DN2.MSEED
# Processing: 34547561_2023-04-02T22.57.18.573506Z_WS.POZA.S2.DNZ.MSEED
# Error parsing P-pick time for 34547561_2023-04-02T22.57.18.573506Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34547561_2023-04-02T22.57.18.573604Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34547561_2023-04-02T22.57.18.573604Z_WS.POZA.S3.DN2.MSEED
# Processing: 34547561_2023-04-02T22.57.18.573604Z_WS.POZA.S3.DNZ.MSEED
# Error parsing P-pick time for 34547561_2023-04-02T22.57.18.573604Z_WS.POZA.S3.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34547641_2023-04-02T22.57.32.438053Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34547641_2023-04-02T22.57.32.438053Z_WS.POZA.S5.DN2.MSEED
# Processing: 34547641_2023-04-02T22.57.32.438053Z_WS.POZA.S5.DNZ.MSEED
# Error parsing P-pick time for 34547641_2023-04-02T22.57.32.438053Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34547641_2023-04-02T22.57.32.441150Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34547641_2023-04-02T22.57.32.441150Z_WS.POZA.S6.DN2.MSEED
# Processing: 34547641_2023-04-02T22.57.32.441150Z_WS.POZA.S6.DNZ.MSEED
# Error parsing P-pick time for 34547641_2023-04-02T22.57.32.441150Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34547641_2023-04-02T22.57.32.441506Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34547641_2023-04-02T22.57.32.441506Z_WS.POZA.S2.DN2.MSEED
# Processing: 34547641_2023-04-02T22.57.32.441506Z_WS.POZA.S2.DNZ.MSEED
# Error parsing P-pick time for 34547641_2023-04-02T22.57.32.441506Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34547641_2023-04-02T22.57.32.441604Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34547641_2023-04-02T22.57.32.441604Z_WS.POZA.S3.DN2.MSEED
# Processing: 34547641_2023-04-02T22.57.32.441604Z_WS.POZA.S3.DNZ.MSEED
# Error parsing P-pick time for 34547641_2023-04-02T22.57.32.441604Z_WS.POZA.S3.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34674981_2023-04-13T23.18.18.486965Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34674981_2023-04-13T23.18.18.486965Z_WS.POZA.S3.DN2.MSEED
# Processing: 34674981_2023-04-13T23.18.18.486965Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# No match found for file: 34674981_2023-04-13T23.18.18.487000Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34674981_2023-04-13T23.18.18.487000Z_WS.POZA.S4.DN2.MSEED
# Processing: 34674981_2023-04-13T23.18.18.487000Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# No match found for file: 34674981_2023-04-13T23.18.18.489840Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34674981_2023-04-13T23.18.18.489840Z_WS.POZA.S2.DN2.MSEED
# Processing: 34674981_2023-04-13T23.18.18.489840Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# No match found for file: 34674981_2023-04-13T23.18.18.489861Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34674981_2023-04-13T23.18.18.489861Z_WS.POZA.S5.DN2.MSEED
# Processing: 34674981_2023-04-13T23.18.18.489861Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# No match found for file: 34674981_2023-04-13T23.18.18.490349Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34674981_2023-04-13T23.18.18.490349Z_WS.POZA.S6.DN2.MSEED
# Processing: 34674981_2023-04-13T23.18.18.490349Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# No match found for file: 34692381_2023-04-15T13.17.55.539433Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34692381_2023-04-15T13.17.55.539433Z_WS.POZA.S6.DN2.MSEED
# Processing: 34692381_2023-04-15T13.17.55.539433Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# No match found for file: 34692381_2023-04-15T13.17.55.539436Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34692381_2023-04-15T13.17.55.539436Z_WS.POZA.S5.DN2.MSEED
# Processing: 34692381_2023-04-15T13.17.55.539436Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# No match found for file: 34692381_2023-04-15T13.17.55.540100Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34692381_2023-04-15T13.17.55.540100Z_WS.POZA.S4.DN2.MSEED
# Processing: 34692381_2023-04-15T13.17.55.540100Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# No match found for file: 34692381_2023-04-15T13.17.55.541619Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34692381_2023-04-15T13.17.55.541619Z_WS.POZA.S2.DN2.MSEED
# Processing: 34692381_2023-04-15T13.17.55.541619Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# No match found for file: 34692381_2023-04-15T13.17.55.542715Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34692381_2023-04-15T13.17.55.542715Z_WS.POZA.S3.DN2.MSEED
# Processing: 34692381_2023-04-15T13.17.55.542715Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# No match found for file: 34821541_2023-04-27T12.08.16.710163Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34821541_2023-04-27T12.08.16.710163Z_WS.POZA.S4.DN2.MSEED
# Processing: 34821541_2023-04-27T12.08.16.710163Z_WS.POZA.S4.DNZ.MSEED
# Error parsing P-pick time for 34821541_2023-04-27T12.08.16.710163Z_WS.POZA.S4.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34821541_2023-04-27T12.08.16.710305Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34821541_2023-04-27T12.08.16.710305Z_WS.POZA.S3.DN2.MSEED
# Processing: 34821541_2023-04-27T12.08.16.710305Z_WS.POZA.S3.DNZ.MSEED
# Error parsing P-pick time for 34821541_2023-04-27T12.08.16.710305Z_WS.POZA.S3.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34821541_2023-04-27T12.08.16.711033Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34821541_2023-04-27T12.08.16.711033Z_WS.POZA.S6.DN2.MSEED
# Processing: 34821541_2023-04-27T12.08.16.711033Z_WS.POZA.S6.DNZ.MSEED
# Error parsing P-pick time for 34821541_2023-04-27T12.08.16.711033Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34821541_2023-04-27T12.08.16.712359Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34821541_2023-04-27T12.08.16.712359Z_WS.POZA.S5.DN2.MSEED
# Processing: 34821541_2023-04-27T12.08.16.712359Z_WS.POZA.S5.DNZ.MSEED
# Error parsing P-pick time for 34821541_2023-04-27T12.08.16.712359Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34821541_2023-04-27T12.08.16.712806Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34821541_2023-04-27T12.08.16.712806Z_WS.POZA.S2.DN2.MSEED
# Processing: 34821541_2023-04-27T12.08.16.712806Z_WS.POZA.S2.DNZ.MSEED
# Error parsing P-pick time for 34821541_2023-04-27T12.08.16.712806Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34836221_2023-04-28T20.50.39.467773Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34836221_2023-04-28T20.50.39.467773Z_WS.POZA.S4.DN2.MSEED
# Processing: 34836221_2023-04-28T20.50.39.467773Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# No match found for file: 34836221_2023-04-28T20.50.39.468678Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34836221_2023-04-28T20.50.39.468678Z_WS.POZA.S6.DN2.MSEED
# Processing: 34836221_2023-04-28T20.50.39.468678Z_WS.POZA.S6.DNZ.MSEED
# Error parsing P-pick time for 34836221_2023-04-28T20.50.39.468678Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34836221_2023-04-28T20.50.39.470042Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34836221_2023-04-28T20.50.39.470042Z_WS.POZA.S5.DN2.MSEED
# Processing: 34836221_2023-04-28T20.50.39.470042Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# No match found for file: 34836221_2023-04-28T20.50.39.470238Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34836221_2023-04-28T20.50.39.470238Z_WS.POZA.S3.DN2.MSEED
# Processing: 34836221_2023-04-28T20.50.39.470238Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# No match found for file: 34836221_2023-04-28T20.50.39.470291Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34836221_2023-04-28T20.50.39.470291Z_WS.POZA.S2.DN2.MSEED
# Processing: 34836221_2023-04-28T20.50.39.470291Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# No match found for file: 34956701_2023-05-11T23.41.38.889527Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34956701_2023-05-11T23.41.38.889527Z_WS.POZA.S5.DN2.MSEED
# Processing: 34956701_2023-05-11T23.41.38.889527Z_WS.POZA.S5.DNZ.MSEED
# Error parsing P-pick time for 34956701_2023-05-11T23.41.38.889527Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34956701_2023-05-11T23.41.38.889759Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34956701_2023-05-11T23.41.38.889759Z_WS.POZA.S2.DN2.MSEED
# Processing: 34956701_2023-05-11T23.41.38.889759Z_WS.POZA.S2.DNZ.MSEED
# Error parsing P-pick time for 34956701_2023-05-11T23.41.38.889759Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34956701_2023-05-11T23.41.38.891323Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34956701_2023-05-11T23.41.38.891323Z_WS.POZA.S3.DN2.MSEED
# Processing: 34956701_2023-05-11T23.41.38.891323Z_WS.POZA.S3.DNZ.MSEED
# Error parsing P-pick time for 34956701_2023-05-11T23.41.38.891323Z_WS.POZA.S3.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34956701_2023-05-11T23.41.38.892111Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34956701_2023-05-11T23.41.38.892111Z_WS.POZA.S6.DN2.MSEED
# Processing: 34956701_2023-05-11T23.41.38.892111Z_WS.POZA.S6.DNZ.MSEED
# Error parsing P-pick time for 34956701_2023-05-11T23.41.38.892111Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 35266701_2023-06-09T22.34.36.208297Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 35266701_2023-06-09T22.34.36.208297Z_WS.POZA.S3.DN2.MSEED
# Processing: 35266701_2023-06-09T22.34.36.208297Z_WS.POZA.S3.DNZ.MSEED
# Error parsing P-pick time for 35266701_2023-06-09T22.34.36.208297Z_WS.POZA.S3.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 35266701_2023-06-09T22.34.36.210008Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 35266701_2023-06-09T22.34.36.210008Z_WS.POZA.S6.DN2.MSEED
# Processing: 35266701_2023-06-09T22.34.36.210008Z_WS.POZA.S6.DNZ.MSEED
# Error parsing P-pick time for 35266701_2023-06-09T22.34.36.210008Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 35266701_2023-06-09T22.34.36.210130Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 35266701_2023-06-09T22.34.36.210130Z_WS.POZA.S5.DN2.MSEED
# Processing: 35266701_2023-06-09T22.34.36.210130Z_WS.POZA.S5.DNZ.MSEED
# Error parsing P-pick time for 35266701_2023-06-09T22.34.36.210130Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 35266701_2023-06-09T22.34.36.211277Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 35266701_2023-06-09T22.34.36.211277Z_WS.POZA.S4.DN2.MSEED
# Processing: 35266701_2023-06-09T22.34.36.211277Z_WS.POZA.S4.DNZ.MSEED
# Error parsing P-pick time for 35266701_2023-06-09T22.34.36.211277Z_WS.POZA.S4.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 35266701_2023-06-09T22.34.36.212005Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 35266701_2023-06-09T22.34.36.212005Z_WS.POZA.S2.DN2.MSEED
# Processing: 35266701_2023-06-09T22.34.36.212005Z_WS.POZA.S2.DNZ.MSEED
# Error parsing P-pick time for 35266701_2023-06-09T22.34.36.212005Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 35419441_2023-06-30T04.10.40.107451Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 35419441_2023-06-30T04.10.40.107451Z_WS.POZA.S5.DN2.MSEED
# Processing: 35419441_2023-06-30T04.10.40.107451Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# No match found for file: 35419441_2023-06-30T04.10.40.107601Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 35419441_2023-06-30T04.10.40.107601Z_WS.POZA.S2.DN2.MSEED
# Processing: 35419441_2023-06-30T04.10.40.107601Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# No match found for file: 35419441_2023-06-30T04.10.40.108520Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 35419441_2023-06-30T04.10.40.108520Z_WS.POZA.S6.DN2.MSEED
# Processing: 35419441_2023-06-30T04.10.40.108520Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# No match found for file: 35419441_2023-06-30T04.10.40.108841Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 35419441_2023-06-30T04.10.40.108841Z_WS.POZA.S3.DN2.MSEED
# Processing: 35419441_2023-06-30T04.10.40.108841Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# No match found for file: 35419441_2023-06-30T04.10.40.109398Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 35419441_2023-06-30T04.10.40.109398Z_WS.POZA.S4.DN2.MSEED
# Processing: 35419441_2023-06-30T04.10.40.109398Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# Acceleration statistics saved to acceleration_stats_250_samples.csv
