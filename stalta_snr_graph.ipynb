# %%
from obspy import read
from obspy import UTCDateTime
from obspy.signal.trigger import classic_sta_lta
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path
import os
import numpy as np

# Load the pick data
pick_data = pd.read_csv(
    "dataset_earthquakes/metadata.csv",
    usecols=['trace_name_original_1', 'trace_p_pick_time', 'trace_s_pick_time', 'source_sensor_distance']
)

# Function to sanitize file names
def sanitize_filename(name):
    return name.replace(".", "").replace(":", "").replace("-", "").replace("_", "")

# Directory containing miniSEED files
mseed_dir = "miniSEED_files"
output_dir = "output_sta_lta_snr_plots"
os.makedirs(output_dir, exist_ok=True)  # Create the output directory if it doesn't exist

# Define STA/LTA parameters
sta_window = 1  # Short-Term Average window (seconds)
lta_window = 10  # Long-Term Average window (seconds)

# Sliding SNR Calculation Function
def sliding_snr(trace, window_length=5, overlap=0.5):
    """
    Calculate SNR as a sliding window ratio of signal to noise.
    """
    sampling_rate = trace.stats.sampling_rate
    window_samples = int(window_length * sampling_rate)
    step_samples = int(window_samples * (1 - overlap))

    snr_values = []
    times = []

    for start_idx in range(0, len(trace.data) - window_samples, step_samples):
        # Extract the window
        noise_window = trace.data[start_idx:start_idx + window_samples // 2]
        signal_window = trace.data[start_idx + window_samples // 2:start_idx + window_samples]

        # Calculate RMS values
        noise_rms = np.sqrt(np.mean(noise_window**2))
        signal_rms = np.sqrt(np.mean(signal_window**2))
        snr = signal_rms / noise_rms if noise_rms > 0 else 0

        snr_values.append(snr)
        times.append(trace.stats.starttime + (start_idx / sampling_rate))

    return times, snr_values

# Loop through each miniSEED file in the directory
for file_path in Path(mseed_dir).glob("*.MSEED"):
    mseed_name = sanitize_filename(file_path.name.strip())  # Sanitize the miniSEED file name

    # Check if the miniSEED file matches an entry in the CSV
    matched_row = None
    for _, row in pick_data.iterrows():
        if sanitize_filename(row['trace_name_original_1']) == mseed_name:
            matched_row = row
            break

    if matched_row is None:
        print(f"No match found for file: {file_path.name}")
        continue

    print(f"Match found: {file_path.name}")

    # Extract P and S pick times and sensor distance
    try:
        p_pick = UTCDateTime(matched_row['trace_p_pick_time'])
        s_pick = UTCDateTime(matched_row['trace_s_pick_time'])
        source_sensor_distance = matched_row['source_sensor_distance']
    except Exception as e:
        print(f"Error parsing data for {file_path.name}: {e}")
        continue

    # Read the miniSEED file
    stream = read(file_path)

    # Process each trace in the miniSEED file
    for trace in stream:
        print(f"Processing trace: {trace.id}")

        # Get the sampling rate of the trace
        sampling_rate = trace.stats.sampling_rate

        # Calculate STA/LTA
        try:
            cft = classic_sta_lta(trace.data, int(sta_window * sampling_rate), int(lta_window * sampling_rate))
        except Exception as e:
            print(f"Error computing STA/LTA for trace {trace.id}: {e}")
            continue

        # Calculate SNR as a graph
        snr_times, snr_values = sliding_snr(trace, window_length=5, overlap=0.5)

        # Plot the waveform, STA/LTA ratio, and SNR
        fig, ax1 = plt.subplots(figsize=(12, 6))

        # Plot the waveform
        times = trace.times("matplotlib")
        ax1.plot(times, trace.data, label=f"Waveform: {trace.id}", color="blue", alpha=0.6)
        ax1.set_xlabel("Time (UTC)")
        ax1.set_ylabel("Amplitude")
        ax1.set_title(f"Waveform, STA/LTA, and SNR: {trace.id}\nDistance: {source_sensor_distance} km")
        ax1.legend(loc="upper left")
        ax1.grid()

        # Plot the STA/LTA ratio
        ax2 = ax1.twinx()
        ax2.plot(times[:len(cft)], cft, label="STA/LTA Ratio", color="orange", alpha=0.8)
        ax2.set_ylabel("STA/LTA Ratio")
        ax2.legend(loc="upper right")

        # Plot the SNR as a graph
        snr_times_matplotlib = [t.matplotlib_date for t in snr_times]
        ax2.plot(snr_times_matplotlib, snr_values, label="SNR", color="green", alpha=0.8)

        # Show P and S picks on the waveform
        ax1.axvline(p_pick.matplotlib_date, color="red", linestyle="--", label="P-wave Pick")
        ax1.axvline(s_pick.matplotlib_date, color="black", linestyle="--", label="S-wave Pick")

        # Save the plot
        output_file = Path(output_dir) / f"{file_path.stem}_{trace.id}_sta_lta_snr_graph.png"
        plt.savefig(output_file)
        plt.close()
        print(f"STA/LTA and SNR graph plot saved to: {output_file}")

# %%
# this is the code for the multiple snr windows like 2,5 seconds 5,5 seconds


from obspy import read
from obspy import UTCDateTime
from obspy.signal.trigger import classic_sta_lta
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path
import os
import numpy as np

# Load the pick data
pick_data = pd.read_csv(
    "dataset_earthquakes/metadata.csv",
    usecols=['trace_name_original_1', 'trace_p_pick_time', 'trace_s_pick_time', 'source_sensor_distance']
)

# Function to sanitize file names
def sanitize_filename(name):
    return name.replace(".", "").replace(":", "").replace("-", "").replace("_", "")

# Directory containing miniSEED files
mseed_dir = "miniSEED_files"
output_dir = "output_sta_lta_snr(multiple)_plots"
os.makedirs(output_dir, exist_ok=True)  # Create the output directory if it doesn't exist

# Define STA/LTA parameters
sta_window = 1  # Short-Term Average window (seconds)
lta_window = 10  # Long-Term Average window (seconds)

# SNR Calculation Function for specific windows
def calculate_snr(trace, pre_window, post_window):
    sampling_rate = trace.stats.sampling_rate
    pre_samples = int(pre_window * sampling_rate)
    post_samples = int(post_window * sampling_rate)

    snr_values = []
    times = []

    for i in range(pre_samples, len(trace.data) - post_samples):
        noise_window = trace.data[i - pre_samples:i]
        signal_window = trace.data[i:i + post_samples]

        # Calculate RMS values
        noise_rms = np.sqrt(np.mean(noise_window**2))
        signal_rms = np.sqrt(np.mean(signal_window**2))
        snr = signal_rms / noise_rms if noise_rms > 0 else 0

        snr_values.append(snr)
        times.append(trace.stats.starttime + i / sampling_rate)

    return times, snr_values

# Loop through each miniSEED file in the directory
for file_path in Path(mseed_dir).glob("*.MSEED"):
    mseed_name = sanitize_filename(file_path.name.strip())  # Sanitize the miniSEED file name

    # Check if the miniSEED file matches an entry in the CSV
    matched_row = None
    for _, row in pick_data.iterrows():
        if sanitize_filename(row['trace_name_original_1']) == mseed_name:
            matched_row = row
            break

    if matched_row is None:
        print(f"No match found for file: {file_path.name}")
        continue

    print(f"Match found: {file_path.name}")

    # Extract P and S pick times and sensor distance
    try:
        p_pick = UTCDateTime(matched_row['trace_p_pick_time'])
        s_pick = UTCDateTime(matched_row['trace_s_pick_time'])
        source_sensor_distance = matched_row['source_sensor_distance']
    except Exception as e:
        print(f"Error parsing data for {file_path.name}: {e}")
        continue

    # Read the miniSEED file
    stream = read(file_path)

    # Process each trace in the miniSEED file
    for trace in stream:
        print(f"Processing trace: {trace.id}")

        # Get the sampling rate of the trace
        sampling_rate = trace.stats.sampling_rate

        # Calculate STA/LTA
        try:
            cft = classic_sta_lta(trace.data, int(sta_window * sampling_rate), int(lta_window * sampling_rate))
        except Exception as e:
            print(f"Error computing STA/LTA for trace {trace.id}: {e}")
            continue

        # Calculate SNR for two different windows
        snr_times_2_5, snr_values_2_5 = calculate_snr(trace, pre_window=2, post_window=2)
        snr_times_5_5, snr_values_5_5 = calculate_snr(trace, pre_window=5, post_window=5)

        # Plot the waveform, STA/LTA ratio, and SNR
        fig, ax1 = plt.subplots(figsize=(12, 6))

        # Plot the waveform
        times = trace.times("matplotlib")
        ax1.plot(times, trace.data, label=f"Waveform: {trace.id}", color="blue", alpha=0.6)
        ax1.set_xlabel("Time (UTC)")
        ax1.set_ylabel("Amplitude")
        ax1.set_title(f"Waveform, STA/LTA, and SNR: {trace.id}\nDistance: {source_sensor_distance} km")
        ax1.legend(loc="upper left")
        ax1.grid()

        # Plot the STA/LTA ratio
        ax2 = ax1.twinx()
        ax2.plot(times[:len(cft)], cft, label="STA/LTA Ratio", color="orange", alpha=0.8)
        ax2.set_ylabel("STA/LTA Ratio")
        ax2.legend(loc="upper right")

        # Plot SNR for (2, 5) window
        snr_times_2_5_matplotlib = [t.matplotlib_date for t in snr_times_2_5]
        ax2.plot(snr_times_2_5_matplotlib, snr_values_2_5, label="SNR (2s, 5s)", color="green", alpha=0.8)

        # Plot SNR for (5, 5) window
        snr_times_5_5_matplotlib = [t.matplotlib_date for t in snr_times_5_5]
        ax2.plot(snr_times_5_5_matplotlib, snr_values_5_5, label="SNR (5s, 5s)", color="purple", alpha=0.8)

        # Show P and S picks on the waveform
        ax1.axvline(p_pick.matplotlib_date, color="red", linestyle="--", label="P-wave Pick")
        ax1.axvline(s_pick.matplotlib_date, color="black", linestyle="--", label="S-wave Pick")

        # Save the plot
        output_file = Path(output_dir) / f"{file_path.stem}_{trace.id}_sta_lta_snr(multiple)_graph.png"
        plt.savefig(output_file)
        plt.close()
        print(f"STA/LTA and SNR graph plot saved to: {output_file}")
# Out:
# Match found: 34161341_2023-02-21T00.07.00.489723Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr(multiple)_plots\34161341_2023-02-21T00.07.00.489723Z_WS.POZA.S5.DN1_WS.POZA.S5.DN1_sta_lta_snr(multiple)_graph.png
# No match found for file: 34161341_2023-02-21T00.07.00.489723Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34161341_2023-02-21T00.07.00.489723Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34161341_2023-02-21T00.07.00.490024Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr(multiple)_plots\34161341_2023-02-21T00.07.00.490024Z_WS.POZA.S3.DN1_WS.POZA.S3.DN1_sta_lta_snr(multiple)_graph.png
# No match found for file: 34161341_2023-02-21T00.07.00.490024Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34161341_2023-02-21T00.07.00.490024Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34161341_2023-02-21T00.07.00.490032Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr(multiple)_plots\34161341_2023-02-21T00.07.00.490032Z_WS.POZA.S2.DN1_WS.POZA.S2.DN1_sta_lta_snr(multiple)_graph.png
# No match found for file: 34161341_2023-02-21T00.07.00.490032Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34161341_2023-02-21T00.07.00.490032Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34161341_2023-02-21T00.07.00.490708Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr(multiple)_plots\34161341_2023-02-21T00.07.00.490708Z_WS.POZA.S4.DN1_WS.POZA.S4.DN1_sta_lta_snr(multiple)_graph.png
# No match found for file: 34161341_2023-02-21T00.07.00.490708Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34161341_2023-02-21T00.07.00.490708Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34161341_2023-02-21T00.07.00.493150Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr(multiple)_plots\34161341_2023-02-21T00.07.00.493150Z_WS.POZA.S6.DN1_WS.POZA.S6.DN1_sta_lta_snr(multiple)_graph.png
# No match found for file: 34161341_2023-02-21T00.07.00.493150Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34161341_2023-02-21T00.07.00.493150Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34161511_2023-02-21T00.12.34.317723Z_WS.POZA.S5.DN1.MSEED
# Error parsing data for 34161511_2023-02-21T00.12.34.317723Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161511_2023-02-21T00.12.34.317723Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34161511_2023-02-21T00.12.34.317723Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34161511_2023-02-21T00.12.34.318024Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr(multiple)_plots\34161511_2023-02-21T00.12.34.318024Z_WS.POZA.S3.DN1_WS.POZA.S3.DN1_sta_lta_snr(multiple)_graph.png
# No match found for file: 34161511_2023-02-21T00.12.34.318024Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34161511_2023-02-21T00.12.34.318024Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34161511_2023-02-21T00.12.34.318032Z_WS.POZA.S2.DN1.MSEED
# Error parsing data for 34161511_2023-02-21T00.12.34.318032Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161511_2023-02-21T00.12.34.318032Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34161511_2023-02-21T00.12.34.318032Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34161511_2023-02-21T00.12.34.318708Z_WS.POZA.S4.DN1.MSEED
# Error parsing data for 34161511_2023-02-21T00.12.34.318708Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161511_2023-02-21T00.12.34.318708Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34161511_2023-02-21T00.12.34.318708Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34161511_2023-02-21T00.12.34.321150Z_WS.POZA.S6.DN1.MSEED
# Error parsing data for 34161511_2023-02-21T00.12.34.321150Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161511_2023-02-21T00.12.34.321150Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34161511_2023-02-21T00.12.34.321150Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34161571_2023-02-21T00.14.39.009723Z_WS.POZA.S5.DN1.MSEED
# Error parsing data for 34161571_2023-02-21T00.14.39.009723Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161571_2023-02-21T00.14.39.009723Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34161571_2023-02-21T00.14.39.009723Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34161571_2023-02-21T00.14.39.010024Z_WS.POZA.S3.DN1.MSEED
# Error parsing data for 34161571_2023-02-21T00.14.39.010024Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161571_2023-02-21T00.14.39.010024Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34161571_2023-02-21T00.14.39.010024Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34161571_2023-02-21T00.14.39.010032Z_WS.POZA.S2.DN1.MSEED
# Error parsing data for 34161571_2023-02-21T00.14.39.010032Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161571_2023-02-21T00.14.39.010032Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34161571_2023-02-21T00.14.39.010032Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34161571_2023-02-21T00.14.39.010708Z_WS.POZA.S4.DN1.MSEED
# Error parsing data for 34161571_2023-02-21T00.14.39.010708Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161571_2023-02-21T00.14.39.010708Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34161571_2023-02-21T00.14.39.010708Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34161571_2023-02-21T00.14.39.013150Z_WS.POZA.S6.DN1.MSEED
# Error parsing data for 34161571_2023-02-21T00.14.39.013150Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161571_2023-02-21T00.14.39.013150Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34161571_2023-02-21T00.14.39.013150Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34161621_2023-02-21T00.18.41.857723Z_WS.POZA.S5.DN1.MSEED
# Error parsing data for 34161621_2023-02-21T00.18.41.857723Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161621_2023-02-21T00.18.41.857723Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34161621_2023-02-21T00.18.41.857723Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34161621_2023-02-21T00.18.41.858024Z_WS.POZA.S3.DN1.MSEED
# Error parsing data for 34161621_2023-02-21T00.18.41.858024Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161621_2023-02-21T00.18.41.858024Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34161621_2023-02-21T00.18.41.858024Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34161621_2023-02-21T00.18.41.858032Z_WS.POZA.S2.DN1.MSEED
# Error parsing data for 34161621_2023-02-21T00.18.41.858032Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161621_2023-02-21T00.18.41.858032Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34161621_2023-02-21T00.18.41.858032Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34161621_2023-02-21T00.18.41.858708Z_WS.POZA.S4.DN1.MSEED
# Error parsing data for 34161621_2023-02-21T00.18.41.858708Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161621_2023-02-21T00.18.41.858708Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34161621_2023-02-21T00.18.41.858708Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34161621_2023-02-21T00.18.41.861150Z_WS.POZA.S6.DN1.MSEED
# Error parsing data for 34161621_2023-02-21T00.18.41.861150Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161621_2023-02-21T00.18.41.861150Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34161621_2023-02-21T00.18.41.861150Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34161791_2023-02-21T00.40.23.069600Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr(multiple)_plots\34161791_2023-02-21T00.40.23.069600Z_WS.POZA.S5.DN1_WS.POZA.S5.DN1_sta_lta_snr(multiple)_graph.png
# No match found for file: 34161791_2023-02-21T00.40.23.069600Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34161791_2023-02-21T00.40.23.069600Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34161791_2023-02-21T00.40.23.070024Z_WS.POZA.S3.DN1.MSEED
# Error parsing data for 34161791_2023-02-21T00.40.23.070024Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161791_2023-02-21T00.40.23.070024Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34161791_2023-02-21T00.40.23.070024Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34161791_2023-02-21T00.40.23.070032Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr(multiple)_plots\34161791_2023-02-21T00.40.23.070032Z_WS.POZA.S2.DN1_WS.POZA.S2.DN1_sta_lta_snr(multiple)_graph.png
# No match found for file: 34161791_2023-02-21T00.40.23.070032Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34161791_2023-02-21T00.40.23.070032Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34161791_2023-02-21T00.40.23.070708Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr(multiple)_plots\34161791_2023-02-21T00.40.23.070708Z_WS.POZA.S4.DN1_WS.POZA.S4.DN1_sta_lta_snr(multiple)_graph.png
# No match found for file: 34161791_2023-02-21T00.40.23.070708Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34161791_2023-02-21T00.40.23.070708Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34161791_2023-02-21T00.40.23.072380Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr(multiple)_plots\34161791_2023-02-21T00.40.23.072380Z_WS.POZA.S6.DN1_WS.POZA.S6.DN1_sta_lta_snr(multiple)_graph.png
# No match found for file: 34161791_2023-02-21T00.40.23.072380Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34161791_2023-02-21T00.40.23.072380Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34162021_2023-02-21T00.56.56.517600Z_WS.POZA.S5.DN1.MSEED
# Error parsing data for 34162021_2023-02-21T00.56.56.517600Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162021_2023-02-21T00.56.56.517600Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34162021_2023-02-21T00.56.56.517600Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34162021_2023-02-21T00.56.56.518032Z_WS.POZA.S2.DN1.MSEED
# Error parsing data for 34162021_2023-02-21T00.56.56.518032Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162021_2023-02-21T00.56.56.518032Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34162021_2023-02-21T00.56.56.518032Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34162021_2023-02-21T00.56.56.519238Z_WS.POZA.S3.DN1.MSEED
# Error parsing data for 34162021_2023-02-21T00.56.56.519238Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162021_2023-02-21T00.56.56.519238Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34162021_2023-02-21T00.56.56.519238Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34162021_2023-02-21T00.56.56.520384Z_WS.POZA.S6.DN1.MSEED
# Error parsing data for 34162021_2023-02-21T00.56.56.520384Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162021_2023-02-21T00.56.56.520384Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34162021_2023-02-21T00.56.56.520384Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34162021_2023-02-21T00.56.56.521079Z_WS.POZA.S4.DN1.MSEED
# Error parsing data for 34162021_2023-02-21T00.56.56.521079Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162021_2023-02-21T00.56.56.521079Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34162021_2023-02-21T00.56.56.521079Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34162111_2023-02-21T01.02.21.829562Z_WS.POZA.S5.DN1.MSEED
# Error parsing data for 34162111_2023-02-21T01.02.21.829562Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162111_2023-02-21T01.02.21.829562Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34162111_2023-02-21T01.02.21.829562Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34162111_2023-02-21T01.02.21.831238Z_WS.POZA.S3.DN1.MSEED
# Error parsing data for 34162111_2023-02-21T01.02.21.831238Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162111_2023-02-21T01.02.21.831238Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34162111_2023-02-21T01.02.21.831238Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34162111_2023-02-21T01.02.21.832384Z_WS.POZA.S6.DN1.MSEED
# Error parsing data for 34162111_2023-02-21T01.02.21.832384Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162111_2023-02-21T01.02.21.832384Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34162111_2023-02-21T01.02.21.832384Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34162111_2023-02-21T01.02.21.832647Z_WS.POZA.S2.DN1.MSEED
# Error parsing data for 34162111_2023-02-21T01.02.21.832647Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162111_2023-02-21T01.02.21.832647Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34162111_2023-02-21T01.02.21.832647Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34162111_2023-02-21T01.02.21.833079Z_WS.POZA.S4.DN1.MSEED
# Error parsing data for 34162111_2023-02-21T01.02.21.833079Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162111_2023-02-21T01.02.21.833079Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34162111_2023-02-21T01.02.21.833079Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34162221_2023-02-21T01.06.56.697562Z_WS.POZA.S5.DN1.MSEED
# Error parsing data for 34162221_2023-02-21T01.06.56.697562Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162221_2023-02-21T01.06.56.697562Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34162221_2023-02-21T01.06.56.697562Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34162221_2023-02-21T01.06.56.698149Z_WS.POZA.S6.DN1.MSEED
# Error parsing data for 34162221_2023-02-21T01.06.56.698149Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162221_2023-02-21T01.06.56.698149Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34162221_2023-02-21T01.06.56.698149Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34162221_2023-02-21T01.06.56.699238Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr(multiple)_plots\34162221_2023-02-21T01.06.56.699238Z_WS.POZA.S3.DN1_WS.POZA.S3.DN1_sta_lta_snr(multiple)_graph.png
# No match found for file: 34162221_2023-02-21T01.06.56.699238Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34162221_2023-02-21T01.06.56.699238Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34162221_2023-02-21T01.06.56.700647Z_WS.POZA.S2.DN1.MSEED
# Error parsing data for 34162221_2023-02-21T01.06.56.700647Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162221_2023-02-21T01.06.56.700647Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34162221_2023-02-21T01.06.56.700647Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34162221_2023-02-21T01.06.56.701079Z_WS.POZA.S4.DN1.MSEED
# Error parsing data for 34162221_2023-02-21T01.06.56.701079Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162221_2023-02-21T01.06.56.701079Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34162221_2023-02-21T01.06.56.701079Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34162311_2023-02-21T01.15.19.397562Z_WS.POZA.S5.DN1.MSEED
# Error parsing data for 34162311_2023-02-21T01.15.19.397562Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162311_2023-02-21T01.15.19.397562Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34162311_2023-02-21T01.15.19.397562Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34162311_2023-02-21T01.15.19.398149Z_WS.POZA.S6.DN1.MSEED
# Error parsing data for 34162311_2023-02-21T01.15.19.398149Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162311_2023-02-21T01.15.19.398149Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34162311_2023-02-21T01.15.19.398149Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34162311_2023-02-21T01.15.19.399238Z_WS.POZA.S3.DN1.MSEED
# Error parsing data for 34162311_2023-02-21T01.15.19.399238Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162311_2023-02-21T01.15.19.399238Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34162311_2023-02-21T01.15.19.399238Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34162311_2023-02-21T01.15.19.400647Z_WS.POZA.S2.DN1.MSEED
# Error parsing data for 34162311_2023-02-21T01.15.19.400647Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162311_2023-02-21T01.15.19.400647Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34162311_2023-02-21T01.15.19.400647Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34162311_2023-02-21T01.15.19.401079Z_WS.POZA.S4.DN1.MSEED
# Error parsing data for 34162311_2023-02-21T01.15.19.401079Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162311_2023-02-21T01.15.19.401079Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34162311_2023-02-21T01.15.19.401079Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34162371_2023-02-21T01.31.01.417675Z_WS.POZA.S5.DN1.MSEED
# Error parsing data for 34162371_2023-02-21T01.31.01.417675Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162371_2023-02-21T01.31.01.417675Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34162371_2023-02-21T01.31.01.417675Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34162371_2023-02-21T01.31.01.417936Z_WS.POZA.S6.DN1.MSEED
# Error parsing data for 34162371_2023-02-21T01.31.01.417936Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162371_2023-02-21T01.31.01.417936Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34162371_2023-02-21T01.31.01.417936Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34162371_2023-02-21T01.31.01.419238Z_WS.POZA.S3.DN1.MSEED
# Error parsing data for 34162371_2023-02-21T01.31.01.419238Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162371_2023-02-21T01.31.01.419238Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34162371_2023-02-21T01.31.01.419238Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34162371_2023-02-21T01.31.01.420647Z_WS.POZA.S2.DN1.MSEED
# Error parsing data for 34162371_2023-02-21T01.31.01.420647Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162371_2023-02-21T01.31.01.420647Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34162371_2023-02-21T01.31.01.420647Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34162371_2023-02-21T01.31.01.421079Z_WS.POZA.S4.DN1.MSEED
# Error parsing data for 34162371_2023-02-21T01.31.01.421079Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162371_2023-02-21T01.31.01.421079Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34162371_2023-02-21T01.31.01.421079Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34162431_2023-02-21T01.31.15.097675Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr(multiple)_plots\34162431_2023-02-21T01.31.15.097675Z_WS.POZA.S5.DN1_WS.POZA.S5.DN1_sta_lta_snr(multiple)_graph.png
# No match found for file: 34162431_2023-02-21T01.31.15.097675Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34162431_2023-02-21T01.31.15.097675Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34162431_2023-02-21T01.31.15.097936Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr(multiple)_plots\34162431_2023-02-21T01.31.15.097936Z_WS.POZA.S6.DN1_WS.POZA.S6.DN1_sta_lta_snr(multiple)_graph.png
# No match found for file: 34162431_2023-02-21T01.31.15.097936Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34162431_2023-02-21T01.31.15.097936Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34162431_2023-02-21T01.31.15.099238Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr(multiple)_plots\34162431_2023-02-21T01.31.15.099238Z_WS.POZA.S3.DN1_WS.POZA.S3.DN1_sta_lta_snr(multiple)_graph.png
# No match found for file: 34162431_2023-02-21T01.31.15.099238Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34162431_2023-02-21T01.31.15.099238Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34162431_2023-02-21T01.31.15.100647Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr(multiple)_plots\34162431_2023-02-21T01.31.15.100647Z_WS.POZA.S2.DN1_WS.POZA.S2.DN1_sta_lta_snr(multiple)_graph.png
# No match found for file: 34162431_2023-02-21T01.31.15.100647Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34162431_2023-02-21T01.31.15.100647Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34162431_2023-02-21T01.31.15.101079Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr(multiple)_plots\34162431_2023-02-21T01.31.15.101079Z_WS.POZA.S4.DN1_WS.POZA.S4.DN1_sta_lta_snr(multiple)_graph.png
# No match found for file: 34162431_2023-02-21T01.31.15.101079Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34162431_2023-02-21T01.31.15.101079Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34162501_2023-02-21T02.02.38.097936Z_WS.POZA.S6.DN1.MSEED
# Error parsing data for 34162501_2023-02-21T02.02.38.097936Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162501_2023-02-21T02.02.38.097936Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34162501_2023-02-21T02.02.38.097936Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34162501_2023-02-21T02.02.38.098562Z_WS.POZA.S2.DN1.MSEED
# Error parsing data for 34162501_2023-02-21T02.02.38.098562Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162501_2023-02-21T02.02.38.098562Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34162501_2023-02-21T02.02.38.098562Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34162501_2023-02-21T02.02.38.098588Z_WS.POZA.S5.DN1.MSEED
# Error parsing data for 34162501_2023-02-21T02.02.38.098588Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162501_2023-02-21T02.02.38.098588Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34162501_2023-02-21T02.02.38.098588Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34162501_2023-02-21T02.02.38.098725Z_WS.POZA.S4.DN1.MSEED
# Error parsing data for 34162501_2023-02-21T02.02.38.098725Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162501_2023-02-21T02.02.38.098725Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34162501_2023-02-21T02.02.38.098725Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34162501_2023-02-21T02.02.38.100243Z_WS.POZA.S3.DN1.MSEED
# Error parsing data for 34162501_2023-02-21T02.02.38.100243Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162501_2023-02-21T02.02.38.100243Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34162501_2023-02-21T02.02.38.100243Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34162511_2023-02-21T02.06.02.977755Z_WS.POZA.S6.DN1.MSEED
# Error parsing data for 34162511_2023-02-21T02.06.02.977755Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162511_2023-02-21T02.06.02.977755Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34162511_2023-02-21T02.06.02.977755Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34162511_2023-02-21T02.06.02.978562Z_WS.POZA.S2.DN1.MSEED
# Error parsing data for 34162511_2023-02-21T02.06.02.978562Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162511_2023-02-21T02.06.02.978562Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34162511_2023-02-21T02.06.02.978562Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34162511_2023-02-21T02.06.02.978588Z_WS.POZA.S5.DN1.MSEED
# Error parsing data for 34162511_2023-02-21T02.06.02.978588Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162511_2023-02-21T02.06.02.978588Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34162511_2023-02-21T02.06.02.978588Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34162511_2023-02-21T02.06.02.978725Z_WS.POZA.S4.DN1.MSEED
# Error parsing data for 34162511_2023-02-21T02.06.02.978725Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162511_2023-02-21T02.06.02.978725Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34162511_2023-02-21T02.06.02.978725Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34162511_2023-02-21T02.06.02.980243Z_WS.POZA.S3.DN1.MSEED
# Error parsing data for 34162511_2023-02-21T02.06.02.980243Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162511_2023-02-21T02.06.02.980243Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34162511_2023-02-21T02.06.02.980243Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34162741_2023-02-21T02.39.54.850587Z_WS.POZA.S5.DN1.MSEED
# Error parsing data for 34162741_2023-02-21T02.39.54.850587Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162741_2023-02-21T02.39.54.850587Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34162741_2023-02-21T02.39.54.850587Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34162741_2023-02-21T02.39.54.850647Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr(multiple)_plots\34162741_2023-02-21T02.39.54.850647Z_WS.POZA.S4.DN1_WS.POZA.S4.DN1_sta_lta_snr(multiple)_graph.png
# No match found for file: 34162741_2023-02-21T02.39.54.850647Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34162741_2023-02-21T02.39.54.850647Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34162741_2023-02-21T02.39.54.850725Z_WS.POZA.S2.DN1.MSEED
# Error parsing data for 34162741_2023-02-21T02.39.54.850725Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162741_2023-02-21T02.39.54.850725Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34162741_2023-02-21T02.39.54.850725Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34162741_2023-02-21T02.39.54.852047Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr(multiple)_plots\34162741_2023-02-21T02.39.54.852047Z_WS.POZA.S3.DN1_WS.POZA.S3.DN1_sta_lta_snr(multiple)_graph.png
# No match found for file: 34162741_2023-02-21T02.39.54.852047Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34162741_2023-02-21T02.39.54.852047Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34162741_2023-02-21T02.39.54.853537Z_WS.POZA.S6.DN1.MSEED
# Error parsing data for 34162741_2023-02-21T02.39.54.853537Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162741_2023-02-21T02.39.54.853537Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34162741_2023-02-21T02.39.54.853537Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34163011_2023-02-21T03.32.30.490319Z_WS.POZA.S3.DN1.MSEED
# Error parsing data for 34163011_2023-02-21T03.32.30.490319Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34163011_2023-02-21T03.32.30.490319Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34163011_2023-02-21T03.32.30.490319Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34163011_2023-02-21T03.32.30.492143Z_WS.POZA.S5.DN1.MSEED
# Error parsing data for 34163011_2023-02-21T03.32.30.492143Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34163011_2023-02-21T03.32.30.492143Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34163011_2023-02-21T03.32.30.492143Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34163011_2023-02-21T03.32.30.492276Z_WS.POZA.S4.DN1.MSEED
# Error parsing data for 34163011_2023-02-21T03.32.30.492276Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34163011_2023-02-21T03.32.30.492276Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34163011_2023-02-21T03.32.30.492276Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34163011_2023-02-21T03.32.30.492397Z_WS.POZA.S2.DN1.MSEED
# Error parsing data for 34163011_2023-02-21T03.32.30.492397Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34163011_2023-02-21T03.32.30.492397Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34163011_2023-02-21T03.32.30.492397Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34163011_2023-02-21T03.32.30.493482Z_WS.POZA.S6.DN1.MSEED
# Error parsing data for 34163011_2023-02-21T03.32.30.493482Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34163011_2023-02-21T03.32.30.493482Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34163011_2023-02-21T03.32.30.493482Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34163051_2023-02-21T03.41.55.050319Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr(multiple)_plots\34163051_2023-02-21T03.41.55.050319Z_WS.POZA.S3.DN1_WS.POZA.S3.DN1_sta_lta_snr(multiple)_graph.png
# No match found for file: 34163051_2023-02-21T03.41.55.050319Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34163051_2023-02-21T03.41.55.050319Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34163051_2023-02-21T03.41.55.052143Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr(multiple)_plots\34163051_2023-02-21T03.41.55.052143Z_WS.POZA.S5.DN1_WS.POZA.S5.DN1_sta_lta_snr(multiple)_graph.png
# No match found for file: 34163051_2023-02-21T03.41.55.052143Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34163051_2023-02-21T03.41.55.052143Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34163051_2023-02-21T03.41.55.052276Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr(multiple)_plots\34163051_2023-02-21T03.41.55.052276Z_WS.POZA.S4.DN1_WS.POZA.S4.DN1_sta_lta_snr(multiple)_graph.png
# No match found for file: 34163051_2023-02-21T03.41.55.052276Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34163051_2023-02-21T03.41.55.052276Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34163051_2023-02-21T03.41.55.052397Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr(multiple)_plots\34163051_2023-02-21T03.41.55.052397Z_WS.POZA.S2.DN1_WS.POZA.S2.DN1_sta_lta_snr(multiple)_graph.png
# No match found for file: 34163051_2023-02-21T03.41.55.052397Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34163051_2023-02-21T03.41.55.052397Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34163051_2023-02-21T03.41.55.053482Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr(multiple)_plots\34163051_2023-02-21T03.41.55.053482Z_WS.POZA.S6.DN1_WS.POZA.S6.DN1_sta_lta_snr(multiple)_graph.png
# No match found for file: 34163051_2023-02-21T03.41.55.053482Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34163051_2023-02-21T03.41.55.053482Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34163411_2023-02-21T04.49.09.159092Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr(multiple)_plots\34163411_2023-02-21T04.49.09.159092Z_WS.POZA.S4.DN1_WS.POZA.S4.DN1_sta_lta_snr(multiple)_graph.png
# No match found for file: 34163411_2023-02-21T04.49.09.159092Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34163411_2023-02-21T04.49.09.159092Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34163411_2023-02-21T04.49.09.159201Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr(multiple)_plots\34163411_2023-02-21T04.49.09.159201Z_WS.POZA.S5.DN1_WS.POZA.S5.DN1_sta_lta_snr(multiple)_graph.png
# No match found for file: 34163411_2023-02-21T04.49.09.159201Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34163411_2023-02-21T04.49.09.159201Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34163411_2023-02-21T04.49.09.160249Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr(multiple)_plots\34163411_2023-02-21T04.49.09.160249Z_WS.POZA.S6.DN1_WS.POZA.S6.DN1_sta_lta_snr(multiple)_graph.png
# No match found for file: 34163411_2023-02-21T04.49.09.160249Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34163411_2023-02-21T04.49.09.160249Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34163411_2023-02-21T04.49.09.161007Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr(multiple)_plots\34163411_2023-02-21T04.49.09.161007Z_WS.POZA.S3.DN1_WS.POZA.S3.DN1_sta_lta_snr(multiple)_graph.png
# No match found for file: 34163411_2023-02-21T04.49.09.161007Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34163411_2023-02-21T04.49.09.161007Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34163411_2023-02-21T04.49.09.161225Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr(multiple)_plots\34163411_2023-02-21T04.49.09.161225Z_WS.POZA.S2.DN1_WS.POZA.S2.DN1_sta_lta_snr(multiple)_graph.png
# No match found for file: 34163411_2023-02-21T04.49.09.161225Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34163411_2023-02-21T04.49.09.161225Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34163481_2023-02-21T05.15.35.189899Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr(multiple)_plots\34163481_2023-02-21T05.15.35.189899Z_WS.POZA.S4.DN1_WS.POZA.S4.DN1_sta_lta_snr(multiple)_graph.png
# No match found for file: 34163481_2023-02-21T05.15.35.189899Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34163481_2023-02-21T05.15.35.189899Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34163481_2023-02-21T05.15.35.190426Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr(multiple)_plots\34163481_2023-02-21T05.15.35.190426Z_WS.POZA.S6.DN1_WS.POZA.S6.DN1_sta_lta_snr(multiple)_graph.png
# No match found for file: 34163481_2023-02-21T05.15.35.190426Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34163481_2023-02-21T05.15.35.190426Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34163481_2023-02-21T05.15.35.191097Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr(multiple)_plots\34163481_2023-02-21T05.15.35.191097Z_WS.POZA.S2.DN1_WS.POZA.S2.DN1_sta_lta_snr(multiple)_graph.png
# No match found for file: 34163481_2023-02-21T05.15.35.191097Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34163481_2023-02-21T05.15.35.191097Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34163481_2023-02-21T05.15.35.191190Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr(multiple)_plots\34163481_2023-02-21T05.15.35.191190Z_WS.POZA.S5.DN1_WS.POZA.S5.DN1_sta_lta_snr(multiple)_graph.png
# No match found for file: 34163481_2023-02-21T05.15.35.191190Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34163481_2023-02-21T05.15.35.191190Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34163481_2023-02-21T05.15.35.193431Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr(multiple)_plots\34163481_2023-02-21T05.15.35.193431Z_WS.POZA.S3.DN1_WS.POZA.S3.DN1_sta_lta_snr(multiple)_graph.png
# No match found for file: 34163481_2023-02-21T05.15.35.193431Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34163481_2023-02-21T05.15.35.193431Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34163561_2023-02-21T05.33.59.897899Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr(multiple)_plots\34163561_2023-02-21T05.33.59.897899Z_WS.POZA.S4.DN1_WS.POZA.S4.DN1_sta_lta_snr(multiple)_graph.png
# No match found for file: 34163561_2023-02-21T05.33.59.897899Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34163561_2023-02-21T05.33.59.897899Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34163561_2023-02-21T05.33.59.898424Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr(multiple)_plots\34163561_2023-02-21T05.33.59.898424Z_WS.POZA.S6.DN1_WS.POZA.S6.DN1_sta_lta_snr(multiple)_graph.png
# No match found for file: 34163561_2023-02-21T05.33.59.898424Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34163561_2023-02-21T05.33.59.898424Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34163561_2023-02-21T05.33.59.899097Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr(multiple)_plots\34163561_2023-02-21T05.33.59.899097Z_WS.POZA.S2.DN1_WS.POZA.S2.DN1_sta_lta_snr(multiple)_graph.png
# No match found for file: 34163561_2023-02-21T05.33.59.899097Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34163561_2023-02-21T05.33.59.899097Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34163561_2023-02-21T05.33.59.899190Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr(multiple)_plots\34163561_2023-02-21T05.33.59.899190Z_WS.POZA.S5.DN1_WS.POZA.S5.DN1_sta_lta_snr(multiple)_graph.png
# No match found for file: 34163561_2023-02-21T05.33.59.899190Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34163561_2023-02-21T05.33.59.899190Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34163561_2023-02-21T05.33.59.901431Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr(multiple)_plots\34163561_2023-02-21T05.33.59.901431Z_WS.POZA.S3.DN1_WS.POZA.S3.DN1_sta_lta_snr(multiple)_graph.png
# No match found for file: 34163561_2023-02-21T05.33.59.901431Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34163561_2023-02-21T05.33.59.901431Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34163931_2023-02-21T06.38.57.057885Z_WS.POZA.S6.DN1.MSEED
# Error parsing data for 34163931_2023-02-21T06.38.57.057885Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34163931_2023-02-21T06.38.57.057885Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34163931_2023-02-21T06.38.57.057885Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34163931_2023-02-21T06.38.57.058077Z_WS.POZA.S3.DN1.MSEED
# Error parsing data for 34163931_2023-02-21T06.38.57.058077Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34163931_2023-02-21T06.38.57.058077Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34163931_2023-02-21T06.38.57.058077Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34163931_2023-02-21T06.38.57.058640Z_WS.POZA.S2.DN1.MSEED
# Error parsing data for 34163931_2023-02-21T06.38.57.058640Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34163931_2023-02-21T06.38.57.058640Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34163931_2023-02-21T06.38.57.058640Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34163931_2023-02-21T06.38.57.059081Z_WS.POZA.S5.DN1.MSEED
# Error parsing data for 34163931_2023-02-21T06.38.57.059081Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34163931_2023-02-21T06.38.57.059081Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34163931_2023-02-21T06.38.57.059081Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34163931_2023-02-21T06.38.57.059276Z_WS.POZA.S4.DN1.MSEED
# Error parsing data for 34163931_2023-02-21T06.38.57.059276Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34163931_2023-02-21T06.38.57.059276Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34163931_2023-02-21T06.38.57.059276Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34164401_2023-02-21T07.13.34.330804Z_WS.POZA.S4.DN1.MSEED
# Error parsing data for 34164401_2023-02-21T07.13.34.330804Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34164401_2023-02-21T07.13.34.330804Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34164401_2023-02-21T07.13.34.330804Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34164401_2023-02-21T07.13.34.331170Z_WS.POZA.S5.DN1.MSEED
# Error parsing data for 34164401_2023-02-21T07.13.34.331170Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34164401_2023-02-21T07.13.34.331170Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34164401_2023-02-21T07.13.34.331170Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34164401_2023-02-21T07.13.34.331365Z_WS.POZA.S2.DN1.MSEED
# Error parsing data for 34164401_2023-02-21T07.13.34.331365Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34164401_2023-02-21T07.13.34.331365Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34164401_2023-02-21T07.13.34.331365Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34164401_2023-02-21T07.13.34.332303Z_WS.POZA.S6.DN1.MSEED
# Error parsing data for 34164401_2023-02-21T07.13.34.332303Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34164401_2023-02-21T07.13.34.332303Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34164401_2023-02-21T07.13.34.332303Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34164401_2023-02-21T07.13.34.333420Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr(multiple)_plots\34164401_2023-02-21T07.13.34.333420Z_WS.POZA.S3.DN1_WS.POZA.S3.DN1_sta_lta_snr(multiple)_graph.png
# No match found for file: 34164401_2023-02-21T07.13.34.333420Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34164401_2023-02-21T07.13.34.333420Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34164891_2023-02-21T08.19.39.829964Z_WS.POZA.S6.DN1.MSEED
# Error parsing data for 34164891_2023-02-21T08.19.39.829964Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34164891_2023-02-21T08.19.39.829964Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34164891_2023-02-21T08.19.39.829964Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34164891_2023-02-21T08.19.39.830367Z_WS.POZA.S3.DN1.MSEED
# Error parsing data for 34164891_2023-02-21T08.19.39.830367Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34164891_2023-02-21T08.19.39.830367Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34164891_2023-02-21T08.19.39.830367Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34164891_2023-02-21T08.19.39.830757Z_WS.POZA.S2.DN1.MSEED
# Error parsing data for 34164891_2023-02-21T08.19.39.830757Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34164891_2023-02-21T08.19.39.830757Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34164891_2023-02-21T08.19.39.830757Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34164891_2023-02-21T08.19.39.831473Z_WS.POZA.S5.DN1.MSEED
# Error parsing data for 34164891_2023-02-21T08.19.39.831473Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34164891_2023-02-21T08.19.39.831473Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34164891_2023-02-21T08.19.39.831473Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34164891_2023-02-21T08.19.39.832827Z_WS.POZA.S4.DN1.MSEED
# Error parsing data for 34164891_2023-02-21T08.19.39.832827Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34164891_2023-02-21T08.19.39.832827Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34164891_2023-02-21T08.19.39.832827Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34165791_2023-02-21T10.36.27.750661Z_WS.POZA.S6.DN1.MSEED
# Error parsing data for 34165791_2023-02-21T10.36.27.750661Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34165791_2023-02-21T10.36.27.750661Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34165791_2023-02-21T10.36.27.750661Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34165791_2023-02-21T10.36.27.751693Z_WS.POZA.S4.DN1.MSEED
# Error parsing data for 34165791_2023-02-21T10.36.27.751693Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34165791_2023-02-21T10.36.27.751693Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34165791_2023-02-21T10.36.27.751693Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34165791_2023-02-21T10.36.27.751736Z_WS.POZA.S3.DN1.MSEED
# Error parsing data for 34165791_2023-02-21T10.36.27.751736Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34165791_2023-02-21T10.36.27.751736Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34165791_2023-02-21T10.36.27.751736Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34165791_2023-02-21T10.36.27.751945Z_WS.POZA.S5.DN1.MSEED
# Error parsing data for 34165791_2023-02-21T10.36.27.751945Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34165791_2023-02-21T10.36.27.751945Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34165791_2023-02-21T10.36.27.751945Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34165791_2023-02-21T10.36.27.752007Z_WS.POZA.S2.DN1.MSEED
# Error parsing data for 34165791_2023-02-21T10.36.27.752007Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34165791_2023-02-21T10.36.27.752007Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34165791_2023-02-21T10.36.27.752007Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34166831_2023-02-21T12.48.34.238879Z_WS.POZA.S3.DN1.MSEED
# Error parsing data for 34166831_2023-02-21T12.48.34.238879Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34166831_2023-02-21T12.48.34.238879Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34166831_2023-02-21T12.48.34.238879Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34166831_2023-02-21T12.48.34.239476Z_WS.POZA.S6.DN1.MSEED
# Error parsing data for 34166831_2023-02-21T12.48.34.239476Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34166831_2023-02-21T12.48.34.239476Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34166831_2023-02-21T12.48.34.239476Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34166831_2023-02-21T12.48.34.239517Z_WS.POZA.S2.DN1.MSEED
# Error parsing data for 34166831_2023-02-21T12.48.34.239517Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34166831_2023-02-21T12.48.34.239517Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34166831_2023-02-21T12.48.34.239517Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34166831_2023-02-21T12.48.34.239983Z_WS.POZA.S5.DN1.MSEED
# Error parsing data for 34166831_2023-02-21T12.48.34.239983Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34166831_2023-02-21T12.48.34.239983Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34166831_2023-02-21T12.48.34.239983Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34166831_2023-02-21T12.48.34.240879Z_WS.POZA.S4.DN1.MSEED
# Error parsing data for 34166831_2023-02-21T12.48.34.240879Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34166831_2023-02-21T12.48.34.240879Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34166831_2023-02-21T12.48.34.240879Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34167831_2023-02-21T15.08.01.278424Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr(multiple)_plots\34167831_2023-02-21T15.08.01.278424Z_WS.POZA.S6.DN1_WS.POZA.S6.DN1_sta_lta_snr(multiple)_graph.png
# No match found for file: 34167831_2023-02-21T15.08.01.278424Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34167831_2023-02-21T15.08.01.278424Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34167831_2023-02-21T15.08.01.279429Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr(multiple)_plots\34167831_2023-02-21T15.08.01.279429Z_WS.POZA.S3.DN1_WS.POZA.S3.DN1_sta_lta_snr(multiple)_graph.png
# No match found for file: 34167831_2023-02-21T15.08.01.279429Z_WS.POZA.S3.DN2.MSEED
# ...
# Match found: 34174291_2023-02-22T10.16.50.069865Z_WS.POZA.S4.DN1.MSEED
# Error parsing data for 34174291_2023-02-22T10.16.50.069865Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34174291_2023-02-22T10.16.50.069865Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34174291_2023-02-22T10.16.50.069865Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34174941_2023-02-22T11.33.54.858861Z_WS.POZA.S3.DN1.MSEED
# Error parsing data for 34174941_2023-02-22T11.33.54.858861Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34174941_2023-02-22T11.33.54.858861Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34174941_2023-02-22T11.33.54.858861Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34174941_2023-02-22T11.33.54.859365Z_WS.POZA.S4.DN1.MSEED
# Error parsing data for 34174941_2023-02-22T11.33.54.859365Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34174941_2023-02-22T11.33.54.859365Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34174941_2023-02-22T11.33.54.859365Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34174941_2023-02-22T11.33.54.861334Z_WS.POZA.S5.DN1.MSEED
# Error parsing data for 34174941_2023-02-22T11.33.54.861334Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34174941_2023-02-22T11.33.54.861334Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 
anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3504, in mean(a, axis, dtype, out, keepdims, where)
#    3501     else:
#    3502         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# -> 3504 return _methods._mean(a, axis=axis, dtype=dtype,
#    3505                       out=out, **kwargs)
#
# File c:\Users\Ayush_trainee\anaconda3\Lib\site-packages\numpy\core\_methods.py:118, in _mean(a, axis, dtype, out, keepdims, where)
#     115         dtype = mu.dtype('f4')
#     116         is_float16_result = True
# --> 118 ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
#     119 if isinstance(ret, mu.ndarray):
#     120     with _no_nep50_warning():
#
# KeyboardInterrupt:

# %%
# this is thee code for thge 2,2 seconds window and 5,5 seconds window


from obspy import read
from obspy import UTCDateTime
from obspy.signal.trigger import classic_sta_lta
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path
import os
import numpy as np

# Load the pick data
pick_data = pd.read_csv(
    "dataset_earthquakes/metadata.csv",
    usecols=['trace_name_original_Z', 'trace_p_pick_time', 'trace_s_pick_time', 'source_sensor_distance']
)

# Function to sanitize file names
def sanitize_filename(name):
    return name.replace(".", "").replace(":", "").replace("-", "").replace("_", "")

# Directory containing miniSEED files
mseed_dir = "miniSEED_files"
output_dir = "output_sta_lta_snr_plots(multiple)"
os.makedirs(output_dir, exist_ok=True)  # Create the output directory if it doesn't exist

# Define STA/LTA parameters
sta_window = 1  # Short-Term Average window (seconds)
lta_window = 10  # Long-Term Average window (seconds)

# SNR Calculation Function
def calculate_snr(trace, pre_window, post_window):
    """
    Calculate SNR for each point using pre-window (noise) and post-window (signal).
    """
    sampling_rate = trace.stats.sampling_rate
    pre_samples = int(pre_window * sampling_rate)
    post_samples = int(post_window * sampling_rate)

    snr_values = []
    times = []

    for i in range(pre_samples, len(trace.data) - post_samples):
        noise_window = trace.data[i - pre_samples:i]
        signal_window = trace.data[i:i + post_samples]

        # Calculate RMS values
        noise_rms = np.sqrt(np.mean(noise_window**2)) if len(noise_window) > 0 else 0
        signal_rms = np.sqrt(np.mean(signal_window**2)) if len(signal_window) > 0 else 0

        # Calculate SNR
        snr = signal_rms / noise_rms if noise_rms > 0 else 0
        snr_values.append(snr)
        times.append(trace.stats.starttime + (i / sampling_rate))

    return times, snr_values

# Loop through each miniSEED file in the directory
for file_path in Path(mseed_dir).glob("*.MSEED"):
    mseed_name = sanitize_filename(file_path.name.strip())  # Sanitize the miniSEED file name

    # Check if the miniSEED file matches an entry in the CSV
    matched_row = None
    for _, row in pick_data.iterrows():
        if sanitize_filename(row['trace_name_original_Z']) == mseed_name:
            matched_row = row
            break

    if matched_row is None:
        print(f"No match found for file: {file_path.name}")
        continue

    print(f"Match found: {file_path.name}")

    # Extract P and S pick times and sensor distance
    try:
        p_pick = UTCDateTime(matched_row['trace_p_pick_time'])
        s_pick = UTCDateTime(matched_row['trace_s_pick_time'])
        source_sensor_distance = matched_row['source_sensor_distance']
    except Exception as e:
        print(f"Error parsing data for {file_path.name}: {e}")
        continue

    # Read the miniSEED file
    stream = read(file_path)

    # Process each trace in the miniSEED file
    for trace in stream:
        print(f"Processing trace: {trace.id}")

        # Get the sampling rate of the trace
        sampling_rate = trace.stats.sampling_rate

        # Calculate STA/LTA
        try:
            cft = classic_sta_lta(trace.data, int(sta_window * sampling_rate), int(lta_window * sampling_rate))
        except Exception as e:
            print(f"Error computing STA/LTA for trace {trace.id}: {e}")
            continue

        # Calculate SNR for both window configurations
        snr_times_2_2, snr_values_2_2 = calculate_snr(trace, pre_window=2, post_window=2)
        snr_times_5_5, snr_values_5_5 = calculate_snr(trace, pre_window=5, post_window=5)

        # Plot the waveform, STA/LTA ratio, and SNR
        fig, ax1 = plt.subplots(figsize=(12, 6))

        # Plot the waveform
        times = trace.times("matplotlib")
        ax1.plot(times, trace.data, label=f"Waveform: {trace.id}", color="blue", alpha=0.6)
        ax1.set_xlabel("Time (UTC)")
        ax1.set_ylabel("Amplitude")
        ax1.set_title(f"Waveform, STA/LTA, and SNR: {trace.id}\nDistance: {source_sensor_distance} km")
        ax1.legend(loc="upper left")
        ax1.grid()

        # Plot the STA/LTA ratio
        ax2 = ax1.twinx()
        ax2.plot(times[:len(cft)], cft, label="STA/LTA Ratio", color="orange", alpha=0.8)
        ax2.set_ylabel("STA/LTA Ratio")
        ax2.legend(loc="upper right")

        # Plot the SNR as a graph for both configurations
        snr_times_2_2_matplotlib = [t.matplotlib_date for t in snr_times_2_2]
        snr_times_5_5_matplotlib = [t.matplotlib_date for t in snr_times_5_5]

        ax2.plot(snr_times_2_2_matplotlib, snr_values_2_2, label="SNR (2s, 2s)", color="green", alpha=0.8)
        ax2.plot(snr_times_5_5_matplotlib, snr_values_5_5, label="SNR (5s, 5s)", color="purple", alpha=0.8)

        # Show P and S picks on the waveform
        ax1.axvline(p_pick.matplotlib_date, color="red", linestyle="--", label="P-wave Pick")
        ax1.axvline(s_pick.matplotlib_date, color="black", linestyle="--", label="S-wave Pick")

        # Save the plot
        output_file = Path(output_dir) / f"{file_path.stem}_{trace.id}_sta_lta_snr_graph(multiple).png"
        plt.savefig(output_file)
        plt.close()
        print(f"STA/LTA and SNR graph plot saved to: {output_file}")
# Out:
# No match found for file: 34161341_2023-02-21T00.07.00.489723Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34161341_2023-02-21T00.07.00.489723Z_WS.POZA.S5.DN2.MSEED
# Match found: 34161341_2023-02-21T00.07.00.489723Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34161341_2023-02-21T00.07.00.489723Z_WS.POZA.S5.DNZ_WS.POZA.S5.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34161341_2023-02-21T00.07.00.490024Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34161341_2023-02-21T00.07.00.490024Z_WS.POZA.S3.DN2.MSEED
# Match found: 34161341_2023-02-21T00.07.00.490024Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34161341_2023-02-21T00.07.00.490024Z_WS.POZA.S3.DNZ_WS.POZA.S3.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34161341_2023-02-21T00.07.00.490032Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34161341_2023-02-21T00.07.00.490032Z_WS.POZA.S2.DN2.MSEED
# Match found: 34161341_2023-02-21T00.07.00.490032Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34161341_2023-02-21T00.07.00.490032Z_WS.POZA.S2.DNZ_WS.POZA.S2.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34161341_2023-02-21T00.07.00.490708Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34161341_2023-02-21T00.07.00.490708Z_WS.POZA.S4.DN2.MSEED
# Match found: 34161341_2023-02-21T00.07.00.490708Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34161341_2023-02-21T00.07.00.490708Z_WS.POZA.S4.DNZ_WS.POZA.S4.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34161341_2023-02-21T00.07.00.493150Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34161341_2023-02-21T00.07.00.493150Z_WS.POZA.S6.DN2.MSEED
# Match found: 34161341_2023-02-21T00.07.00.493150Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34161341_2023-02-21T00.07.00.493150Z_WS.POZA.S6.DNZ_WS.POZA.S6.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34161511_2023-02-21T00.12.34.317723Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34161511_2023-02-21T00.12.34.317723Z_WS.POZA.S5.DN2.MSEED
# Match found: 34161511_2023-02-21T00.12.34.317723Z_WS.POZA.S5.DNZ.MSEED
# Error parsing data for 34161511_2023-02-21T00.12.34.317723Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161511_2023-02-21T00.12.34.318024Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34161511_2023-02-21T00.12.34.318024Z_WS.POZA.S3.DN2.MSEED
# Match found: 34161511_2023-02-21T00.12.34.318024Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34161511_2023-02-21T00.12.34.318024Z_WS.POZA.S3.DNZ_WS.POZA.S3.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34161511_2023-02-21T00.12.34.318032Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34161511_2023-02-21T00.12.34.318032Z_WS.POZA.S2.DN2.MSEED
# Match found: 34161511_2023-02-21T00.12.34.318032Z_WS.POZA.S2.DNZ.MSEED
# Error parsing data for 34161511_2023-02-21T00.12.34.318032Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161511_2023-02-21T00.12.34.318708Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34161511_2023-02-21T00.12.34.318708Z_WS.POZA.S4.DN2.MSEED
# Match found: 34161511_2023-02-21T00.12.34.318708Z_WS.POZA.S4.DNZ.MSEED
# Error parsing data for 34161511_2023-02-21T00.12.34.318708Z_WS.POZA.S4.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161511_2023-02-21T00.12.34.321150Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34161511_2023-02-21T00.12.34.321150Z_WS.POZA.S6.DN2.MSEED
# Match found: 34161511_2023-02-21T00.12.34.321150Z_WS.POZA.S6.DNZ.MSEED
# Error parsing data for 34161511_2023-02-21T00.12.34.321150Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161571_2023-02-21T00.14.39.009723Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34161571_2023-02-21T00.14.39.009723Z_WS.POZA.S5.DN2.MSEED
# Match found: 34161571_2023-02-21T00.14.39.009723Z_WS.POZA.S5.DNZ.MSEED
# Error parsing data for 34161571_2023-02-21T00.14.39.009723Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161571_2023-02-21T00.14.39.010024Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34161571_2023-02-21T00.14.39.010024Z_WS.POZA.S3.DN2.MSEED
# Match found: 34161571_2023-02-21T00.14.39.010024Z_WS.POZA.S3.DNZ.MSEED
# Error parsing data for 34161571_2023-02-21T00.14.39.010024Z_WS.POZA.S3.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161571_2023-02-21T00.14.39.010032Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34161571_2023-02-21T00.14.39.010032Z_WS.POZA.S2.DN2.MSEED
# Match found: 34161571_2023-02-21T00.14.39.010032Z_WS.POZA.S2.DNZ.MSEED
# Error parsing data for 34161571_2023-02-21T00.14.39.010032Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161571_2023-02-21T00.14.39.010708Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34161571_2023-02-21T00.14.39.010708Z_WS.POZA.S4.DN2.MSEED
# Match found: 34161571_2023-02-21T00.14.39.010708Z_WS.POZA.S4.DNZ.MSEED
# Error parsing data for 34161571_2023-02-21T00.14.39.010708Z_WS.POZA.S4.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161571_2023-02-21T00.14.39.013150Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34161571_2023-02-21T00.14.39.013150Z_WS.POZA.S6.DN2.MSEED
# Match found: 34161571_2023-02-21T00.14.39.013150Z_WS.POZA.S6.DNZ.MSEED
# Error parsing data for 34161571_2023-02-21T00.14.39.013150Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161621_2023-02-21T00.18.41.857723Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34161621_2023-02-21T00.18.41.857723Z_WS.POZA.S5.DN2.MSEED
# Match found: 34161621_2023-02-21T00.18.41.857723Z_WS.POZA.S5.DNZ.MSEED
# Error parsing data for 34161621_2023-02-21T00.18.41.857723Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161621_2023-02-21T00.18.41.858024Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34161621_2023-02-21T00.18.41.858024Z_WS.POZA.S3.DN2.MSEED
# Match found: 34161621_2023-02-21T00.18.41.858024Z_WS.POZA.S3.DNZ.MSEED
# Error parsing data for 34161621_2023-02-21T00.18.41.858024Z_WS.POZA.S3.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161621_2023-02-21T00.18.41.858032Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34161621_2023-02-21T00.18.41.858032Z_WS.POZA.S2.DN2.MSEED
# Match found: 34161621_2023-02-21T00.18.41.858032Z_WS.POZA.S2.DNZ.MSEED
# Error parsing data for 34161621_2023-02-21T00.18.41.858032Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161621_2023-02-21T00.18.41.858708Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34161621_2023-02-21T00.18.41.858708Z_WS.POZA.S4.DN2.MSEED
# Match found: 34161621_2023-02-21T00.18.41.858708Z_WS.POZA.S4.DNZ.MSEED
# Error parsing data for 34161621_2023-02-21T00.18.41.858708Z_WS.POZA.S4.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161621_2023-02-21T00.18.41.861150Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34161621_2023-02-21T00.18.41.861150Z_WS.POZA.S6.DN2.MSEED
# Match found: 34161621_2023-02-21T00.18.41.861150Z_WS.POZA.S6.DNZ.MSEED
# Error parsing data for 34161621_2023-02-21T00.18.41.861150Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161791_2023-02-21T00.40.23.069600Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34161791_2023-02-21T00.40.23.069600Z_WS.POZA.S5.DN2.MSEED
# Match found: 34161791_2023-02-21T00.40.23.069600Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34161791_2023-02-21T00.40.23.069600Z_WS.POZA.S5.DNZ_WS.POZA.S5.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34161791_2023-02-21T00.40.23.070024Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34161791_2023-02-21T00.40.23.070024Z_WS.POZA.S3.DN2.MSEED
# Match found: 34161791_2023-02-21T00.40.23.070024Z_WS.POZA.S3.DNZ.MSEED
# Error parsing data for 34161791_2023-02-21T00.40.23.070024Z_WS.POZA.S3.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161791_2023-02-21T00.40.23.070032Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34161791_2023-02-21T00.40.23.070032Z_WS.POZA.S2.DN2.MSEED
# Match found: 34161791_2023-02-21T00.40.23.070032Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34161791_2023-02-21T00.40.23.070032Z_WS.POZA.S2.DNZ_WS.POZA.S2.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34161791_2023-02-21T00.40.23.070708Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34161791_2023-02-21T00.40.23.070708Z_WS.POZA.S4.DN2.MSEED
# Match found: 34161791_2023-02-21T00.40.23.070708Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34161791_2023-02-21T00.40.23.070708Z_WS.POZA.S4.DNZ_WS.POZA.S4.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34161791_2023-02-21T00.40.23.072380Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34161791_2023-02-21T00.40.23.072380Z_WS.POZA.S6.DN2.MSEED
# Match found: 34161791_2023-02-21T00.40.23.072380Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34161791_2023-02-21T00.40.23.072380Z_WS.POZA.S6.DNZ_WS.POZA.S6.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34162021_2023-02-21T00.56.56.517600Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34162021_2023-02-21T00.56.56.517600Z_WS.POZA.S5.DN2.MSEED
# Match found: 34162021_2023-02-21T00.56.56.517600Z_WS.POZA.S5.DNZ.MSEED
# Error parsing data for 34162021_2023-02-21T00.56.56.517600Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162021_2023-02-21T00.56.56.518032Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34162021_2023-02-21T00.56.56.518032Z_WS.POZA.S2.DN2.MSEED
# Match found: 34162021_2023-02-21T00.56.56.518032Z_WS.POZA.S2.DNZ.MSEED
# Error parsing data for 34162021_2023-02-21T00.56.56.518032Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162021_2023-02-21T00.56.56.519238Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34162021_2023-02-21T00.56.56.519238Z_WS.POZA.S3.DN2.MSEED
# Match found: 34162021_2023-02-21T00.56.56.519238Z_WS.POZA.S3.DNZ.MSEED
# Error parsing data for 34162021_2023-02-21T00.56.56.519238Z_WS.POZA.S3.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162021_2023-02-21T00.56.56.520384Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34162021_2023-02-21T00.56.56.520384Z_WS.POZA.S6.DN2.MSEED
# Match found: 34162021_2023-02-21T00.56.56.520384Z_WS.POZA.S6.DNZ.MSEED
# Error parsing data for 34162021_2023-02-21T00.56.56.520384Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162021_2023-02-21T00.56.56.521079Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34162021_2023-02-21T00.56.56.521079Z_WS.POZA.S4.DN2.MSEED
# Match found: 34162021_2023-02-21T00.56.56.521079Z_WS.POZA.S4.DNZ.MSEED
# Error parsing data for 34162021_2023-02-21T00.56.56.521079Z_WS.POZA.S4.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162111_2023-02-21T01.02.21.829562Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34162111_2023-02-21T01.02.21.829562Z_WS.POZA.S5.DN2.MSEED
# Match found: 34162111_2023-02-21T01.02.21.829562Z_WS.POZA.S5.DNZ.MSEED
# Error parsing data for 34162111_2023-02-21T01.02.21.829562Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162111_2023-02-21T01.02.21.831238Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34162111_2023-02-21T01.02.21.831238Z_WS.POZA.S3.DN2.MSEED
# Match found: 34162111_2023-02-21T01.02.21.831238Z_WS.POZA.S3.DNZ.MSEED
# Error parsing data for 34162111_2023-02-21T01.02.21.831238Z_WS.POZA.S3.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162111_2023-02-21T01.02.21.832384Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34162111_2023-02-21T01.02.21.832384Z_WS.POZA.S6.DN2.MSEED
# Match found: 34162111_2023-02-21T01.02.21.832384Z_WS.POZA.S6.DNZ.MSEED
# Error parsing data for 34162111_2023-02-21T01.02.21.832384Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162111_2023-02-21T01.02.21.832647Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34162111_2023-02-21T01.02.21.832647Z_WS.POZA.S2.DN2.MSEED
# Match found: 34162111_2023-02-21T01.02.21.832647Z_WS.POZA.S2.DNZ.MSEED
# Error parsing data for 34162111_2023-02-21T01.02.21.832647Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162111_2023-02-21T01.02.21.833079Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34162111_2023-02-21T01.02.21.833079Z_WS.POZA.S4.DN2.MSEED
# Match found: 34162111_2023-02-21T01.02.21.833079Z_WS.POZA.S4.DNZ.MSEED
# Error parsing data for 34162111_2023-02-21T01.02.21.833079Z_WS.POZA.S4.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162221_2023-02-21T01.06.56.697562Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34162221_2023-02-21T01.06.56.697562Z_WS.POZA.S5.DN2.MSEED
# Match found: 34162221_2023-02-21T01.06.56.697562Z_WS.POZA.S5.DNZ.MSEED
# Error parsing data for 34162221_2023-02-21T01.06.56.697562Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162221_2023-02-21T01.06.56.698149Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34162221_2023-02-21T01.06.56.698149Z_WS.POZA.S6.DN2.MSEED
# Match found: 34162221_2023-02-21T01.06.56.698149Z_WS.POZA.S6.DNZ.MSEED
# Error parsing data for 34162221_2023-02-21T01.06.56.698149Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162221_2023-02-21T01.06.56.699238Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34162221_2023-02-21T01.06.56.699238Z_WS.POZA.S3.DN2.MSEED
# Match found: 34162221_2023-02-21T01.06.56.699238Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34162221_2023-02-21T01.06.56.699238Z_WS.POZA.S3.DNZ_WS.POZA.S3.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34162221_2023-02-21T01.06.56.700647Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34162221_2023-02-21T01.06.56.700647Z_WS.POZA.S2.DN2.MSEED
# Match found: 34162221_2023-02-21T01.06.56.700647Z_WS.POZA.S2.DNZ.MSEED
# Error parsing data for 34162221_2023-02-21T01.06.56.700647Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162221_2023-02-21T01.06.56.701079Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34162221_2023-02-21T01.06.56.701079Z_WS.POZA.S4.DN2.MSEED
# Match found: 34162221_2023-02-21T01.06.56.701079Z_WS.POZA.S4.DNZ.MSEED
# Error parsing data for 34162221_2023-02-21T01.06.56.701079Z_WS.POZA.S4.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162311_2023-02-21T01.15.19.397562Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34162311_2023-02-21T01.15.19.397562Z_WS.POZA.S5.DN2.MSEED
# Match found: 34162311_2023-02-21T01.15.19.397562Z_WS.POZA.S5.DNZ.MSEED
# Error parsing data for 34162311_2023-02-21T01.15.19.397562Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162311_2023-02-21T01.15.19.398149Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34162311_2023-02-21T01.15.19.398149Z_WS.POZA.S6.DN2.MSEED
# Match found: 34162311_2023-02-21T01.15.19.398149Z_WS.POZA.S6.DNZ.MSEED
# Error parsing data for 34162311_2023-02-21T01.15.19.398149Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162311_2023-02-21T01.15.19.399238Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34162311_2023-02-21T01.15.19.399238Z_WS.POZA.S3.DN2.MSEED
# Match found: 34162311_2023-02-21T01.15.19.399238Z_WS.POZA.S3.DNZ.MSEED
# Error parsing data for 34162311_2023-02-21T01.15.19.399238Z_WS.POZA.S3.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162311_2023-02-21T01.15.19.400647Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34162311_2023-02-21T01.15.19.400647Z_WS.POZA.S2.DN2.MSEED
# Match found: 34162311_2023-02-21T01.15.19.400647Z_WS.POZA.S2.DNZ.MSEED
# Error parsing data for 34162311_2023-02-21T01.15.19.400647Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162311_2023-02-21T01.15.19.401079Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34162311_2023-02-21T01.15.19.401079Z_WS.POZA.S4.DN2.MSEED
# Match found: 34162311_2023-02-21T01.15.19.401079Z_WS.POZA.S4.DNZ.MSEED
# Error parsing data for 34162311_2023-02-21T01.15.19.401079Z_WS.POZA.S4.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162371_2023-02-21T01.31.01.417675Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34162371_2023-02-21T01.31.01.417675Z_WS.POZA.S5.DN2.MSEED
# Match found: 34162371_2023-02-21T01.31.01.417675Z_WS.POZA.S5.DNZ.MSEED
# Error parsing data for 34162371_2023-02-21T01.31.01.417675Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162371_2023-02-21T01.31.01.417936Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34162371_2023-02-21T01.31.01.417936Z_WS.POZA.S6.DN2.MSEED
# Match found: 34162371_2023-02-21T01.31.01.417936Z_WS.POZA.S6.DNZ.MSEED
# Error parsing data for 34162371_2023-02-21T01.31.01.417936Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162371_2023-02-21T01.31.01.419238Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34162371_2023-02-21T01.31.01.419238Z_WS.POZA.S3.DN2.MSEED
# Match found: 34162371_2023-02-21T01.31.01.419238Z_WS.POZA.S3.DNZ.MSEED
# Error parsing data for 34162371_2023-02-21T01.31.01.419238Z_WS.POZA.S3.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162371_2023-02-21T01.31.01.420647Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34162371_2023-02-21T01.31.01.420647Z_WS.POZA.S2.DN2.MSEED
# Match found: 34162371_2023-02-21T01.31.01.420647Z_WS.POZA.S2.DNZ.MSEED
# Error parsing data for 34162371_2023-02-21T01.31.01.420647Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162371_2023-02-21T01.31.01.421079Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34162371_2023-02-21T01.31.01.421079Z_WS.POZA.S4.DN2.MSEED
# Match found: 34162371_2023-02-21T01.31.01.421079Z_WS.POZA.S4.DNZ.MSEED
# Error parsing data for 34162371_2023-02-21T01.31.01.421079Z_WS.POZA.S4.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162431_2023-02-21T01.31.15.097675Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34162431_2023-02-21T01.31.15.097675Z_WS.POZA.S5.DN2.MSEED
# Match found: 34162431_2023-02-21T01.31.15.097675Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34162431_2023-02-21T01.31.15.097675Z_WS.POZA.S5.DNZ_WS.POZA.S5.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34162431_2023-02-21T01.31.15.097936Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34162431_2023-02-21T01.31.15.097936Z_WS.POZA.S6.DN2.MSEED
# Match found: 34162431_2023-02-21T01.31.15.097936Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34162431_2023-02-21T01.31.15.097936Z_WS.POZA.S6.DNZ_WS.POZA.S6.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34162431_2023-02-21T01.31.15.099238Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34162431_2023-02-21T01.31.15.099238Z_WS.POZA.S3.DN2.MSEED
# Match found: 34162431_2023-02-21T01.31.15.099238Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34162431_2023-02-21T01.31.15.099238Z_WS.POZA.S3.DNZ_WS.POZA.S3.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34162431_2023-02-21T01.31.15.100647Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34162431_2023-02-21T01.31.15.100647Z_WS.POZA.S2.DN2.MSEED
# Match found: 34162431_2023-02-21T01.31.15.100647Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34162431_2023-02-21T01.31.15.100647Z_WS.POZA.S2.DNZ_WS.POZA.S2.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34162431_2023-02-21T01.31.15.101079Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34162431_2023-02-21T01.31.15.101079Z_WS.POZA.S4.DN2.MSEED
# Match found: 34162431_2023-02-21T01.31.15.101079Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34162431_2023-02-21T01.31.15.101079Z_WS.POZA.S4.DNZ_WS.POZA.S4.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34162501_2023-02-21T02.02.38.097936Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34162501_2023-02-21T02.02.38.097936Z_WS.POZA.S6.DN2.MSEED
# Match found: 34162501_2023-02-21T02.02.38.097936Z_WS.POZA.S6.DNZ.MSEED
# Error parsing data for 34162501_2023-02-21T02.02.38.097936Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162501_2023-02-21T02.02.38.098562Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34162501_2023-02-21T02.02.38.098562Z_WS.POZA.S2.DN2.MSEED
# Match found: 34162501_2023-02-21T02.02.38.098562Z_WS.POZA.S2.DNZ.MSEED
# Error parsing data for 34162501_2023-02-21T02.02.38.098562Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162501_2023-02-21T02.02.38.098588Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34162501_2023-02-21T02.02.38.098588Z_WS.POZA.S5.DN2.MSEED
# Match found: 34162501_2023-02-21T02.02.38.098588Z_WS.POZA.S5.DNZ.MSEED
# Error parsing data for 34162501_2023-02-21T02.02.38.098588Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162501_2023-02-21T02.02.38.098725Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34162501_2023-02-21T02.02.38.098725Z_WS.POZA.S4.DN2.MSEED
# Match found: 34162501_2023-02-21T02.02.38.098725Z_WS.POZA.S4.DNZ.MSEED
# Error parsing data for 34162501_2023-02-21T02.02.38.098725Z_WS.POZA.S4.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162501_2023-02-21T02.02.38.100243Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34162501_2023-02-21T02.02.38.100243Z_WS.POZA.S3.DN2.MSEED
# Match found: 34162501_2023-02-21T02.02.38.100243Z_WS.POZA.S3.DNZ.MSEED
# Error parsing data for 34162501_2023-02-21T02.02.38.100243Z_WS.POZA.S3.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162511_2023-02-21T02.06.02.977755Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34162511_2023-02-21T02.06.02.977755Z_WS.POZA.S6.DN2.MSEED
# Match found: 34162511_2023-02-21T02.06.02.977755Z_WS.POZA.S6.DNZ.MSEED
# Error parsing data for 34162511_2023-02-21T02.06.02.977755Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162511_2023-02-21T02.06.02.978562Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34162511_2023-02-21T02.06.02.978562Z_WS.POZA.S2.DN2.MSEED
# Match found: 34162511_2023-02-21T02.06.02.978562Z_WS.POZA.S2.DNZ.MSEED
# Error parsing data for 34162511_2023-02-21T02.06.02.978562Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162511_2023-02-21T02.06.02.978588Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34162511_2023-02-21T02.06.02.978588Z_WS.POZA.S5.DN2.MSEED
# Match found: 34162511_2023-02-21T02.06.02.978588Z_WS.POZA.S5.DNZ.MSEED
# Error parsing data for 34162511_2023-02-21T02.06.02.978588Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162511_2023-02-21T02.06.02.978725Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34162511_2023-02-21T02.06.02.978725Z_WS.POZA.S4.DN2.MSEED
# Match found: 34162511_2023-02-21T02.06.02.978725Z_WS.POZA.S4.DNZ.MSEED
# Error parsing data for 34162511_2023-02-21T02.06.02.978725Z_WS.POZA.S4.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162511_2023-02-21T02.06.02.980243Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34162511_2023-02-21T02.06.02.980243Z_WS.POZA.S3.DN2.MSEED
# Match found: 34162511_2023-02-21T02.06.02.980243Z_WS.POZA.S3.DNZ.MSEED
# Error parsing data for 34162511_2023-02-21T02.06.02.980243Z_WS.POZA.S3.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162741_2023-02-21T02.39.54.850587Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34162741_2023-02-21T02.39.54.850587Z_WS.POZA.S5.DN2.MSEED
# Match found: 34162741_2023-02-21T02.39.54.850587Z_WS.POZA.S5.DNZ.MSEED
# Error parsing data for 34162741_2023-02-21T02.39.54.850587Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162741_2023-02-21T02.39.54.850647Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34162741_2023-02-21T02.39.54.850647Z_WS.POZA.S4.DN2.MSEED
# Match found: 34162741_2023-02-21T02.39.54.850647Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34162741_2023-02-21T02.39.54.850647Z_WS.POZA.S4.DNZ_WS.POZA.S4.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34162741_2023-02-21T02.39.54.850725Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34162741_2023-02-21T02.39.54.850725Z_WS.POZA.S2.DN2.MSEED
# Match found: 34162741_2023-02-21T02.39.54.850725Z_WS.POZA.S2.DNZ.MSEED
# Error parsing data for 34162741_2023-02-21T02.39.54.850725Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162741_2023-02-21T02.39.54.852047Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34162741_2023-02-21T02.39.54.852047Z_WS.POZA.S3.DN2.MSEED
# Match found: 34162741_2023-02-21T02.39.54.852047Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34162741_2023-02-21T02.39.54.852047Z_WS.POZA.S3.DNZ_WS.POZA.S3.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34162741_2023-02-21T02.39.54.853537Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34162741_2023-02-21T02.39.54.853537Z_WS.POZA.S6.DN2.MSEED
# Match found: 34162741_2023-02-21T02.39.54.853537Z_WS.POZA.S6.DNZ.MSEED
# Error parsing data for 34162741_2023-02-21T02.39.54.853537Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34163011_2023-02-21T03.32.30.490319Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34163011_2023-02-21T03.32.30.490319Z_WS.POZA.S3.DN2.MSEED
# Match found: 34163011_2023-02-21T03.32.30.490319Z_WS.POZA.S3.DNZ.MSEED
# Error parsing data for 34163011_2023-02-21T03.32.30.490319Z_WS.POZA.S3.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34163011_2023-02-21T03.32.30.492143Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34163011_2023-02-21T03.32.30.492143Z_WS.POZA.S5.DN2.MSEED
# Match found: 34163011_2023-02-21T03.32.30.492143Z_WS.POZA.S5.DNZ.MSEED
# Error parsing data for 34163011_2023-02-21T03.32.30.492143Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34163011_2023-02-21T03.32.30.492276Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34163011_2023-02-21T03.32.30.492276Z_WS.POZA.S4.DN2.MSEED
# Match found: 34163011_2023-02-21T03.32.30.492276Z_WS.POZA.S4.DNZ.MSEED
# Error parsing data for 34163011_2023-02-21T03.32.30.492276Z_WS.POZA.S4.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34163011_2023-02-21T03.32.30.492397Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34163011_2023-02-21T03.32.30.492397Z_WS.POZA.S2.DN2.MSEED
# Match found: 34163011_2023-02-21T03.32.30.492397Z_WS.POZA.S2.DNZ.MSEED
# Error parsing data for 34163011_2023-02-21T03.32.30.492397Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34163011_2023-02-21T03.32.30.493482Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34163011_2023-02-21T03.32.30.493482Z_WS.POZA.S6.DN2.MSEED
# Match found: 34163011_2023-02-21T03.32.30.493482Z_WS.POZA.S6.DNZ.MSEED
# Error parsing data for 34163011_2023-02-21T03.32.30.493482Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34163051_2023-02-21T03.41.55.050319Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34163051_2023-02-21T03.41.55.050319Z_WS.POZA.S3.DN2.MSEED
# Match found: 34163051_2023-02-21T03.41.55.050319Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34163051_2023-02-21T03.41.55.050319Z_WS.POZA.S3.DNZ_WS.POZA.S3.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34163051_2023-02-21T03.41.55.052143Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34163051_2023-02-21T03.41.55.052143Z_WS.POZA.S5.DN2.MSEED
# Match found: 34163051_2023-02-21T03.41.55.052143Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34163051_2023-02-21T03.41.55.052143Z_WS.POZA.S5.DNZ_WS.POZA.S5.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34163051_2023-02-21T03.41.55.052276Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34163051_2023-02-21T03.41.55.052276Z_WS.POZA.S4.DN2.MSEED
# Match found: 34163051_2023-02-21T03.41.55.052276Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34163051_2023-02-21T03.41.55.052276Z_WS.POZA.S4.DNZ_WS.POZA.S4.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34163051_2023-02-21T03.41.55.052397Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34163051_2023-02-21T03.41.55.052397Z_WS.POZA.S2.DN2.MSEED
# Match found: 34163051_2023-02-21T03.41.55.052397Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34163051_2023-02-21T03.41.55.052397Z_WS.POZA.S2.DNZ_WS.POZA.S2.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34163051_2023-02-21T03.41.55.053482Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34163051_2023-02-21T03.41.55.053482Z_WS.POZA.S6.DN2.MSEED
# Match found: 34163051_2023-02-21T03.41.55.053482Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34163051_2023-02-21T03.41.55.053482Z_WS.POZA.S6.DNZ_WS.POZA.S6.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34163411_2023-02-21T04.49.09.159092Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34163411_2023-02-21T04.49.09.159092Z_WS.POZA.S4.DN2.MSEED
# Match found: 34163411_2023-02-21T04.49.09.159092Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34163411_2023-02-21T04.49.09.159092Z_WS.POZA.S4.DNZ_WS.POZA.S4.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34163411_2023-02-21T04.49.09.159201Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34163411_2023-02-21T04.49.09.159201Z_WS.POZA.S5.DN2.MSEED
# Match found: 34163411_2023-02-21T04.49.09.159201Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34163411_2023-02-21T04.49.09.159201Z_WS.POZA.S5.DNZ_WS.POZA.S5.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34163411_2023-02-21T04.49.09.160249Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34163411_2023-02-21T04.49.09.160249Z_WS.POZA.S6.DN2.MSEED
# Match found: 34163411_2023-02-21T04.49.09.160249Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34163411_2023-02-21T04.49.09.160249Z_WS.POZA.S6.DNZ_WS.POZA.S6.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34163411_2023-02-21T04.49.09.161007Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34163411_2023-02-21T04.49.09.161007Z_WS.POZA.S3.DN2.MSEED
# Match found: 34163411_2023-02-21T04.49.09.161007Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34163411_2023-02-21T04.49.09.161007Z_WS.POZA.S3.DNZ_WS.POZA.S3.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34163411_2023-02-21T04.49.09.161225Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34163411_2023-02-21T04.49.09.161225Z_WS.POZA.S2.DN2.MSEED
# Match found: 34163411_2023-02-21T04.49.09.161225Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34163411_2023-02-21T04.49.09.161225Z_WS.POZA.S2.DNZ_WS.POZA.S2.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34163481_2023-02-21T05.15.35.189899Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34163481_2023-02-21T05.15.35.189899Z_WS.POZA.S4.DN2.MSEED
# Match found: 34163481_2023-02-21T05.15.35.189899Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34163481_2023-02-21T05.15.35.189899Z_WS.POZA.S4.DNZ_WS.POZA.S4.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34163481_2023-02-21T05.15.35.190426Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34163481_2023-02-21T05.15.35.190426Z_WS.POZA.S6.DN2.MSEED
# Match found: 34163481_2023-02-21T05.15.35.190426Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34163481_2023-02-21T05.15.35.190426Z_WS.POZA.S6.DNZ_WS.POZA.S6.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34163481_2023-02-21T05.15.35.191097Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34163481_2023-02-21T05.15.35.191097Z_WS.POZA.S2.DN2.MSEED
# Match found: 34163481_2023-02-21T05.15.35.191097Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34163481_2023-02-21T05.15.35.191097Z_WS.POZA.S2.DNZ_WS.POZA.S2.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34163481_2023-02-21T05.15.35.191190Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34163481_2023-02-21T05.15.35.191190Z_WS.POZA.S5.DN2.MSEED
# Match found: 34163481_2023-02-21T05.15.35.191190Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34163481_2023-02-21T05.15.35.191190Z_WS.POZA.S5.DNZ_WS.POZA.S5.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34163481_2023-02-21T05.15.35.193431Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34163481_2023-02-21T05.15.35.193431Z_WS.POZA.S3.DN2.MSEED
# Match found: 34163481_2023-02-21T05.15.35.193431Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34163481_2023-02-21T05.15.35.193431Z_WS.POZA.S3.DNZ_WS.POZA.S3.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34163561_2023-02-21T05.33.59.897899Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34163561_2023-02-21T05.33.59.897899Z_WS.POZA.S4.DN2.MSEED
# Match found: 34163561_2023-02-21T05.33.59.897899Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34163561_2023-02-21T05.33.59.897899Z_WS.POZA.S4.DNZ_WS.POZA.S4.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34163561_2023-02-21T05.33.59.898424Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34163561_2023-02-21T05.33.59.898424Z_WS.POZA.S6.DN2.MSEED
# Match found: 34163561_2023-02-21T05.33.59.898424Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34163561_2023-02-21T05.33.59.898424Z_WS.POZA.S6.DNZ_WS.POZA.S6.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34163561_2023-02-21T05.33.59.899097Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34163561_2023-02-21T05.33.59.899097Z_WS.POZA.S2.DN2.MSEED
# Match found: 34163561_2023-02-21T05.33.59.899097Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34163561_2023-02-21T05.33.59.899097Z_WS.POZA.S2.DNZ_WS.POZA.S2.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34163561_2023-02-21T05.33.59.899190Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34163561_2023-02-21T05.33.59.899190Z_WS.POZA.S5.DN2.MSEED
# Match found: 34163561_2023-02-21T05.33.59.899190Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34163561_2023-02-21T05.33.59.899190Z_WS.POZA.S5.DNZ_WS.POZA.S5.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34163561_2023-02-21T05.33.59.901431Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34163561_2023-02-21T05.33.59.901431Z_WS.POZA.S3.DN2.MSEED
# Match found: 34163561_2023-02-21T05.33.59.901431Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34163561_2023-02-21T05.33.59.901431Z_WS.POZA.S3.DNZ_WS.POZA.S3.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34163931_2023-02-21T06.38.57.057885Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34163931_2023-02-21T06.38.57.057885Z_WS.POZA.S6.DN2.MSEED
# Match found: 34163931_2023-02-21T06.38.57.057885Z_WS.POZA.S6.DNZ.MSEED
# Error parsing data for 34163931_2023-02-21T06.38.57.057885Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34163931_2023-02-21T06.38.57.058077Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34163931_2023-02-21T06.38.57.058077Z_WS.POZA.S3.DN2.MSEED
# Match found: 34163931_2023-02-21T06.38.57.058077Z_WS.POZA.S3.DNZ.MSEED
# Error parsing data for 34163931_2023-02-21T06.38.57.058077Z_WS.POZA.S3.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34163931_2023-02-21T06.38.57.058640Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34163931_2023-02-21T06.38.57.058640Z_WS.POZA.S2.DN2.MSEED
# Match found: 34163931_2023-02-21T06.38.57.058640Z_WS.POZA.S2.DNZ.MSEED
# Error parsing data for 34163931_2023-02-21T06.38.57.058640Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34163931_2023-02-21T06.38.57.059081Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34163931_2023-02-21T06.38.57.059081Z_WS.POZA.S5.DN2.MSEED
# Match found: 34163931_2023-02-21T06.38.57.059081Z_WS.POZA.S5.DNZ.MSEED
# Error parsing data for 34163931_2023-02-21T06.38.57.059081Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34163931_2023-02-21T06.38.57.059276Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34163931_2023-02-21T06.38.57.059276Z_WS.POZA.S4.DN2.MSEED
# Match found: 34163931_2023-02-21T06.38.57.059276Z_WS.POZA.S4.DNZ.MSEED
# Error parsing data for 34163931_2023-02-21T06.38.57.059276Z_WS.POZA.S4.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34164401_2023-02-21T07.13.34.330804Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34164401_2023-02-21T07.13.34.330804Z_WS.POZA.S4.DN2.MSEED
# Match found: 34164401_2023-02-21T07.13.34.330804Z_WS.POZA.S4.DNZ.MSEED
# Error parsing data for 34164401_2023-02-21T07.13.34.330804Z_WS.POZA.S4.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34164401_2023-02-21T07.13.34.331170Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34164401_2023-02-21T07.13.34.331170Z_WS.POZA.S5.DN2.MSEED
# Match found: 34164401_2023-02-21T07.13.34.331170Z_WS.POZA.S5.DNZ.MSEED
# Error parsing data for 34164401_2023-02-21T07.13.34.331170Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34164401_2023-02-21T07.13.34.331365Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34164401_2023-02-21T07.13.34.331365Z_WS.POZA.S2.DN2.MSEED
# Match found: 34164401_2023-02-21T07.13.34.331365Z_WS.POZA.S2.DNZ.MSEED
# Error parsing data for 34164401_2023-02-21T07.13.34.331365Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34164401_2023-02-21T07.13.34.332303Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34164401_2023-02-21T07.13.34.332303Z_WS.POZA.S6.DN2.MSEED
# Match found: 34164401_2023-02-21T07.13.34.332303Z_WS.POZA.S6.DNZ.MSEED
# Error parsing data for 34164401_2023-02-21T07.13.34.332303Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34164401_2023-02-21T07.13.34.333420Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34164401_2023-02-21T07.13.34.333420Z_WS.POZA.S3.DN2.MSEED
# Match found: 34164401_2023-02-21T07.13.34.333420Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34164401_2023-02-21T07.13.34.333420Z_WS.POZA.S3.DNZ_WS.POZA.S3.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34164891_2023-02-21T08.19.39.829964Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34164891_2023-02-21T08.19.39.829964Z_WS.POZA.S6.DN2.MSEED
# Match found: 34164891_2023-02-21T08.19.39.829964Z_WS.POZA.S6.DNZ.MSEED
# Error parsing data for 34164891_2023-02-21T08.19.39.829964Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34164891_2023-02-21T08.19.39.830367Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34164891_2023-02-21T08.19.39.830367Z_WS.POZA.S3.DN2.MSEED
# Match found: 34164891_2023-02-21T08.19.39.830367Z_WS.POZA.S3.DNZ.MSEED
# Error parsing data for 34164891_2023-02-21T08.19.39.830367Z_WS.POZA.S3.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34164891_2023-02-21T08.19.39.830757Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34164891_2023-02-21T08.19.39.830757Z_WS.POZA.S2.DN2.MSEED
# Match found: 34164891_2023-02-21T08.19.39.830757Z_WS.POZA.S2.DNZ.MSEED
# Error parsing data for 34164891_2023-02-21T08.19.39.830757Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34164891_2023-02-21T08.19.39.831473Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34164891_2023-02-21T08.19.39.831473Z_WS.POZA.S5.DN2.MSEED
# Match found: 34164891_2023-02-21T08.19.39.831473Z_WS.POZA.S5.DNZ.MSEED
# Error parsing data for 34164891_2023-02-21T08.19.39.831473Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34164891_2023-02-21T08.19.39.832827Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34164891_2023-02-21T08.19.39.832827Z_WS.POZA.S4.DN2.MSEED
# Match found: 34164891_2023-02-21T08.19.39.832827Z_WS.POZA.S4.DNZ.MSEED
# Error parsing data for 34164891_2023-02-21T08.19.39.832827Z_WS.POZA.S4.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34165791_2023-02-21T10.36.27.750661Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34165791_2023-02-21T10.36.27.750661Z_WS.POZA.S6.DN2.MSEED
# Match found: 34165791_2023-02-21T10.36.27.750661Z_WS.POZA.S6.DNZ.MSEED
# Error parsing data for 34165791_2023-02-21T10.36.27.750661Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34165791_2023-02-21T10.36.27.751693Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34165791_2023-02-21T10.36.27.751693Z_WS.POZA.S4.DN2.MSEED
# Match found: 34165791_2023-02-21T10.36.27.751693Z_WS.POZA.S4.DNZ.MSEED
# Error parsing data for 34165791_2023-02-21T10.36.27.751693Z_WS.POZA.S4.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34165791_2023-02-21T10.36.27.751736Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34165791_2023-02-21T10.36.27.751736Z_WS.POZA.S3.DN2.MSEED
# Match found: 34165791_2023-02-21T10.36.27.751736Z_WS.POZA.S3.DNZ.MSEED
# Error parsing data for 34165791_2023-02-21T10.36.27.751736Z_WS.POZA.S3.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34165791_2023-02-21T10.36.27.751945Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34165791_2023-02-21T10.36.27.751945Z_WS.POZA.S5.DN2.MSEED
# Match found: 34165791_2023-02-21T10.36.27.751945Z_WS.POZA.S5.DNZ.MSEED
# Error parsing data for 34165791_2023-02-21T10.36.27.751945Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34165791_2023-02-21T10.36.27.752007Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34165791_2023-02-21T10.36.27.752007Z_WS.POZA.S2.DN2.MSEED
# Match found: 34165791_2023-02-21T10.36.27.752007Z_WS.POZA.S2.DNZ.MSEED
# Error parsing data for 34165791_2023-02-21T10.36.27.752007Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34166831_2023-02-21T12.48.34.238879Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34166831_2023-02-21T12.48.34.238879Z_WS.POZA.S3.DN2.MSEED
# Match found: 34166831_2023-02-21T12.48.34.238879Z_WS.POZA.S3.DNZ.MSEED
# Error parsing data for 34166831_2023-02-21T12.48.34.238879Z_WS.POZA.S3.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34166831_2023-02-21T12.48.34.239476Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34166831_2023-02-21T12.48.34.239476Z_WS.POZA.S6.DN2.MSEED
# Match found: 34166831_2023-02-21T12.48.34.239476Z_WS.POZA.S6.DNZ.MSEED
# Error parsing data for 34166831_2023-02-21T12.48.34.239476Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34166831_2023-02-21T12.48.34.239517Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34166831_2023-02-21T12.48.34.239517Z_WS.POZA.S2.DN2.MSEED
# Match found: 34166831_2023-02-21T12.48.34.239517Z_WS.POZA.S2.DNZ.MSEED
# Error parsing data for 34166831_2023-02-21T12.48.34.239517Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34166831_2023-02-21T12.48.34.239983Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34166831_2023-02-21T12.48.34.239983Z_WS.POZA.S5.DN2.MSEED
# Match found: 34166831_2023-02-21T12.48.34.239983Z_WS.POZA.S5.DNZ.MSEED
# Error parsing data for 34166831_2023-02-21T12.48.34.239983Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34166831_2023-02-21T12.48.34.240879Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34166831_2023-02-21T12.48.34.240879Z_WS.POZA.S4.DN2.MSEED
# Match found: 34166831_2023-02-21T12.48.34.240879Z_WS.POZA.S4.DNZ.MSEED
# Error parsing data for 34166831_2023-02-21T12.48.34.240879Z_WS.POZA.S4.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34167831_2023-02-21T15.08.01.278424Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34167831_2023-02-21T15.08.01.278424Z_WS.POZA.S6.DN2.MSEED
# Match found: 34167831_2023-02-21T15.08.01.278424Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34167831_2023-02-21T15.08.01.278424Z_WS.POZA.S6.DNZ_WS.POZA.S6.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34167831_2023-02-21T15.08.01.279429Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34167831_2023-02-21T15.08.01.279429Z_WS.POZA.S3.DN2.MSEED
# Match found: 34167831_2023-02-21T15.08.01.279429Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# ...
# Match found: 34547561_2023-04-02T22.57.18.573506Z_WS.POZA.S2.DNZ.MSEED
# Error parsing data for 34547561_2023-04-02T22.57.18.573506Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34547561_2023-04-02T22.57.18.573604Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34547561_2023-04-02T22.57.18.573604Z_WS.POZA.S3.DN2.MSEED
# Match found: 34547561_2023-04-02T22.57.18.573604Z_WS.POZA.S3.DNZ.MSEED
# Error parsing data for 34547561_2023-04-02T22.57.18.573604Z_WS.POZA.S3.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34547641_2023-04-02T22.57.32.438053Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34547641_2023-04-02T22.57.32.438053Z_WS.POZA.S5.DN2.MSEED
# Match found: 34547641_2023-04-02T22.57.32.438053Z_WS.POZA.S5.DNZ.MSEED
# Error parsing data for 34547641_2023-04-02T22.57.32.438053Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34547641_2023-04-02T22.57.32.441150Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34547641_2023-04-02T22.57.32.441150Z_WS.POZA.S6.DN2.MSEED
# Match found: 34547641_2023-04-02T22.57.32.441150Z_WS.POZA.S6.DNZ.MSEED
# Error parsing data for 34547641_2023-04-02T22.57.32.441150Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34547641_2023-04-02T22.57.32.441506Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34547641_2023-04-02T22.57.32.441506Z_WS.POZA.S2.DN2.MSEED
# Match found: 34547641_2023-04-02T22.57.32.441506Z_WS.POZA.S2.DNZ.MSEED
# Error parsing data for 34547641_2023-04-02T22.57.32.441506Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34547641_2023-04-02T22.57.32.441604Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34547641_2023-04-02T22.57.32.441604Z_WS.POZA.S3.DN2.MSEED
# Match found: 34547641_2023-04-02T22.57.32.441604Z_WS.POZA.S3.DNZ.MSEED
# Error parsing data for 34547641_2023-04-02T22.57.32.441604Z_WS.POZA.S3.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34674981_2023-04-13T23.18.18.486965Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34674981_2023-04-13T23.18.18.486965Z_WS.POZA.S3.DN2.MSEED
# Match found: 34674981_2023-04-13T23.18.18.486965Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34674981_2023-04-13T23.18.18.486965Z_WS.POZA.S3.DNZ_WS.POZA.S3.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34674981_2023-04-13T23.18.18.487000Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34674981_2023-04-13T23.18.18.487000Z_WS.POZA.S4.DN2.MSEED
# Match found: 34674981_2023-04-13T23.18.18.487000Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34674981_2023-04-13T23.18.18.487000Z_WS.POZA.S4.DNZ_WS.POZA.S4.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34674981_2023-04-13T23.18.18.489840Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34674981_2023-04-13T23.18.18.489840Z_WS.POZA.S2.DN2.MSEED
# Match found: 34674981_2023-04-13T23.18.18.489840Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34674981_2023-04-13T23.18.18.489840Z_WS.POZA.S2.DNZ_WS.POZA.S2.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34674981_2023-04-13T23.18.18.489861Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34674981_2023-04-13T23.18.18.489861Z_WS.POZA.S5.DN2.MSEED
# Match found: 34674981_2023-04-13T23.18.18.489861Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34674981_2023-04-13T23.18.18.489861Z_WS.POZA.S5.DNZ_WS.POZA.S5.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34674981_2023-04-13T23.18.18.490349Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34674981_2023-04-13T23.18.18.490349Z_WS.POZA.S6.DN2.MSEED
# Match found: 34674981_2023-04-13T23.18.18.490349Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34674981_2023-04-13T23.18.18.490349Z_WS.POZA.S6.DNZ_WS.POZA.S6.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34692381_2023-04-15T13.17.55.539433Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34692381_2023-04-15T13.17.55.539433Z_WS.POZA.S6.DN2.MSEED
# Match found: 34692381_2023-04-15T13.17.55.539433Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34692381_2023-04-15T13.17.55.539433Z_WS.POZA.S6.DNZ_WS.POZA.S6.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34692381_2023-04-15T13.17.55.539436Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34692381_2023-04-15T13.17.55.539436Z_WS.POZA.S5.DN2.MSEED
# Match found: 34692381_2023-04-15T13.17.55.539436Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34692381_2023-04-15T13.17.55.539436Z_WS.POZA.S5.DNZ_WS.POZA.S5.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34692381_2023-04-15T13.17.55.540100Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34692381_2023-04-15T13.17.55.540100Z_WS.POZA.S4.DN2.MSEED
# Match found: 34692381_2023-04-15T13.17.55.540100Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34692381_2023-04-15T13.17.55.540100Z_WS.POZA.S4.DNZ_WS.POZA.S4.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34692381_2023-04-15T13.17.55.541619Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34692381_2023-04-15T13.17.55.541619Z_WS.POZA.S2.DN2.MSEED
# Match found: 34692381_2023-04-15T13.17.55.541619Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34692381_2023-04-15T13.17.55.541619Z_WS.POZA.S2.DNZ_WS.POZA.S2.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34692381_2023-04-15T13.17.55.542715Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34692381_2023-04-15T13.17.55.542715Z_WS.POZA.S3.DN2.MSEED
# Match found: 34692381_2023-04-15T13.17.55.542715Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34692381_2023-04-15T13.17.55.542715Z_WS.POZA.S3.DNZ_WS.POZA.S3.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34821541_2023-04-27T12.08.16.710163Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34821541_2023-04-27T12.08.16.710163Z_WS.POZA.S4.DN2.MSEED
# Match found: 34821541_2023-04-27T12.08.16.710163Z_WS.POZA.S4.DNZ.MSEED
# Error parsing data for 34821541_2023-04-27T12.08.16.710163Z_WS.POZA.S4.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34821541_2023-04-27T12.08.16.710305Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34821541_2023-04-27T12.08.16.710305Z_WS.POZA.S3.DN2.MSEED
# Match found: 34821541_2023-04-27T12.08.16.710305Z_WS.POZA.S3.DNZ.MSEED
# Error parsing data for 34821541_2023-04-27T12.08.16.710305Z_WS.POZA.S3.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34821541_2023-04-27T12.08.16.711033Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34821541_2023-04-27T12.08.16.711033Z_WS.POZA.S6.DN2.MSEED
# Match found: 34821541_2023-04-27T12.08.16.711033Z_WS.POZA.S6.DNZ.MSEED
# Error parsing data for 34821541_2023-04-27T12.08.16.711033Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34821541_2023-04-27T12.08.16.712359Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34821541_2023-04-27T12.08.16.712359Z_WS.POZA.S5.DN2.MSEED
# Match found: 34821541_2023-04-27T12.08.16.712359Z_WS.POZA.S5.DNZ.MSEED
# Error parsing data for 34821541_2023-04-27T12.08.16.712359Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34821541_2023-04-27T12.08.16.712806Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34821541_2023-04-27T12.08.16.712806Z_WS.POZA.S2.DN2.MSEED
# Match found: 34821541_2023-04-27T12.08.16.712806Z_WS.POZA.S2.DNZ.MSEED
# Error parsing data for 34821541_2023-04-27T12.08.16.712806Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34836221_2023-04-28T20.50.39.467773Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 34836221_2023-04-28T20.50.39.467773Z_WS.POZA.S4.DN2.MSEED
# Match found: 34836221_2023-04-28T20.50.39.467773Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34836221_2023-04-28T20.50.39.467773Z_WS.POZA.S4.DNZ_WS.POZA.S4.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34836221_2023-04-28T20.50.39.468678Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34836221_2023-04-28T20.50.39.468678Z_WS.POZA.S6.DN2.MSEED
# Match found: 34836221_2023-04-28T20.50.39.468678Z_WS.POZA.S6.DNZ.MSEED
# Error parsing data for 34836221_2023-04-28T20.50.39.468678Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34836221_2023-04-28T20.50.39.470042Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34836221_2023-04-28T20.50.39.470042Z_WS.POZA.S5.DN2.MSEED
# Match found: 34836221_2023-04-28T20.50.39.470042Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34836221_2023-04-28T20.50.39.470042Z_WS.POZA.S5.DNZ_WS.POZA.S5.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34836221_2023-04-28T20.50.39.470238Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34836221_2023-04-28T20.50.39.470238Z_WS.POZA.S3.DN2.MSEED
# Match found: 34836221_2023-04-28T20.50.39.470238Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34836221_2023-04-28T20.50.39.470238Z_WS.POZA.S3.DNZ_WS.POZA.S3.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34836221_2023-04-28T20.50.39.470291Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34836221_2023-04-28T20.50.39.470291Z_WS.POZA.S2.DN2.MSEED
# Match found: 34836221_2023-04-28T20.50.39.470291Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\34836221_2023-04-28T20.50.39.470291Z_WS.POZA.S2.DNZ_WS.POZA.S2.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 34956701_2023-05-11T23.41.38.889527Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 34956701_2023-05-11T23.41.38.889527Z_WS.POZA.S5.DN2.MSEED
# Match found: 34956701_2023-05-11T23.41.38.889527Z_WS.POZA.S5.DNZ.MSEED
# Error parsing data for 34956701_2023-05-11T23.41.38.889527Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34956701_2023-05-11T23.41.38.889759Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 34956701_2023-05-11T23.41.38.889759Z_WS.POZA.S2.DN2.MSEED
# Match found: 34956701_2023-05-11T23.41.38.889759Z_WS.POZA.S2.DNZ.MSEED
# Error parsing data for 34956701_2023-05-11T23.41.38.889759Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34956701_2023-05-11T23.41.38.891323Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 34956701_2023-05-11T23.41.38.891323Z_WS.POZA.S3.DN2.MSEED
# Match found: 34956701_2023-05-11T23.41.38.891323Z_WS.POZA.S3.DNZ.MSEED
# Error parsing data for 34956701_2023-05-11T23.41.38.891323Z_WS.POZA.S3.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34956701_2023-05-11T23.41.38.892111Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 34956701_2023-05-11T23.41.38.892111Z_WS.POZA.S6.DN2.MSEED
# Match found: 34956701_2023-05-11T23.41.38.892111Z_WS.POZA.S6.DNZ.MSEED
# Error parsing data for 34956701_2023-05-11T23.41.38.892111Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 35266701_2023-06-09T22.34.36.208297Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 35266701_2023-06-09T22.34.36.208297Z_WS.POZA.S3.DN2.MSEED
# Match found: 35266701_2023-06-09T22.34.36.208297Z_WS.POZA.S3.DNZ.MSEED
# Error parsing data for 35266701_2023-06-09T22.34.36.208297Z_WS.POZA.S3.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 35266701_2023-06-09T22.34.36.210008Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 35266701_2023-06-09T22.34.36.210008Z_WS.POZA.S6.DN2.MSEED
# Match found: 35266701_2023-06-09T22.34.36.210008Z_WS.POZA.S6.DNZ.MSEED
# Error parsing data for 35266701_2023-06-09T22.34.36.210008Z_WS.POZA.S6.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 35266701_2023-06-09T22.34.36.210130Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 35266701_2023-06-09T22.34.36.210130Z_WS.POZA.S5.DN2.MSEED
# Match found: 35266701_2023-06-09T22.34.36.210130Z_WS.POZA.S5.DNZ.MSEED
# Error parsing data for 35266701_2023-06-09T22.34.36.210130Z_WS.POZA.S5.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 35266701_2023-06-09T22.34.36.211277Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 35266701_2023-06-09T22.34.36.211277Z_WS.POZA.S4.DN2.MSEED
# Match found: 35266701_2023-06-09T22.34.36.211277Z_WS.POZA.S4.DNZ.MSEED
# Error parsing data for 35266701_2023-06-09T22.34.36.211277Z_WS.POZA.S4.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 35266701_2023-06-09T22.34.36.212005Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 35266701_2023-06-09T22.34.36.212005Z_WS.POZA.S2.DN2.MSEED
# Match found: 35266701_2023-06-09T22.34.36.212005Z_WS.POZA.S2.DNZ.MSEED
# Error parsing data for 35266701_2023-06-09T22.34.36.212005Z_WS.POZA.S2.DNZ.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 35419441_2023-06-30T04.10.40.107451Z_WS.POZA.S5.DN1.MSEED
# No match found for file: 35419441_2023-06-30T04.10.40.107451Z_WS.POZA.S5.DN2.MSEED
# Match found: 35419441_2023-06-30T04.10.40.107451Z_WS.POZA.S5.DNZ.MSEED
# Processing trace: WS.POZA.S5.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\35419441_2023-06-30T04.10.40.107451Z_WS.POZA.S5.DNZ_WS.POZA.S5.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 35419441_2023-06-30T04.10.40.107601Z_WS.POZA.S2.DN1.MSEED
# No match found for file: 35419441_2023-06-30T04.10.40.107601Z_WS.POZA.S2.DN2.MSEED
# Match found: 35419441_2023-06-30T04.10.40.107601Z_WS.POZA.S2.DNZ.MSEED
# Processing trace: WS.POZA.S2.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\35419441_2023-06-30T04.10.40.107601Z_WS.POZA.S2.DNZ_WS.POZA.S2.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 35419441_2023-06-30T04.10.40.108520Z_WS.POZA.S6.DN1.MSEED
# No match found for file: 35419441_2023-06-30T04.10.40.108520Z_WS.POZA.S6.DN2.MSEED
# Match found: 35419441_2023-06-30T04.10.40.108520Z_WS.POZA.S6.DNZ.MSEED
# Processing trace: WS.POZA.S6.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\35419441_2023-06-30T04.10.40.108520Z_WS.POZA.S6.DNZ_WS.POZA.S6.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 35419441_2023-06-30T04.10.40.108841Z_WS.POZA.S3.DN1.MSEED
# No match found for file: 35419441_2023-06-30T04.10.40.108841Z_WS.POZA.S3.DN2.MSEED
# Match found: 35419441_2023-06-30T04.10.40.108841Z_WS.POZA.S3.DNZ.MSEED
# Processing trace: WS.POZA.S3.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\35419441_2023-06-30T04.10.40.108841Z_WS.POZA.S3.DNZ_WS.POZA.S3.DNZ_sta_lta_snr_graph(multiple).png
# No match found for file: 35419441_2023-06-30T04.10.40.109398Z_WS.POZA.S4.DN1.MSEED
# No match found for file: 35419441_2023-06-30T04.10.40.109398Z_WS.POZA.S4.DN2.MSEED
# Match found: 35419441_2023-06-30T04.10.40.109398Z_WS.POZA.S4.DNZ.MSEED
# Processing trace: WS.POZA.S4.DNZ
# STA/LTA and SNR graph plot saved to: output_sta_lta_snr_plots(multiple)\35419441_2023-06-30T04.10.40.109398Z_WS.POZA.S4.DNZ_WS.POZA.S4.DNZ_sta_lta_snr_graph(multiple).png

# %%
from obspy import read
from obspy import UTCDateTime
from obspy.signal.trigger import classic_sta_lta
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path
import os
import numpy as np

# Load the pick data
pick_data = pd.read_csv(
    "dataset_earthquakes/metadata.csv",
    usecols=['trace_name_original_1', 'trace_p_pick_time', 'trace_s_pick_time', 'source_sensor_distance']
)

# Function to sanitize file names
def sanitize_filename(name):
    return name.replace(".", "").replace(":", "").replace("-", "").replace("_", "")

# Directory containing miniSEED files
mseed_dir = "miniSEED_files"
output_dir = "output_mer_plots"
os.makedirs(output_dir, exist_ok=True)  # Create the output directory if it doesn't exist

# Define STA/LTA parameters
sta_window = 1  # Short-Term Average window (seconds)
lta_window = 10  # Long-Term Average window (seconds)

# Modified Energy Ratio Calculation Function
def calculate_mer(trace, pick_time, pre_window, post_window):
    """
    Calculate the Modified Energy Ratio (MER) for a given trace and pick time.

    Parameters:
        trace (obspy.Trace): The trace containing the waveform data.
        pick_time (UTCDateTime): The pick time to center the calculation around.
        pre_window (float): Duration of the pre-noise window in seconds.
        post_window (float): Duration of the post-signal window in seconds.

    Returns:
        float: The Modified Energy Ratio (MER).
    """
    sampling_rate = trace.stats.sampling_rate
    pre_samples = int(pre_window * sampling_rate)
    post_samples = int(post_window * sampling_rate)

    # Calculate start and end indices for noise and signal windows
    pick_idx = int((pick_time - trace.stats.starttime) * sampling_rate)
    noise_window = trace.data[max(0, pick_idx - pre_samples):pick_idx]
    signal_window = trace.data[pick_idx:min(len(trace.data), pick_idx + post_samples)]

    # Calculate energy in the windows
    noise_energy = np.sum(noise_window**2)
    signal_energy = np.sum(signal_window**2)

    return signal_energy / noise_energy if noise_energy > 0 else 0

# Loop through each miniSEED file in the directory
for file_path in Path(mseed_dir).glob("*.MSEED"):
    mseed_name = sanitize_filename(file_path.name.strip())  # Sanitize the miniSEED file name

    # Check if the miniSEED file matches an entry in the CSV
    matched_row = None
    for _, row in pick_data.iterrows():
        if sanitize_filename(row['trace_name_original_1']) == mseed_name:
            matched_row = row
            break

    if matched_row is None:
        print(f"No match found for file: {file_path.name}")
        continue

    print(f"Match found: {file_path.name}")

    # Extract P and S pick times and sensor distance
    try:
        p_pick = UTCDateTime(matched_row['trace_p_pick_time'])
        s_pick = UTCDateTime(matched_row['trace_s_pick_time'])
        source_sensor_distance = matched_row['source_sensor_distance']
    except Exception as e:
        print(f"Error parsing data for {file_path.name}: {e}")
        continue

    # Read the miniSEED file
    stream = read(file_path)

    # Process each trace in the miniSEED file
    for trace in stream:
        print(f"Processing trace: {trace.id}")

        # Get the sampling rate of the trace
        sampling_rate = trace.stats.sampling_rate

        # Calculate STA/LTA
        try:
            cft = classic_sta_lta(trace.data, int(sta_window * sampling_rate), int(lta_window * sampling_rate))
        except Exception as e:
            print(f"Error computing STA/LTA for trace {trace.id}: {e}")
            continue

        # Calculate MER for different window configurations
        mer_2_5 = calculate_mer(trace, p_pick, pre_window=2, post_window=5)
        mer_5_5 = calculate_mer(trace, p_pick, pre_window=5, post_window=5)

        # Plot the waveform, STA/LTA, and MER
        fig, ax1 = plt.subplots(figsize=(12, 6))

        # Plot the waveform
        times = trace.times("matplotlib")
        ax1.plot(times, trace.data, label=f"Waveform: {trace.id}", color="blue", alpha=0.6)
        ax1.set_xlabel("Time (UTC)")
        ax1.set_ylabel("Amplitude")
        ax1.set_title(f"Waveform, STA/LTA, and MER: {trace.id}\nDistance: {source_sensor_distance} km")
        ax1.legend(loc="upper left")
        ax1.grid()

        # Plot the STA/LTA ratio
        ax2 = ax1.twinx()
        ax2.plot(times[:len(cft)], cft, label="STA/LTA Ratio", color="orange", alpha=0.8)
        ax2.set_ylabel("STA/LTA Ratio")
        ax2.legend(loc="upper right")

        # Add MER values as annotations
        ax1.axhline(mer_2_5, color="green", linestyle="--", label="MER (2s Pre, 5s Post)", alpha=0.8)
        ax1.axhline(mer_5_5, color="red", linestyle="--", label="MER (5s Pre, 5s Post)", alpha=0.8)

        # Show P and S picks on the waveform
        ax1.axvline(p_pick.matplotlib_date, color="red", linestyle="--", label="P-wave Pick")
        ax1.axvline(s_pick.matplotlib_date, color="black", linestyle="--", label="S-wave Pick")

        # Save the plot
        output_file = Path(output_dir) / f"{file_path.stem}_{trace.id}_mer_plot.png"
        plt.savefig(output_file)
        plt.close()
        print(f"MER plot saved to: {output_file}")
# Out:
# Match found: 34161341_2023-02-21T00.07.00.489723Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# MER plot saved to: output_mer_plots\34161341_2023-02-21T00.07.00.489723Z_WS.POZA.S5.DN1_WS.POZA.S5.DN1_mer_plot.png
# No match found for file: 34161341_2023-02-21T00.07.00.489723Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34161341_2023-02-21T00.07.00.489723Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34161341_2023-02-21T00.07.00.490024Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# MER plot saved to: output_mer_plots\34161341_2023-02-21T00.07.00.490024Z_WS.POZA.S3.DN1_WS.POZA.S3.DN1_mer_plot.png
# No match found for file: 34161341_2023-02-21T00.07.00.490024Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34161341_2023-02-21T00.07.00.490024Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34161341_2023-02-21T00.07.00.490032Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# MER plot saved to: output_mer_plots\34161341_2023-02-21T00.07.00.490032Z_WS.POZA.S2.DN1_WS.POZA.S2.DN1_mer_plot.png
# No match found for file: 34161341_2023-02-21T00.07.00.490032Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34161341_2023-02-21T00.07.00.490032Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34161341_2023-02-21T00.07.00.490708Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# MER plot saved to: output_mer_plots\34161341_2023-02-21T00.07.00.490708Z_WS.POZA.S4.DN1_WS.POZA.S4.DN1_mer_plot.png
# No match found for file: 34161341_2023-02-21T00.07.00.490708Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34161341_2023-02-21T00.07.00.490708Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34161341_2023-02-21T00.07.00.493150Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# MER plot saved to: output_mer_plots\34161341_2023-02-21T00.07.00.493150Z_WS.POZA.S6.DN1_WS.POZA.S6.DN1_mer_plot.png
# No match found for file: 34161341_2023-02-21T00.07.00.493150Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34161341_2023-02-21T00.07.00.493150Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34161511_2023-02-21T00.12.34.317723Z_WS.POZA.S5.DN1.MSEED
# Error parsing data for 34161511_2023-02-21T00.12.34.317723Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161511_2023-02-21T00.12.34.317723Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34161511_2023-02-21T00.12.34.317723Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34161511_2023-02-21T00.12.34.318024Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# MER plot saved to: output_mer_plots\34161511_2023-02-21T00.12.34.318024Z_WS.POZA.S3.DN1_WS.POZA.S3.DN1_mer_plot.png
# No match found for file: 34161511_2023-02-21T00.12.34.318024Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34161511_2023-02-21T00.12.34.318024Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34161511_2023-02-21T00.12.34.318032Z_WS.POZA.S2.DN1.MSEED
# Error parsing data for 34161511_2023-02-21T00.12.34.318032Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161511_2023-02-21T00.12.34.318032Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34161511_2023-02-21T00.12.34.318032Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34161511_2023-02-21T00.12.34.318708Z_WS.POZA.S4.DN1.MSEED
# Error parsing data for 34161511_2023-02-21T00.12.34.318708Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161511_2023-02-21T00.12.34.318708Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34161511_2023-02-21T00.12.34.318708Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34161511_2023-02-21T00.12.34.321150Z_WS.POZA.S6.DN1.MSEED
# Error parsing data for 34161511_2023-02-21T00.12.34.321150Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161511_2023-02-21T00.12.34.321150Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34161511_2023-02-21T00.12.34.321150Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34161571_2023-02-21T00.14.39.009723Z_WS.POZA.S5.DN1.MSEED
# Error parsing data for 34161571_2023-02-21T00.14.39.009723Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161571_2023-02-21T00.14.39.009723Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34161571_2023-02-21T00.14.39.009723Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34161571_2023-02-21T00.14.39.010024Z_WS.POZA.S3.DN1.MSEED
# Error parsing data for 34161571_2023-02-21T00.14.39.010024Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161571_2023-02-21T00.14.39.010024Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34161571_2023-02-21T00.14.39.010024Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34161571_2023-02-21T00.14.39.010032Z_WS.POZA.S2.DN1.MSEED
# Error parsing data for 34161571_2023-02-21T00.14.39.010032Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161571_2023-02-21T00.14.39.010032Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34161571_2023-02-21T00.14.39.010032Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34161571_2023-02-21T00.14.39.010708Z_WS.POZA.S4.DN1.MSEED
# Error parsing data for 34161571_2023-02-21T00.14.39.010708Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161571_2023-02-21T00.14.39.010708Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34161571_2023-02-21T00.14.39.010708Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34161571_2023-02-21T00.14.39.013150Z_WS.POZA.S6.DN1.MSEED
# Error parsing data for 34161571_2023-02-21T00.14.39.013150Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161571_2023-02-21T00.14.39.013150Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34161571_2023-02-21T00.14.39.013150Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34161621_2023-02-21T00.18.41.857723Z_WS.POZA.S5.DN1.MSEED
# Error parsing data for 34161621_2023-02-21T00.18.41.857723Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161621_2023-02-21T00.18.41.857723Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34161621_2023-02-21T00.18.41.857723Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34161621_2023-02-21T00.18.41.858024Z_WS.POZA.S3.DN1.MSEED
# Error parsing data for 34161621_2023-02-21T00.18.41.858024Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161621_2023-02-21T00.18.41.858024Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34161621_2023-02-21T00.18.41.858024Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34161621_2023-02-21T00.18.41.858032Z_WS.POZA.S2.DN1.MSEED
# Error parsing data for 34161621_2023-02-21T00.18.41.858032Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161621_2023-02-21T00.18.41.858032Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34161621_2023-02-21T00.18.41.858032Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34161621_2023-02-21T00.18.41.858708Z_WS.POZA.S4.DN1.MSEED
# Error parsing data for 34161621_2023-02-21T00.18.41.858708Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161621_2023-02-21T00.18.41.858708Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34161621_2023-02-21T00.18.41.858708Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34161621_2023-02-21T00.18.41.861150Z_WS.POZA.S6.DN1.MSEED
# Error parsing data for 34161621_2023-02-21T00.18.41.861150Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161621_2023-02-21T00.18.41.861150Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34161621_2023-02-21T00.18.41.861150Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34161791_2023-02-21T00.40.23.069600Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# MER plot saved to: output_mer_plots\34161791_2023-02-21T00.40.23.069600Z_WS.POZA.S5.DN1_WS.POZA.S5.DN1_mer_plot.png
# No match found for file: 34161791_2023-02-21T00.40.23.069600Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34161791_2023-02-21T00.40.23.069600Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34161791_2023-02-21T00.40.23.070024Z_WS.POZA.S3.DN1.MSEED
# Error parsing data for 34161791_2023-02-21T00.40.23.070024Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34161791_2023-02-21T00.40.23.070024Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34161791_2023-02-21T00.40.23.070024Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34161791_2023-02-21T00.40.23.070032Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# MER plot saved to: output_mer_plots\34161791_2023-02-21T00.40.23.070032Z_WS.POZA.S2.DN1_WS.POZA.S2.DN1_mer_plot.png
# No match found for file: 34161791_2023-02-21T00.40.23.070032Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34161791_2023-02-21T00.40.23.070032Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34161791_2023-02-21T00.40.23.070708Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# MER plot saved to: output_mer_plots\34161791_2023-02-21T00.40.23.070708Z_WS.POZA.S4.DN1_WS.POZA.S4.DN1_mer_plot.png
# No match found for file: 34161791_2023-02-21T00.40.23.070708Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34161791_2023-02-21T00.40.23.070708Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34161791_2023-02-21T00.40.23.072380Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# MER plot saved to: output_mer_plots\34161791_2023-02-21T00.40.23.072380Z_WS.POZA.S6.DN1_WS.POZA.S6.DN1_mer_plot.png
# No match found for file: 34161791_2023-02-21T00.40.23.072380Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34161791_2023-02-21T00.40.23.072380Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34162021_2023-02-21T00.56.56.517600Z_WS.POZA.S5.DN1.MSEED
# Error parsing data for 34162021_2023-02-21T00.56.56.517600Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162021_2023-02-21T00.56.56.517600Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34162021_2023-02-21T00.56.56.517600Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34162021_2023-02-21T00.56.56.518032Z_WS.POZA.S2.DN1.MSEED
# Error parsing data for 34162021_2023-02-21T00.56.56.518032Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162021_2023-02-21T00.56.56.518032Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34162021_2023-02-21T00.56.56.518032Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34162021_2023-02-21T00.56.56.519238Z_WS.POZA.S3.DN1.MSEED
# Error parsing data for 34162021_2023-02-21T00.56.56.519238Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162021_2023-02-21T00.56.56.519238Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34162021_2023-02-21T00.56.56.519238Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34162021_2023-02-21T00.56.56.520384Z_WS.POZA.S6.DN1.MSEED
# Error parsing data for 34162021_2023-02-21T00.56.56.520384Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162021_2023-02-21T00.56.56.520384Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34162021_2023-02-21T00.56.56.520384Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34162021_2023-02-21T00.56.56.521079Z_WS.POZA.S4.DN1.MSEED
# Error parsing data for 34162021_2023-02-21T00.56.56.521079Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162021_2023-02-21T00.56.56.521079Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34162021_2023-02-21T00.56.56.521079Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34162111_2023-02-21T01.02.21.829562Z_WS.POZA.S5.DN1.MSEED
# Error parsing data for 34162111_2023-02-21T01.02.21.829562Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162111_2023-02-21T01.02.21.829562Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34162111_2023-02-21T01.02.21.829562Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34162111_2023-02-21T01.02.21.831238Z_WS.POZA.S3.DN1.MSEED
# Error parsing data for 34162111_2023-02-21T01.02.21.831238Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162111_2023-02-21T01.02.21.831238Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34162111_2023-02-21T01.02.21.831238Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34162111_2023-02-21T01.02.21.832384Z_WS.POZA.S6.DN1.MSEED
# Error parsing data for 34162111_2023-02-21T01.02.21.832384Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162111_2023-02-21T01.02.21.832384Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34162111_2023-02-21T01.02.21.832384Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34162111_2023-02-21T01.02.21.832647Z_WS.POZA.S2.DN1.MSEED
# Error parsing data for 34162111_2023-02-21T01.02.21.832647Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162111_2023-02-21T01.02.21.832647Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34162111_2023-02-21T01.02.21.832647Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34162111_2023-02-21T01.02.21.833079Z_WS.POZA.S4.DN1.MSEED
# Error parsing data for 34162111_2023-02-21T01.02.21.833079Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162111_2023-02-21T01.02.21.833079Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34162111_2023-02-21T01.02.21.833079Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34162221_2023-02-21T01.06.56.697562Z_WS.POZA.S5.DN1.MSEED
# Error parsing data for 34162221_2023-02-21T01.06.56.697562Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162221_2023-02-21T01.06.56.697562Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34162221_2023-02-21T01.06.56.697562Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34162221_2023-02-21T01.06.56.698149Z_WS.POZA.S6.DN1.MSEED
# Error parsing data for 34162221_2023-02-21T01.06.56.698149Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162221_2023-02-21T01.06.56.698149Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34162221_2023-02-21T01.06.56.698149Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34162221_2023-02-21T01.06.56.699238Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# MER plot saved to: output_mer_plots\34162221_2023-02-21T01.06.56.699238Z_WS.POZA.S3.DN1_WS.POZA.S3.DN1_mer_plot.png
# No match found for file: 34162221_2023-02-21T01.06.56.699238Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34162221_2023-02-21T01.06.56.699238Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34162221_2023-02-21T01.06.56.700647Z_WS.POZA.S2.DN1.MSEED
# Error parsing data for 34162221_2023-02-21T01.06.56.700647Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162221_2023-02-21T01.06.56.700647Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34162221_2023-02-21T01.06.56.700647Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34162221_2023-02-21T01.06.56.701079Z_WS.POZA.S4.DN1.MSEED
# Error parsing data for 34162221_2023-02-21T01.06.56.701079Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162221_2023-02-21T01.06.56.701079Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34162221_2023-02-21T01.06.56.701079Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34162311_2023-02-21T01.15.19.397562Z_WS.POZA.S5.DN1.MSEED
# Error parsing data for 34162311_2023-02-21T01.15.19.397562Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162311_2023-02-21T01.15.19.397562Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34162311_2023-02-21T01.15.19.397562Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34162311_2023-02-21T01.15.19.398149Z_WS.POZA.S6.DN1.MSEED
# Error parsing data for 34162311_2023-02-21T01.15.19.398149Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162311_2023-02-21T01.15.19.398149Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34162311_2023-02-21T01.15.19.398149Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34162311_2023-02-21T01.15.19.399238Z_WS.POZA.S3.DN1.MSEED
# Error parsing data for 34162311_2023-02-21T01.15.19.399238Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162311_2023-02-21T01.15.19.399238Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34162311_2023-02-21T01.15.19.399238Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34162311_2023-02-21T01.15.19.400647Z_WS.POZA.S2.DN1.MSEED
# Error parsing data for 34162311_2023-02-21T01.15.19.400647Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162311_2023-02-21T01.15.19.400647Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34162311_2023-02-21T01.15.19.400647Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34162311_2023-02-21T01.15.19.401079Z_WS.POZA.S4.DN1.MSEED
# Error parsing data for 34162311_2023-02-21T01.15.19.401079Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162311_2023-02-21T01.15.19.401079Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34162311_2023-02-21T01.15.19.401079Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34162371_2023-02-21T01.31.01.417675Z_WS.POZA.S5.DN1.MSEED
# Error parsing data for 34162371_2023-02-21T01.31.01.417675Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162371_2023-02-21T01.31.01.417675Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34162371_2023-02-21T01.31.01.417675Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34162371_2023-02-21T01.31.01.417936Z_WS.POZA.S6.DN1.MSEED
# Error parsing data for 34162371_2023-02-21T01.31.01.417936Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162371_2023-02-21T01.31.01.417936Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34162371_2023-02-21T01.31.01.417936Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34162371_2023-02-21T01.31.01.419238Z_WS.POZA.S3.DN1.MSEED
# Error parsing data for 34162371_2023-02-21T01.31.01.419238Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162371_2023-02-21T01.31.01.419238Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34162371_2023-02-21T01.31.01.419238Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34162371_2023-02-21T01.31.01.420647Z_WS.POZA.S2.DN1.MSEED
# Error parsing data for 34162371_2023-02-21T01.31.01.420647Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162371_2023-02-21T01.31.01.420647Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34162371_2023-02-21T01.31.01.420647Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34162371_2023-02-21T01.31.01.421079Z_WS.POZA.S4.DN1.MSEED
# Error parsing data for 34162371_2023-02-21T01.31.01.421079Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162371_2023-02-21T01.31.01.421079Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34162371_2023-02-21T01.31.01.421079Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34162431_2023-02-21T01.31.15.097675Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# MER plot saved to: output_mer_plots\34162431_2023-02-21T01.31.15.097675Z_WS.POZA.S5.DN1_WS.POZA.S5.DN1_mer_plot.png
# No match found for file: 34162431_2023-02-21T01.31.15.097675Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34162431_2023-02-21T01.31.15.097675Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34162431_2023-02-21T01.31.15.097936Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# MER plot saved to: output_mer_plots\34162431_2023-02-21T01.31.15.097936Z_WS.POZA.S6.DN1_WS.POZA.S6.DN1_mer_plot.png
# No match found for file: 34162431_2023-02-21T01.31.15.097936Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34162431_2023-02-21T01.31.15.097936Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34162431_2023-02-21T01.31.15.099238Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# MER plot saved to: output_mer_plots\34162431_2023-02-21T01.31.15.099238Z_WS.POZA.S3.DN1_WS.POZA.S3.DN1_mer_plot.png
# No match found for file: 34162431_2023-02-21T01.31.15.099238Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34162431_2023-02-21T01.31.15.099238Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34162431_2023-02-21T01.31.15.100647Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# MER plot saved to: output_mer_plots\34162431_2023-02-21T01.31.15.100647Z_WS.POZA.S2.DN1_WS.POZA.S2.DN1_mer_plot.png
# No match found for file: 34162431_2023-02-21T01.31.15.100647Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34162431_2023-02-21T01.31.15.100647Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34162431_2023-02-21T01.31.15.101079Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# MER plot saved to: output_mer_plots\34162431_2023-02-21T01.31.15.101079Z_WS.POZA.S4.DN1_WS.POZA.S4.DN1_mer_plot.png
# No match found for file: 34162431_2023-02-21T01.31.15.101079Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34162431_2023-02-21T01.31.15.101079Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34162501_2023-02-21T02.02.38.097936Z_WS.POZA.S6.DN1.MSEED
# Error parsing data for 34162501_2023-02-21T02.02.38.097936Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162501_2023-02-21T02.02.38.097936Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34162501_2023-02-21T02.02.38.097936Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34162501_2023-02-21T02.02.38.098562Z_WS.POZA.S2.DN1.MSEED
# Error parsing data for 34162501_2023-02-21T02.02.38.098562Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162501_2023-02-21T02.02.38.098562Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34162501_2023-02-21T02.02.38.098562Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34162501_2023-02-21T02.02.38.098588Z_WS.POZA.S5.DN1.MSEED
# Error parsing data for 34162501_2023-02-21T02.02.38.098588Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162501_2023-02-21T02.02.38.098588Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34162501_2023-02-21T02.02.38.098588Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34162501_2023-02-21T02.02.38.098725Z_WS.POZA.S4.DN1.MSEED
# Error parsing data for 34162501_2023-02-21T02.02.38.098725Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162501_2023-02-21T02.02.38.098725Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34162501_2023-02-21T02.02.38.098725Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34162501_2023-02-21T02.02.38.100243Z_WS.POZA.S3.DN1.MSEED
# Error parsing data for 34162501_2023-02-21T02.02.38.100243Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162501_2023-02-21T02.02.38.100243Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34162501_2023-02-21T02.02.38.100243Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34162511_2023-02-21T02.06.02.977755Z_WS.POZA.S6.DN1.MSEED
# Error parsing data for 34162511_2023-02-21T02.06.02.977755Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162511_2023-02-21T02.06.02.977755Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34162511_2023-02-21T02.06.02.977755Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34162511_2023-02-21T02.06.02.978562Z_WS.POZA.S2.DN1.MSEED
# Error parsing data for 34162511_2023-02-21T02.06.02.978562Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162511_2023-02-21T02.06.02.978562Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34162511_2023-02-21T02.06.02.978562Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34162511_2023-02-21T02.06.02.978588Z_WS.POZA.S5.DN1.MSEED
# Error parsing data for 34162511_2023-02-21T02.06.02.978588Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162511_2023-02-21T02.06.02.978588Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34162511_2023-02-21T02.06.02.978588Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34162511_2023-02-21T02.06.02.978725Z_WS.POZA.S4.DN1.MSEED
# Error parsing data for 34162511_2023-02-21T02.06.02.978725Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162511_2023-02-21T02.06.02.978725Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34162511_2023-02-21T02.06.02.978725Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34162511_2023-02-21T02.06.02.980243Z_WS.POZA.S3.DN1.MSEED
# Error parsing data for 34162511_2023-02-21T02.06.02.980243Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162511_2023-02-21T02.06.02.980243Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34162511_2023-02-21T02.06.02.980243Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34162741_2023-02-21T02.39.54.850587Z_WS.POZA.S5.DN1.MSEED
# Error parsing data for 34162741_2023-02-21T02.39.54.850587Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162741_2023-02-21T02.39.54.850587Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34162741_2023-02-21T02.39.54.850587Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34162741_2023-02-21T02.39.54.850647Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# MER plot saved to: output_mer_plots\34162741_2023-02-21T02.39.54.850647Z_WS.POZA.S4.DN1_WS.POZA.S4.DN1_mer_plot.png
# No match found for file: 34162741_2023-02-21T02.39.54.850647Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34162741_2023-02-21T02.39.54.850647Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34162741_2023-02-21T02.39.54.850725Z_WS.POZA.S2.DN1.MSEED
# Error parsing data for 34162741_2023-02-21T02.39.54.850725Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162741_2023-02-21T02.39.54.850725Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34162741_2023-02-21T02.39.54.850725Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34162741_2023-02-21T02.39.54.852047Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# MER plot saved to: output_mer_plots\34162741_2023-02-21T02.39.54.852047Z_WS.POZA.S3.DN1_WS.POZA.S3.DN1_mer_plot.png
# No match found for file: 34162741_2023-02-21T02.39.54.852047Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34162741_2023-02-21T02.39.54.852047Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34162741_2023-02-21T02.39.54.853537Z_WS.POZA.S6.DN1.MSEED
# Error parsing data for 34162741_2023-02-21T02.39.54.853537Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34162741_2023-02-21T02.39.54.853537Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34162741_2023-02-21T02.39.54.853537Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34163011_2023-02-21T03.32.30.490319Z_WS.POZA.S3.DN1.MSEED
# Error parsing data for 34163011_2023-02-21T03.32.30.490319Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34163011_2023-02-21T03.32.30.490319Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34163011_2023-02-21T03.32.30.490319Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34163011_2023-02-21T03.32.30.492143Z_WS.POZA.S5.DN1.MSEED
# Error parsing data for 34163011_2023-02-21T03.32.30.492143Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34163011_2023-02-21T03.32.30.492143Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34163011_2023-02-21T03.32.30.492143Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34163011_2023-02-21T03.32.30.492276Z_WS.POZA.S4.DN1.MSEED
# Error parsing data for 34163011_2023-02-21T03.32.30.492276Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34163011_2023-02-21T03.32.30.492276Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34163011_2023-02-21T03.32.30.492276Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34163011_2023-02-21T03.32.30.492397Z_WS.POZA.S2.DN1.MSEED
# Error parsing data for 34163011_2023-02-21T03.32.30.492397Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34163011_2023-02-21T03.32.30.492397Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34163011_2023-02-21T03.32.30.492397Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34163011_2023-02-21T03.32.30.493482Z_WS.POZA.S6.DN1.MSEED
# Error parsing data for 34163011_2023-02-21T03.32.30.493482Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34163011_2023-02-21T03.32.30.493482Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34163011_2023-02-21T03.32.30.493482Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34163051_2023-02-21T03.41.55.050319Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# MER plot saved to: output_mer_plots\34163051_2023-02-21T03.41.55.050319Z_WS.POZA.S3.DN1_WS.POZA.S3.DN1_mer_plot.png
# No match found for file: 34163051_2023-02-21T03.41.55.050319Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34163051_2023-02-21T03.41.55.050319Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34163051_2023-02-21T03.41.55.052143Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# MER plot saved to: output_mer_plots\34163051_2023-02-21T03.41.55.052143Z_WS.POZA.S5.DN1_WS.POZA.S5.DN1_mer_plot.png
# No match found for file: 34163051_2023-02-21T03.41.55.052143Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34163051_2023-02-21T03.41.55.052143Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34163051_2023-02-21T03.41.55.052276Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# MER plot saved to: output_mer_plots\34163051_2023-02-21T03.41.55.052276Z_WS.POZA.S4.DN1_WS.POZA.S4.DN1_mer_plot.png
# No match found for file: 34163051_2023-02-21T03.41.55.052276Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34163051_2023-02-21T03.41.55.052276Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34163051_2023-02-21T03.41.55.052397Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# MER plot saved to: output_mer_plots\34163051_2023-02-21T03.41.55.052397Z_WS.POZA.S2.DN1_WS.POZA.S2.DN1_mer_plot.png
# No match found for file: 34163051_2023-02-21T03.41.55.052397Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34163051_2023-02-21T03.41.55.052397Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34163051_2023-02-21T03.41.55.053482Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# MER plot saved to: output_mer_plots\34163051_2023-02-21T03.41.55.053482Z_WS.POZA.S6.DN1_WS.POZA.S6.DN1_mer_plot.png
# No match found for file: 34163051_2023-02-21T03.41.55.053482Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34163051_2023-02-21T03.41.55.053482Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34163411_2023-02-21T04.49.09.159092Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# MER plot saved to: output_mer_plots\34163411_2023-02-21T04.49.09.159092Z_WS.POZA.S4.DN1_WS.POZA.S4.DN1_mer_plot.png
# No match found for file: 34163411_2023-02-21T04.49.09.159092Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34163411_2023-02-21T04.49.09.159092Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34163411_2023-02-21T04.49.09.159201Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# MER plot saved to: output_mer_plots\34163411_2023-02-21T04.49.09.159201Z_WS.POZA.S5.DN1_WS.POZA.S5.DN1_mer_plot.png
# No match found for file: 34163411_2023-02-21T04.49.09.159201Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34163411_2023-02-21T04.49.09.159201Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34163411_2023-02-21T04.49.09.160249Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# MER plot saved to: output_mer_plots\34163411_2023-02-21T04.49.09.160249Z_WS.POZA.S6.DN1_WS.POZA.S6.DN1_mer_plot.png
# No match found for file: 34163411_2023-02-21T04.49.09.160249Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34163411_2023-02-21T04.49.09.160249Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34163411_2023-02-21T04.49.09.161007Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# MER plot saved to: output_mer_plots\34163411_2023-02-21T04.49.09.161007Z_WS.POZA.S3.DN1_WS.POZA.S3.DN1_mer_plot.png
# No match found for file: 34163411_2023-02-21T04.49.09.161007Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34163411_2023-02-21T04.49.09.161007Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34163411_2023-02-21T04.49.09.161225Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# MER plot saved to: output_mer_plots\34163411_2023-02-21T04.49.09.161225Z_WS.POZA.S2.DN1_WS.POZA.S2.DN1_mer_plot.png
# No match found for file: 34163411_2023-02-21T04.49.09.161225Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34163411_2023-02-21T04.49.09.161225Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34163481_2023-02-21T05.15.35.189899Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# MER plot saved to: output_mer_plots\34163481_2023-02-21T05.15.35.189899Z_WS.POZA.S4.DN1_WS.POZA.S4.DN1_mer_plot.png
# No match found for file: 34163481_2023-02-21T05.15.35.189899Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34163481_2023-02-21T05.15.35.189899Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34163481_2023-02-21T05.15.35.190426Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# MER plot saved to: output_mer_plots\34163481_2023-02-21T05.15.35.190426Z_WS.POZA.S6.DN1_WS.POZA.S6.DN1_mer_plot.png
# No match found for file: 34163481_2023-02-21T05.15.35.190426Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34163481_2023-02-21T05.15.35.190426Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34163481_2023-02-21T05.15.35.191097Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# MER plot saved to: output_mer_plots\34163481_2023-02-21T05.15.35.191097Z_WS.POZA.S2.DN1_WS.POZA.S2.DN1_mer_plot.png
# No match found for file: 34163481_2023-02-21T05.15.35.191097Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34163481_2023-02-21T05.15.35.191097Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34163481_2023-02-21T05.15.35.191190Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# MER plot saved to: output_mer_plots\34163481_2023-02-21T05.15.35.191190Z_WS.POZA.S5.DN1_WS.POZA.S5.DN1_mer_plot.png
# No match found for file: 34163481_2023-02-21T05.15.35.191190Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34163481_2023-02-21T05.15.35.191190Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34163481_2023-02-21T05.15.35.193431Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# MER plot saved to: output_mer_plots\34163481_2023-02-21T05.15.35.193431Z_WS.POZA.S3.DN1_WS.POZA.S3.DN1_mer_plot.png
# No match found for file: 34163481_2023-02-21T05.15.35.193431Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34163481_2023-02-21T05.15.35.193431Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34163561_2023-02-21T05.33.59.897899Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# MER plot saved to: output_mer_plots\34163561_2023-02-21T05.33.59.897899Z_WS.POZA.S4.DN1_WS.POZA.S4.DN1_mer_plot.png
# No match found for file: 34163561_2023-02-21T05.33.59.897899Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34163561_2023-02-21T05.33.59.897899Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34163561_2023-02-21T05.33.59.898424Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# MER plot saved to: output_mer_plots\34163561_2023-02-21T05.33.59.898424Z_WS.POZA.S6.DN1_WS.POZA.S6.DN1_mer_plot.png
# No match found for file: 34163561_2023-02-21T05.33.59.898424Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34163561_2023-02-21T05.33.59.898424Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34163561_2023-02-21T05.33.59.899097Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# MER plot saved to: output_mer_plots\34163561_2023-02-21T05.33.59.899097Z_WS.POZA.S2.DN1_WS.POZA.S2.DN1_mer_plot.png
# No match found for file: 34163561_2023-02-21T05.33.59.899097Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34163561_2023-02-21T05.33.59.899097Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34163561_2023-02-21T05.33.59.899190Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# MER plot saved to: output_mer_plots\34163561_2023-02-21T05.33.59.899190Z_WS.POZA.S5.DN1_WS.POZA.S5.DN1_mer_plot.png
# No match found for file: 34163561_2023-02-21T05.33.59.899190Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34163561_2023-02-21T05.33.59.899190Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34163561_2023-02-21T05.33.59.901431Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# MER plot saved to: output_mer_plots\34163561_2023-02-21T05.33.59.901431Z_WS.POZA.S3.DN1_WS.POZA.S3.DN1_mer_plot.png
# No match found for file: 34163561_2023-02-21T05.33.59.901431Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34163561_2023-02-21T05.33.59.901431Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34163931_2023-02-21T06.38.57.057885Z_WS.POZA.S6.DN1.MSEED
# Error parsing data for 34163931_2023-02-21T06.38.57.057885Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34163931_2023-02-21T06.38.57.057885Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34163931_2023-02-21T06.38.57.057885Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34163931_2023-02-21T06.38.57.058077Z_WS.POZA.S3.DN1.MSEED
# Error parsing data for 34163931_2023-02-21T06.38.57.058077Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34163931_2023-02-21T06.38.57.058077Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34163931_2023-02-21T06.38.57.058077Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34163931_2023-02-21T06.38.57.058640Z_WS.POZA.S2.DN1.MSEED
# Error parsing data for 34163931_2023-02-21T06.38.57.058640Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34163931_2023-02-21T06.38.57.058640Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34163931_2023-02-21T06.38.57.058640Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34163931_2023-02-21T06.38.57.059081Z_WS.POZA.S5.DN1.MSEED
# Error parsing data for 34163931_2023-02-21T06.38.57.059081Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34163931_2023-02-21T06.38.57.059081Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34163931_2023-02-21T06.38.57.059081Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34163931_2023-02-21T06.38.57.059276Z_WS.POZA.S4.DN1.MSEED
# Error parsing data for 34163931_2023-02-21T06.38.57.059276Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34163931_2023-02-21T06.38.57.059276Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34163931_2023-02-21T06.38.57.059276Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34164401_2023-02-21T07.13.34.330804Z_WS.POZA.S4.DN1.MSEED
# Error parsing data for 34164401_2023-02-21T07.13.34.330804Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34164401_2023-02-21T07.13.34.330804Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34164401_2023-02-21T07.13.34.330804Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34164401_2023-02-21T07.13.34.331170Z_WS.POZA.S5.DN1.MSEED
# Error parsing data for 34164401_2023-02-21T07.13.34.331170Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34164401_2023-02-21T07.13.34.331170Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34164401_2023-02-21T07.13.34.331170Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34164401_2023-02-21T07.13.34.331365Z_WS.POZA.S2.DN1.MSEED
# Error parsing data for 34164401_2023-02-21T07.13.34.331365Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34164401_2023-02-21T07.13.34.331365Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34164401_2023-02-21T07.13.34.331365Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34164401_2023-02-21T07.13.34.332303Z_WS.POZA.S6.DN1.MSEED
# Error parsing data for 34164401_2023-02-21T07.13.34.332303Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34164401_2023-02-21T07.13.34.332303Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34164401_2023-02-21T07.13.34.332303Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34164401_2023-02-21T07.13.34.333420Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# MER plot saved to: output_mer_plots\34164401_2023-02-21T07.13.34.333420Z_WS.POZA.S3.DN1_WS.POZA.S3.DN1_mer_plot.png
# No match found for file: 34164401_2023-02-21T07.13.34.333420Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34164401_2023-02-21T07.13.34.333420Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34164891_2023-02-21T08.19.39.829964Z_WS.POZA.S6.DN1.MSEED
# Error parsing data for 34164891_2023-02-21T08.19.39.829964Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34164891_2023-02-21T08.19.39.829964Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34164891_2023-02-21T08.19.39.829964Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34164891_2023-02-21T08.19.39.830367Z_WS.POZA.S3.DN1.MSEED
# Error parsing data for 34164891_2023-02-21T08.19.39.830367Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34164891_2023-02-21T08.19.39.830367Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34164891_2023-02-21T08.19.39.830367Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34164891_2023-02-21T08.19.39.830757Z_WS.POZA.S2.DN1.MSEED
# Error parsing data for 34164891_2023-02-21T08.19.39.830757Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34164891_2023-02-21T08.19.39.830757Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34164891_2023-02-21T08.19.39.830757Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34164891_2023-02-21T08.19.39.831473Z_WS.POZA.S5.DN1.MSEED
# Error parsing data for 34164891_2023-02-21T08.19.39.831473Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34164891_2023-02-21T08.19.39.831473Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34164891_2023-02-21T08.19.39.831473Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34164891_2023-02-21T08.19.39.832827Z_WS.POZA.S4.DN1.MSEED
# Error parsing data for 34164891_2023-02-21T08.19.39.832827Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34164891_2023-02-21T08.19.39.832827Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34164891_2023-02-21T08.19.39.832827Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34165791_2023-02-21T10.36.27.750661Z_WS.POZA.S6.DN1.MSEED
# Error parsing data for 34165791_2023-02-21T10.36.27.750661Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34165791_2023-02-21T10.36.27.750661Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34165791_2023-02-21T10.36.27.750661Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34165791_2023-02-21T10.36.27.751693Z_WS.POZA.S4.DN1.MSEED
# Error parsing data for 34165791_2023-02-21T10.36.27.751693Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34165791_2023-02-21T10.36.27.751693Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34165791_2023-02-21T10.36.27.751693Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34165791_2023-02-21T10.36.27.751736Z_WS.POZA.S3.DN1.MSEED
# Error parsing data for 34165791_2023-02-21T10.36.27.751736Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34165791_2023-02-21T10.36.27.751736Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34165791_2023-02-21T10.36.27.751736Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34165791_2023-02-21T10.36.27.751945Z_WS.POZA.S5.DN1.MSEED
# Error parsing data for 34165791_2023-02-21T10.36.27.751945Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34165791_2023-02-21T10.36.27.751945Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34165791_2023-02-21T10.36.27.751945Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34165791_2023-02-21T10.36.27.752007Z_WS.POZA.S2.DN1.MSEED
# Error parsing data for 34165791_2023-02-21T10.36.27.752007Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34165791_2023-02-21T10.36.27.752007Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34165791_2023-02-21T10.36.27.752007Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34166831_2023-02-21T12.48.34.238879Z_WS.POZA.S3.DN1.MSEED
# Error parsing data for 34166831_2023-02-21T12.48.34.238879Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34166831_2023-02-21T12.48.34.238879Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34166831_2023-02-21T12.48.34.238879Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34166831_2023-02-21T12.48.34.239476Z_WS.POZA.S6.DN1.MSEED
# Error parsing data for 34166831_2023-02-21T12.48.34.239476Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34166831_2023-02-21T12.48.34.239476Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34166831_2023-02-21T12.48.34.239476Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34166831_2023-02-21T12.48.34.239517Z_WS.POZA.S2.DN1.MSEED
# Error parsing data for 34166831_2023-02-21T12.48.34.239517Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34166831_2023-02-21T12.48.34.239517Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34166831_2023-02-21T12.48.34.239517Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34166831_2023-02-21T12.48.34.239983Z_WS.POZA.S5.DN1.MSEED
# Error parsing data for 34166831_2023-02-21T12.48.34.239983Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34166831_2023-02-21T12.48.34.239983Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34166831_2023-02-21T12.48.34.239983Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34166831_2023-02-21T12.48.34.240879Z_WS.POZA.S4.DN1.MSEED
# Error parsing data for 34166831_2023-02-21T12.48.34.240879Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34166831_2023-02-21T12.48.34.240879Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34166831_2023-02-21T12.48.34.240879Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34167831_2023-02-21T15.08.01.278424Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# MER plot saved to: output_mer_plots\34167831_2023-02-21T15.08.01.278424Z_WS.POZA.S6.DN1_WS.POZA.S6.DN1_mer_plot.png
# No match found for file: 34167831_2023-02-21T15.08.01.278424Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34167831_2023-02-21T15.08.01.278424Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34167831_2023-02-21T15.08.01.279429Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# MER plot saved to: output_mer_plots\34167831_2023-02-21T15.08.01.279429Z_WS.POZA.S3.DN1_WS.POZA.S3.DN1_mer_plot.png
# No match found for file: 34167831_2023-02-21T15.08.01.279429Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34167831_2023-02-21T15.08.01.279429Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34167831_2023-02-21T15.08.01.279469Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# MER plot saved to: output_mer_plots\34167831_2023-02-21T15.08.01.279469Z_WS.POZA.S4.DN1_WS.POZA.S4.DN1_mer_plot.png
# No match found for file: 34167831_2023-02-21T15.08.01.279469Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34167831_2023-02-21T15.08.01.279469Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34167831_2023-02-21T15.08.01.279496Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# MER plot saved to: output_mer_plots\34167831_2023-02-21T15.08.01.279496Z_WS.POZA.S5.DN1_WS.POZA.S5.DN1_mer_plot.png
# No match found for file: 34167831_2023-02-21T15.08.01.279496Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34167831_2023-02-21T15.08.01.279496Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34167831_2023-02-21T15.08.01.281277Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# MER plot saved to: output_mer_plots\34167831_2023-02-21T15.08.01.281277Z_WS.POZA.S2.DN1_WS.POZA.S2.DN1_mer_plot.png
# No match found for file: 34167831_2023-02-21T15.08.01.281277Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34167831_2023-02-21T15.08.01.281277Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34168011_2023-02-21T15.48.46.238372Z_WS.POZA.S6.DN1.MSEED
# Error parsing data for 34168011_2023-02-21T15.48.46.238372Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34168011_2023-02-21T15.48.46.238372Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34168011_2023-02-21T15.48.46.238372Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34168011_2023-02-21T15.48.46.239421Z_WS.POZA.S4.DN1.MSEED
# Error parsing data for 34168011_2023-02-21T15.48.46.239421Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34168011_2023-02-21T15.48.46.239421Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34168011_2023-02-21T15.48.46.239421Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34168011_2023-02-21T15.48.46.239429Z_WS.POZA.S3.DN1.MSEED
# Error parsing data for 34168011_2023-02-21T15.48.46.239429Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34168011_2023-02-21T15.48.46.239429Z_WS.POZA.S3.DN2.MSEED
# ...
# No match found for file: 34491411_2023-03-28T03.31.54.130204Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34547561_2023-04-02T22.57.18.570053Z_WS.POZA.S5.DN1.MSEED
# Error parsing data for 34547561_2023-04-02T22.57.18.570053Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34547561_2023-04-02T22.57.18.570053Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34547561_2023-04-02T22.57.18.570053Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34547561_2023-04-02T22.57.18.573150Z_WS.POZA.S6.DN1.MSEED
# Error parsing data for 34547561_2023-04-02T22.57.18.573150Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34547561_2023-04-02T22.57.18.573150Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34547561_2023-04-02T22.57.18.573150Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34547561_2023-04-02T22.57.18.573506Z_WS.POZA.S2.DN1.MSEED
# Error parsing data for 34547561_2023-04-02T22.57.18.573506Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34547561_2023-04-02T22.57.18.573506Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34547561_2023-04-02T22.57.18.573506Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34547561_2023-04-02T22.57.18.573604Z_WS.POZA.S3.DN1.MSEED
# Error parsing data for 34547561_2023-04-02T22.57.18.573604Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34547561_2023-04-02T22.57.18.573604Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34547561_2023-04-02T22.57.18.573604Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34547641_2023-04-02T22.57.32.438053Z_WS.POZA.S5.DN1.MSEED
# Error parsing data for 34547641_2023-04-02T22.57.32.438053Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34547641_2023-04-02T22.57.32.438053Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34547641_2023-04-02T22.57.32.438053Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34547641_2023-04-02T22.57.32.441150Z_WS.POZA.S6.DN1.MSEED
# Error parsing data for 34547641_2023-04-02T22.57.32.441150Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34547641_2023-04-02T22.57.32.441150Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34547641_2023-04-02T22.57.32.441150Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34547641_2023-04-02T22.57.32.441506Z_WS.POZA.S2.DN1.MSEED
# Error parsing data for 34547641_2023-04-02T22.57.32.441506Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34547641_2023-04-02T22.57.32.441506Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34547641_2023-04-02T22.57.32.441506Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34547641_2023-04-02T22.57.32.441604Z_WS.POZA.S3.DN1.MSEED
# Error parsing data for 34547641_2023-04-02T22.57.32.441604Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34547641_2023-04-02T22.57.32.441604Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34547641_2023-04-02T22.57.32.441604Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34674981_2023-04-13T23.18.18.486965Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# MER plot saved to: output_mer_plots\34674981_2023-04-13T23.18.18.486965Z_WS.POZA.S3.DN1_WS.POZA.S3.DN1_mer_plot.png
# No match found for file: 34674981_2023-04-13T23.18.18.486965Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34674981_2023-04-13T23.18.18.486965Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34674981_2023-04-13T23.18.18.487000Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# MER plot saved to: output_mer_plots\34674981_2023-04-13T23.18.18.487000Z_WS.POZA.S4.DN1_WS.POZA.S4.DN1_mer_plot.png
# No match found for file: 34674981_2023-04-13T23.18.18.487000Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34674981_2023-04-13T23.18.18.487000Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34674981_2023-04-13T23.18.18.489840Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# MER plot saved to: output_mer_plots\34674981_2023-04-13T23.18.18.489840Z_WS.POZA.S2.DN1_WS.POZA.S2.DN1_mer_plot.png
# No match found for file: 34674981_2023-04-13T23.18.18.489840Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34674981_2023-04-13T23.18.18.489840Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34674981_2023-04-13T23.18.18.489861Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# MER plot saved to: output_mer_plots\34674981_2023-04-13T23.18.18.489861Z_WS.POZA.S5.DN1_WS.POZA.S5.DN1_mer_plot.png
# No match found for file: 34674981_2023-04-13T23.18.18.489861Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34674981_2023-04-13T23.18.18.489861Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34674981_2023-04-13T23.18.18.490349Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# MER plot saved to: output_mer_plots\34674981_2023-04-13T23.18.18.490349Z_WS.POZA.S6.DN1_WS.POZA.S6.DN1_mer_plot.png
# No match found for file: 34674981_2023-04-13T23.18.18.490349Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34674981_2023-04-13T23.18.18.490349Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34692381_2023-04-15T13.17.55.539433Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# MER plot saved to: output_mer_plots\34692381_2023-04-15T13.17.55.539433Z_WS.POZA.S6.DN1_WS.POZA.S6.DN1_mer_plot.png
# No match found for file: 34692381_2023-04-15T13.17.55.539433Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34692381_2023-04-15T13.17.55.539433Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34692381_2023-04-15T13.17.55.539436Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# MER plot saved to: output_mer_plots\34692381_2023-04-15T13.17.55.539436Z_WS.POZA.S5.DN1_WS.POZA.S5.DN1_mer_plot.png
# No match found for file: 34692381_2023-04-15T13.17.55.539436Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34692381_2023-04-15T13.17.55.539436Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34692381_2023-04-15T13.17.55.540100Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# MER plot saved to: output_mer_plots\34692381_2023-04-15T13.17.55.540100Z_WS.POZA.S4.DN1_WS.POZA.S4.DN1_mer_plot.png
# No match found for file: 34692381_2023-04-15T13.17.55.540100Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34692381_2023-04-15T13.17.55.540100Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34692381_2023-04-15T13.17.55.541619Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# MER plot saved to: output_mer_plots\34692381_2023-04-15T13.17.55.541619Z_WS.POZA.S2.DN1_WS.POZA.S2.DN1_mer_plot.png
# No match found for file: 34692381_2023-04-15T13.17.55.541619Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34692381_2023-04-15T13.17.55.541619Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34692381_2023-04-15T13.17.55.542715Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# MER plot saved to: output_mer_plots\34692381_2023-04-15T13.17.55.542715Z_WS.POZA.S3.DN1_WS.POZA.S3.DN1_mer_plot.png
# No match found for file: 34692381_2023-04-15T13.17.55.542715Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34692381_2023-04-15T13.17.55.542715Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34821541_2023-04-27T12.08.16.710163Z_WS.POZA.S4.DN1.MSEED
# Error parsing data for 34821541_2023-04-27T12.08.16.710163Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34821541_2023-04-27T12.08.16.710163Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34821541_2023-04-27T12.08.16.710163Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34821541_2023-04-27T12.08.16.710305Z_WS.POZA.S3.DN1.MSEED
# Error parsing data for 34821541_2023-04-27T12.08.16.710305Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34821541_2023-04-27T12.08.16.710305Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34821541_2023-04-27T12.08.16.710305Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34821541_2023-04-27T12.08.16.711033Z_WS.POZA.S6.DN1.MSEED
# Error parsing data for 34821541_2023-04-27T12.08.16.711033Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34821541_2023-04-27T12.08.16.711033Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34821541_2023-04-27T12.08.16.711033Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34821541_2023-04-27T12.08.16.712359Z_WS.POZA.S5.DN1.MSEED
# Error parsing data for 34821541_2023-04-27T12.08.16.712359Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34821541_2023-04-27T12.08.16.712359Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34821541_2023-04-27T12.08.16.712359Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34821541_2023-04-27T12.08.16.712806Z_WS.POZA.S2.DN1.MSEED
# Error parsing data for 34821541_2023-04-27T12.08.16.712806Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34821541_2023-04-27T12.08.16.712806Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34821541_2023-04-27T12.08.16.712806Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34836221_2023-04-28T20.50.39.467773Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# MER plot saved to: output_mer_plots\34836221_2023-04-28T20.50.39.467773Z_WS.POZA.S4.DN1_WS.POZA.S4.DN1_mer_plot.png
# No match found for file: 34836221_2023-04-28T20.50.39.467773Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 34836221_2023-04-28T20.50.39.467773Z_WS.POZA.S4.DNZ.MSEED
# Match found: 34836221_2023-04-28T20.50.39.468678Z_WS.POZA.S6.DN1.MSEED
# Error parsing data for 34836221_2023-04-28T20.50.39.468678Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34836221_2023-04-28T20.50.39.468678Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34836221_2023-04-28T20.50.39.468678Z_WS.POZA.S6.DNZ.MSEED
# Match found: 34836221_2023-04-28T20.50.39.470042Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# MER plot saved to: output_mer_plots\34836221_2023-04-28T20.50.39.470042Z_WS.POZA.S5.DN1_WS.POZA.S5.DN1_mer_plot.png
# No match found for file: 34836221_2023-04-28T20.50.39.470042Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34836221_2023-04-28T20.50.39.470042Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34836221_2023-04-28T20.50.39.470238Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# MER plot saved to: output_mer_plots\34836221_2023-04-28T20.50.39.470238Z_WS.POZA.S3.DN1_WS.POZA.S3.DN1_mer_plot.png
# No match found for file: 34836221_2023-04-28T20.50.39.470238Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34836221_2023-04-28T20.50.39.470238Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34836221_2023-04-28T20.50.39.470291Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# MER plot saved to: output_mer_plots\34836221_2023-04-28T20.50.39.470291Z_WS.POZA.S2.DN1_WS.POZA.S2.DN1_mer_plot.png
# No match found for file: 34836221_2023-04-28T20.50.39.470291Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34836221_2023-04-28T20.50.39.470291Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34956701_2023-05-11T23.41.38.889527Z_WS.POZA.S5.DN1.MSEED
# Error parsing data for 34956701_2023-05-11T23.41.38.889527Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34956701_2023-05-11T23.41.38.889527Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 34956701_2023-05-11T23.41.38.889527Z_WS.POZA.S5.DNZ.MSEED
# Match found: 34956701_2023-05-11T23.41.38.889759Z_WS.POZA.S2.DN1.MSEED
# Error parsing data for 34956701_2023-05-11T23.41.38.889759Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34956701_2023-05-11T23.41.38.889759Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 34956701_2023-05-11T23.41.38.889759Z_WS.POZA.S2.DNZ.MSEED
# Match found: 34956701_2023-05-11T23.41.38.891323Z_WS.POZA.S3.DN1.MSEED
# Error parsing data for 34956701_2023-05-11T23.41.38.891323Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34956701_2023-05-11T23.41.38.891323Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 34956701_2023-05-11T23.41.38.891323Z_WS.POZA.S3.DNZ.MSEED
# Match found: 34956701_2023-05-11T23.41.38.892111Z_WS.POZA.S6.DN1.MSEED
# Error parsing data for 34956701_2023-05-11T23.41.38.892111Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 34956701_2023-05-11T23.41.38.892111Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 34956701_2023-05-11T23.41.38.892111Z_WS.POZA.S6.DNZ.MSEED
# Match found: 35266701_2023-06-09T22.34.36.208297Z_WS.POZA.S3.DN1.MSEED
# Error parsing data for 35266701_2023-06-09T22.34.36.208297Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 35266701_2023-06-09T22.34.36.208297Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 35266701_2023-06-09T22.34.36.208297Z_WS.POZA.S3.DNZ.MSEED
# Match found: 35266701_2023-06-09T22.34.36.210008Z_WS.POZA.S6.DN1.MSEED
# Error parsing data for 35266701_2023-06-09T22.34.36.210008Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 35266701_2023-06-09T22.34.36.210008Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 35266701_2023-06-09T22.34.36.210008Z_WS.POZA.S6.DNZ.MSEED
# Match found: 35266701_2023-06-09T22.34.36.210130Z_WS.POZA.S5.DN1.MSEED
# Error parsing data for 35266701_2023-06-09T22.34.36.210130Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 35266701_2023-06-09T22.34.36.210130Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 35266701_2023-06-09T22.34.36.210130Z_WS.POZA.S5.DNZ.MSEED
# Match found: 35266701_2023-06-09T22.34.36.211277Z_WS.POZA.S4.DN1.MSEED
# Error parsing data for 35266701_2023-06-09T22.34.36.211277Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 35266701_2023-06-09T22.34.36.211277Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 35266701_2023-06-09T22.34.36.211277Z_WS.POZA.S4.DNZ.MSEED
# Match found: 35266701_2023-06-09T22.34.36.212005Z_WS.POZA.S2.DN1.MSEED
# Error parsing data for 35266701_2023-06-09T22.34.36.212005Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
# No match found for file: 35266701_2023-06-09T22.34.36.212005Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 35266701_2023-06-09T22.34.36.212005Z_WS.POZA.S2.DNZ.MSEED
# Match found: 35419441_2023-06-30T04.10.40.107451Z_WS.POZA.S5.DN1.MSEED
# Processing trace: WS.POZA.S5.DN1
# MER plot saved to: output_mer_plots\35419441_2023-06-30T04.10.40.107451Z_WS.POZA.S5.DN1_WS.POZA.S5.DN1_mer_plot.png
# No match found for file: 35419441_2023-06-30T04.10.40.107451Z_WS.POZA.S5.DN2.MSEED
# No match found for file: 35419441_2023-06-30T04.10.40.107451Z_WS.POZA.S5.DNZ.MSEED
# Match found: 35419441_2023-06-30T04.10.40.107601Z_WS.POZA.S2.DN1.MSEED
# Processing trace: WS.POZA.S2.DN1
# MER plot saved to: output_mer_plots\35419441_2023-06-30T04.10.40.107601Z_WS.POZA.S2.DN1_WS.POZA.S2.DN1_mer_plot.png
# No match found for file: 35419441_2023-06-30T04.10.40.107601Z_WS.POZA.S2.DN2.MSEED
# No match found for file: 35419441_2023-06-30T04.10.40.107601Z_WS.POZA.S2.DNZ.MSEED
# Match found: 35419441_2023-06-30T04.10.40.108520Z_WS.POZA.S6.DN1.MSEED
# Processing trace: WS.POZA.S6.DN1
# MER plot saved to: output_mer_plots\35419441_2023-06-30T04.10.40.108520Z_WS.POZA.S6.DN1_WS.POZA.S6.DN1_mer_plot.png
# No match found for file: 35419441_2023-06-30T04.10.40.108520Z_WS.POZA.S6.DN2.MSEED
# No match found for file: 35419441_2023-06-30T04.10.40.108520Z_WS.POZA.S6.DNZ.MSEED
# Match found: 35419441_2023-06-30T04.10.40.108841Z_WS.POZA.S3.DN1.MSEED
# Processing trace: WS.POZA.S3.DN1
# MER plot saved to: output_mer_plots\35419441_2023-06-30T04.10.40.108841Z_WS.POZA.S3.DN1_WS.POZA.S3.DN1_mer_plot.png
# No match found for file: 35419441_2023-06-30T04.10.40.108841Z_WS.POZA.S3.DN2.MSEED
# No match found for file: 35419441_2023-06-30T04.10.40.108841Z_WS.POZA.S3.DNZ.MSEED
# Match found: 35419441_2023-06-30T04.10.40.109398Z_WS.POZA.S4.DN1.MSEED
# Processing trace: WS.POZA.S4.DN1
# MER plot saved to: output_mer_plots\35419441_2023-06-30T04.10.40.109398Z_WS.POZA.S4.DN1_WS.POZA.S4.DN1_mer_plot.png
# No match found for file: 35419441_2023-06-30T04.10.40.109398Z_WS.POZA.S4.DN2.MSEED
# No match found for file: 35419441_2023-06-30T04.10.40.109398Z_WS.POZA.S4.DNZ.MSEED

# %%
#code for the checking of wheather the plot was matc hing or not 




from obspy import read
from obspy import UTCDateTime
from obspy.signal.trigger import classic_sta_lta
import pandas as pd
from pathlib import Path
import os
import numpy as np

# Load the pick data
pick_data = pd.read_csv(
    "dataset_earthquakes/metadata.csv",
    usecols=['trace_name_original_1', 'trace_p_pick_time', 'trace_s_pick_time', 'source_sensor_distance']
)

# Function to sanitize file names
def sanitize_filename(name):
    return name.replace(".", "").replace(":", "").replace("-", "").replace("_", "")

# Directory containing miniSEED files
mseed_dir = "miniSEED_files"

# Define SNR Calculation Function
def calculate_snr(trace, pre_window, post_window):
    """
    Calculate SNR for each point using pre-window (noise) and post-window (signal).
    """
    sampling_rate = trace.stats.sampling_rate
    pre_samples = int(pre_window * sampling_rate)
    post_samples = int(post_window * sampling_rate)

    snr_values = []
    times = []

    for i in range(pre_samples, len(trace.data) - post_samples):
        noise_window = trace.data[i - pre_samples:i]
        signal_window = trace.data[i:i + post_samples]

        # Calculate RMS values
        noise_rms = np.sqrt(np.mean(noise_window**2)) if len(noise_window) > 0 else 0
        signal_rms = np.sqrt(np.mean(signal_window**2)) if len(signal_window) > 0 else 0

        # Calculate SNR
        snr = signal_rms / noise_rms if noise_rms > 0 else 0
        snr_values.append(snr)
        times.append(trace.stats.starttime + (i / sampling_rate))

    return times, snr_values

# Parameters
pre_window = 2  # Pre-window for SNR calculation (seconds)
post_window = 2  # Post-window for SNR calculation (seconds)
snr_threshold = 2  # Minimum SNR value to consider
time_tolerance = 1.0  # Tolerance in seconds for "near match" to P-pick time

# Initialize counters
total_files = 0.0
matching_files = 0

# Loop through each miniSEED file in the directory
for file_path in Path(mseed_dir).glob("*.MSEED"):
    mseed_name = sanitize_filename(file_path.name.strip())  # Sanitize the miniSEED file name

    # Check if the miniSEED file matches an entry in the CSV
    matched_row = None
    for _, row in pick_data.iterrows():
        if sanitize_filename(row['trace_name_original_1']) == mseed_name:
            matched_row = row
            break

    if matched_row is None:
        print(f"No match found for file: {file_path.name}")
        continue

    total_files += 1

    # Extract P-pick time
    try:
        p_pick = UTCDateTime(matched_row['trace_p_pick_time'])
    except Exception as e:
        print(f"Error parsing P-pick time for {file_path.name}: {e}")
        continue

    # Read the miniSEED file
    stream = read(file_path)

    # Process each trace in the miniSEED file
    for trace in stream:
        print(f"Processing trace: {trace.id}")

        # Calculate SNR for 2s,2s duration window
        try:
            snr_times, snr_values = calculate_snr(trace, pre_window, post_window)
        except Exception as e:
            print(f"Error calculating SNR for trace {trace.id}: {e}")
            continue

        # Find the peak SNR and its corresponding time
        peak_snr = max(snr_values)
        peak_time = snr_times[np.argmax(snr_values)]

        # Check if the peak SNR exceeds the threshold and is near the P-pick time
        if peak_snr >= snr_threshold and abs((peak_time - p_pick).total_seconds()) <= time_tolerance:
            matching_files += 1
            print(f"Match found for file: {file_path.name}, Trace: {trace.id}")
            break  # Only count the file once if one trace matches

print(f"\nTotal files processed: {total_files}")
print(f"Files with SNR peak near P-pick: {matching_files}")
# Out:
# Processing trace: WS.POZA.S5.DN1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 107
#     104 peak_time = snr_times[np.argmax(snr_values)]
#     106 # Check if the peak SNR exceeds the threshold and is near the P-pick time
# --> 107 if peak_snr >= snr_threshold and abs((peak_time - p_pick).total_seconds()) <= time_tolerance:
#     108     matching_files += 1
#     109     print(f"Match found for file: {file_path.name}, Trace: {trace.id}")
#
# AttributeError: 'float' object has no attribute 'total_seconds'

# %%
from obspy import read
from obspy import UTCDateTime
from obspy.signal.trigger import classic_sta_lta
import pandas as pd
from pathlib import Path
import os
import numpy as np

# Load the pick data
pick_data = pd.read_csv(
    "dataset_earthquakes/metadata.csv",
    usecols=['trace_name_original_1', 'trace_p_pick_time', 'trace_s_pick_time', 'source_sensor_distance']
)

# Function to sanitize file names
def sanitize_filename(name):
    return name.replace(".", "").replace(":", "").replace("-", "").replace("_", "")

# Directory containing miniSEED files
mseed_dir = "miniSEED_files"

# Define SNR Calculation Function
def calculate_snr(trace, pre_window, post_window):
    """
    Calculate SNR for each point using pre-window (noise) and post-window (signal).
    """
    sampling_rate = trace.stats.sampling_rate
    pre_samples = int(pre_window * sampling_rate)
    post_samples = int(post_window * sampling_rate)

    snr_values = []
    times = []

    for i in range(pre_samples, len(trace.data) - post_samples):
        noise_window = trace.data[i - pre_samples:i]
        signal_window = trace.data[i:i + post_samples]

        # Calculate RMS values
        noise_rms = np.sqrt(np.mean(noise_window**2)) if len(noise_window) > 0 else 0
        signal_rms = np.sqrt(np.mean(signal_window**2)) if len(signal_window) > 0 else 0

        # Calculate SNR
        snr = signal_rms / noise_rms if noise_rms > 0 else 0
        snr_values.append(snr)
        times.append(trace.stats.starttime + (i / sampling_rate))

    return times, snr_values

# Parameters
pre_window = 2  # Pre-window for SNR calculation (seconds)
post_window = 2  # Post-window for SNR calculation (seconds)
snr_threshold = 2  # Minimum SNR value to consider
time_tolerance = 1.0  # Tolerance in seconds for "near match" to P-pick time

# Initialize counters
total_files = 0
matching_files = 0

# Loop through each miniSEED file in the directory
for file_path in Path(mseed_dir).glob("*.MSEED"):
    mseed_name = sanitize_filename(file_path.name.strip())  # Sanitize the miniSEED file name

    # Check if the miniSEED file matches an entry in the CSV
    matched_row = None
    for _, row in pick_data.iterrows():
        if sanitize_filename(row['trace_name_original_1']) == mseed_name:
            matched_row = row
            break

    if matched_row is None:
        print(f"No match found for file: {file_path.name}")
        continue

    total_files += 1

    # Extract P-pick time
    try:
        p_pick = UTCDateTime(matched_row['trace_p_pick_time'])
    except Exception as e:
        print(f"Error parsing P-pick time for {file_path.name}: {e}")
        continue

    # Read the miniSEED file
    stream = read(file_path)

    # Process each trace in the miniSEED file
    for trace in stream:
        print(f"Processing trace: {trace.id}")

        # Calculate SNR for 2s,2s duration window
        try:
            snr_times, snr_values = calculate_snr(trace, pre_window, post_window)
        except Exception as e:
            print(f"Error calculating SNR for trace {trace.id}: {e}")
            continue

        # Find the peak SNR and its corresponding time
        peak_snr = max(snr_values)
        peak_time = snr_times[np.argmax(snr_values)]

        # Check if the peak SNR exceeds the threshold and is near the P-pick time
        if peak_snr >= snr_threshold:
            # Convert both times to UTCDateTime if not already
            if not isinstance(peak_time, UTCDateTime):
# Out:
#   Cell In[9], line 104
#     if not isinstance(peak_time, UTCDateTime):
#                                               ^
# SyntaxError: incomplete input

# %%
#claude ai version code


from obspy import read
from obspy import UTCDateTime
import pandas as pd
from pathlib import Path
import numpy as np
from scipy.signal import find_peaks
import matplotlib.pyplot as plt

# Load the pick data
pick_data = pd.read_csv(
    "dataset_earthquakes/metadata.csv",
    usecols=['trace_name_original_1', 'trace_p_pick_time', 'trace_s_pick_time', 'source_sensor_distance']
)

def sanitize_filename(name):
    """Sanitize file names for consistent matching"""
    return name.replace(".", "").replace(":", "").replace("-", "").replace("_", "")

def calculate_snr(trace, time_point, pre_window=2, post_window=2):
    """
    Calculate SNR for a specific time point using pre and post windows
    
    Args:
        trace: ObsPy trace object
        time_point: UTCDateTime of the point to calculate SNR around
        pre_window: seconds before time_point for noise window
        post_window: seconds after time_point for signal window
    
    Returns:
        float: SNR value
    """
    sampling_rate = trace.stats.sampling_rate
    
    # Convert time point to sample index
    point_index = int((time_point - trace.stats.starttime) * sampling_rate)
    
    # Calculate window indices
    noise_start = max(0, point_index - int(pre_window * sampling_rate))
    noise_end = point_index
    signal_start = point_index
    signal_end = min(len(trace.data), point_index + int(post_window * sampling_rate))
    
    # Extract windows
    noise_window = trace.data[noise_start:noise_end]
    signal_window = trace.data[signal_start:signal_end]
    
    # Calculate RMS values
    noise_rms = np.sqrt(np.mean(noise_window**2)) if len(noise_window) > 0 else 1e-10
    signal_rms = np.sqrt(np.mean(signal_window**2)) if len(signal_window) > 0 else 0
    
    return signal_rms / noise_rms

def calculate_snr_series(trace, pre_window=2, post_window=2):
    """
    Calculate SNR for entire trace using sliding windows
    
    Returns:
        times: array of timestamps
        snr_values: array of SNR values
    """
    sampling_rate = trace.stats.sampling_rate
    times = []
    snr_values = []
    
    for i in range(len(trace.data)):
        current_time = trace.stats.starttime + i/sampling_rate
        snr = calculate_snr(trace, current_time, pre_window, post_window)
        times.append(current_time)
        snr_values.append(snr)
    
    return np.array(times), np.array(snr_values)

def find_snr_peaks(times, snr_values, min_snr=2.0, min_distance_samples=100):
    """Find peaks in SNR values above threshold"""
    peaks, _ = find_peaks(snr_values, height=min_snr, distance=min_distance_samples)
    return times[peaks], snr_values[peaks]

def validate_p_picks(trace, p_pick_time, time_tolerance=1.0, snr_threshold=2.0):
    """
    Validate P-picks by comparing with SNR peaks
    
    Returns:
        bool: Whether P-pick is valid
        float: SNR at P-pick time
        UTCDateTime: Nearest SNR peak time
        float: SNR at peak
    """
    # Calculate SNR series
    times, snr_values = calculate_snr_series(trace)
    
    # Find SNR peaks
    peak_times, peak_snrs = find_snr_peaks(times, snr_values, snr_threshold)
    
    # Calculate SNR at P-pick time
    p_pick_snr = calculate_snr(trace, p_pick_time)
    
    # Find nearest peak to P-pick
    if len(peak_times) > 0:
        time_diffs = np.abs([t.timestamp - p_pick_time.timestamp for t in peak_times])
        nearest_peak_idx = np.argmin(time_diffs)
        nearest_peak_time = peak_times[nearest_peak_idx]
        nearest_peak_snr = peak_snrs[nearest_peak_idx]
        
        # Check if within tolerance
        is_valid = time_diffs[nearest_peak_idx] <= time_tolerance
    else:
        is_valid = False
        nearest_peak_time = None
        nearest_peak_snr = None
    
    return is_valid, p_pick_snr, nearest_peak_time, nearest_peak_snr

def plot_validation_results(trace, p_pick_time, times, snr_values, peak_times, peak_snrs):
    """Plot trace data, SNR values, and validation results"""
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 8))
    
    # Plot trace data
    trace_times = np.arange(len(trace.data)) / trace.stats.sampling_rate
    ax1.plot(trace_times, trace.data, 'b-', label='Trace Data')
    ax1.axvline(p_pick_time - trace.stats.starttime, color='r', linestyle='--', label='P-Pick')
    ax1.set_title('Seismic Trace')
    ax1.legend()
    
    # Plot SNR values
    ax2.plot(times - trace.stats.starttime, snr_values, 'g-', label='SNR')
    ax2.scatter(peak_times - trace.stats.starttime, peak_snrs, color='r', label='SNR Peaks')
    ax2.axvline(p_pick_time - trace.stats.starttime, color='r', linestyle='--', label='P-Pick')
    ax2.axhline(2.0, color='k', linestyle=':', label='SNR Threshold')
    ax2.set_title('Signal-to-Noise Ratio')
    ax2.legend()
    
    plt.tight_layout()
    return fig

# Main processing loop
mseed_dir = "miniSEED_files"
results = []

for file_path in Path(mseed_dir).glob("*.MSEED"):
    mseed_name = sanitize_filename(file_path.name)
    
    # Find matching metadata
    matched_row = pick_data[pick_data['trace_name_original_1'].apply(sanitize_filename) == mseed_name].iloc[0]
    
    if matched_row is None:
        print(f"No match found for file: {file_path.name}")
        continue
    
    try:
        p_pick = UTCDateTime(matched_row['trace_p_pick_time'])
        stream = read(file_path)
        
        for trace in stream:
            print(f"Processing trace: {trace.id}")
            
            # Validate P-pick
            is_valid, p_pick_snr, nearest_peak_time, nearest_peak_snr = validate_p_picks(trace, p_pick)
            
            # Calculate SNR series for plotting
            times, snr_values = calculate_snr_series(trace)
            peak_times, peak_snrs = find_snr_peaks(times, snr_values)
            
            # Plot results
            fig = plot_validation_results(trace, p_pick, times, snr_values, peak_times, peak_snrs)
            plt.savefig(f"validation_{trace.id}.png")
            plt.close()
            
            # Store results
            results.append({
                'trace_id': trace.id,
                'is_valid': is_valid,
                'p_pick_snr': p_pick_snr,
                'nearest_peak_time': nearest_peak_time,
                'nearest_peak_snr': nearest_peak_snr,
                'time_difference': None if nearest_peak_time is None else abs(nearest_peak_time - p_pick)
            })
            
    except Exception as e:
        print(f"Error processing {file_path.name}: {e}")

# Create summary DataFrame
results_df = pd.DataFrame(results)
print("\nValidation Results Summary:")
print(f"Total traces processed: {len(results_df)}")
print(f"Valid P-picks: {results_df['is_valid'].sum()}")
print(f"Average P-pick SNR: {results_df['p_pick_snr'].mean():.2f}")
# Out:
# Processing trace: WS.POZA.S5.DN1
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 146
#     143 mseed_name = sanitize_filename(file_path.name)
#     145 # Find matching metadata
# --> 146 matched_row = pick_data[pick_data['trace_name_original_1'].apply(sanitize_filename) == mseed_name].iloc[0]
#     148 if matched_row is None:
#     149     print(f"No match found for file: {file_path.name}")
#
# File c:\Users\Ayush_trainee\anaconda3\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\Ayush_trainee\anaconda3\Lib\site-packages\pandas\core\indexing.py:1752, in _iLocIndexer._getitem_axis(self, key, axis)
#    1749     raise TypeError("Cannot index by location index with a non-integer key")
#    1751 # validate the location
# -> 1752 self._validate_integer(key, axis)
#    1754 return self.obj._ixs(key, axis=axis)
#
# File c:\Users\Ayush_trainee\anaconda3\Lib\site-packages\pandas\core\indexing.py:1685, in _iLocIndexer._validate_integer(self, key, axis)
#    1683 len_axis = len(self.obj._get_axis(axis))
#    1684 if key >= len_axis or key < -len_axis:
# -> 1685     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %%
#gemini version of the code 
from obspy import read
from obspy import UTCDateTime
from obspy.signal.trigger import classic_sta_lta
import pandas as pd
from pathlib import Path
import os
import numpy as np

# Load the pick data
pick_data = pd.read_csv(
    "dataset_earthquakes/metadata.csv",
    usecols=['trace_name_original_1', 'trace_p_pick_time', 'trace_s_pick_time', 'source_sensor_distance']
)

# Function to sanitize file names
def sanitize_filename(name):
    return name.replace(".", "").replace(":", "").replace("-", "").replace("_", "")

# Directory containing miniSEED files
mseed_dir = "miniSEED_files"

# Define SNR Calculation Function
def calculate_snr(trace, pre_window, post_window, p_pick_time, time_tolerance):
    """
    Calculate SNR for each point considering P-pick time and tolerance.
    """
    sampling_rate = trace.stats.sampling_rate

    # Convert pre-window and post-window to samples
    pre_samples = int(pre_window * sampling_rate)
    post_samples = int(post_window * sampling_rate)

    snr_values = []
    times = []

    # Adjust window based on P-pick time and tolerance
    start_time = p_pick_time - time_tolerance
    end_time = p_pick_time + time_tolerance

    # Ensure window stays within trace bounds
    start_index = max(0, int((start_time - trace.stats.starttime) * sampling_rate))
    end_index = min(len(trace.data), int((end_time - trace.stats.starttime) * sampling_rate))

    # Calculate SNR within the adjusted window
    for i in range(start_index, end_index - post_samples):
        noise_window = trace.data[i: i + pre_samples]
        signal_window = trace.data[i + pre_samples: i + pre_samples + post_samples]

        # Calculate RMS values
        noise_rms = np.sqrt(np.mean(noise_window**2)) if len(noise_window) > 0 else 0
        signal_rms = np.sqrt(np.mean(signal_window**2)) if len(signal_window) > 0 else 0

        # Calculate SNR
        snr = signal_rms / noise_rms if noise_rms > 0 else 0
        snr_values.append(snr)
        times.append(trace.stats.starttime + (i / sampling_rate))

    return times, snr_values

# Parameters
pre_window = 2  # Pre-window for SNR calculation (seconds)
post_window = 2  # Post-window for SNR calculation (seconds)
snr_threshold = 1.3  # Minimum SNR value to consider
time_tolerance = 1.0  # Tolerance in seconds for "near match" to P-pick time

# Initialize counters
total_files = 0
matching_files = 0

# Loop through each miniSEED file in the directory
for file_path in Path(mseed_dir).glob("*.MSEED"):
    mseed_name = sanitize_filename(file_path.name.strip())  # Sanitize the miniSEED file name

    # Check if the miniSEED file matches an entry in the CSV
    matched_row = None
    for _, row in pick_data.iterrows():
        if sanitize_filename(row['trace_name_original_1']) == mseed_name:
            matched_row = row
            break

    if matched_row is None:
        print(f"No match found for file: {file_path.name}")
        continue

    total_files += 1

    # Extract P-pick time
    try:
        p_pick = UTCDateTime(matched_row['trace_p_pick_time'])
    except Exception as e:
        print(f"Error parsing P-pick time for {file_path.name}: {e}")
        continue

    # Read the miniSEED file
    stream = read(file_path)

    # Process each trace in the miniSEED file
    for trace in stream:
        print(f"Processing trace: {trace.id}")

        # Calculate SNR with adjusted window
        times, snr_values = calculate_snr(trace, pre_window, post_window, p_pick, time_tolerance)

        # Further processing or analysis with SNR values and times
        # ... (e.g., plot SNR, identify peaks, etc.)

        # Check if SNR exceeds threshold
        if any(snr > snr_threshold for snr in snr_values):
            matching_files += 1
            print(f"Trace {trace.id} meets SNR threshold.")

print(f"Total files processed: {total_files}")
print(f"Files meeting SNR threshold: {matching_files}")
# Out:
# Processing trace: WS.POZA.S5.DN1
# No match found for file: 34161341_2023-02-21T00.07.00