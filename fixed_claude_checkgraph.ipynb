# %%
from obspy import read
from obspy import UTCDateTime
import pandas as pd
from pathlib import Path
import numpy as np
from scipy.signal import find_peaks
import matplotlib.pyplot as plt

# Load the pick data
pick_data = pd.read_csv(
    "dataset_earthquakes/metadata.csv",
    usecols=['trace_name_original_1', 'trace_p_pick_time', 'trace_s_pick_time', 'source_sensor_distance']
)

def sanitize_filename(name):
    """Sanitize file names for consistent matching"""
    return str(name).replace(".", "").replace(":", "").replace("-", "").replace("_", "").strip().lower()

def calculate_snr(trace, time_point, pre_window=2, post_window=2):
    """
    Calculate SNR for a specific time point using pre and post windows
    """
    sampling_rate = trace.stats.sampling_rate
    
    # Convert time point to sample index
    point_index = int((time_point - trace.stats.starttime) * sampling_rate)
    
    # Calculate window indices
    noise_start = max(0, point_index - int(pre_window * sampling_rate))
    noise_end = point_index
    signal_start = point_index
    signal_end = min(len(trace.data), point_index + int(post_window * sampling_rate))
    
    # Extract windows
    noise_window = trace.data[noise_start:noise_end]
    signal_window = trace.data[signal_start:signal_end]
    
    # Calculate RMS values
    noise_rms = np.sqrt(np.mean(noise_window**2)) if len(noise_window) > 0 else 1e-10
    signal_rms = np.sqrt(np.mean(signal_window**2)) if len(signal_window) > 0 else 0
    
    return signal_rms / noise_rms

def calculate_snr_series(trace, pre_window=2, post_window=2):
    """
    Calculate SNR for entire trace using sliding windows
    """
    sampling_rate = trace.stats.sampling_rate
    window_samples = int((pre_window + post_window) * sampling_rate)
    
    # Calculate SNR at fewer points to improve performance
    step = max(1, int(sampling_rate / 10))  # Calculate SNR every 0.1 seconds
    times = []
    snr_values = []
    
    for i in range(0, len(trace.data) - window_samples, step):
        current_time = trace.stats.starttime + i/sampling_rate
        snr = calculate_snr(trace, current_time, pre_window, post_window)
        times.append(current_time)
        snr_values.append(snr)
    
    return np.array(times), np.array(snr_values)

def find_snr_peaks(times, snr_values, min_snr=1.7, min_distance_samples=10):
    """Find peaks in SNR values above threshold"""
    if len(snr_values) == 0:
        return np.array([]), np.array([])
    
    peaks, properties = find_peaks(snr_values, height=min_snr, distance=min_distance_samples)
    if len(peaks) == 0:
        return np.array([]), np.array([])
    
    return times[peaks], snr_values[peaks]

def validate_p_picks(trace, p_pick_time, time_tolerance=1.0, snr_threshold=1.7):
    """
    Validate P-picks by comparing with SNR peaks
    """
    # Calculate SNR series
    times, snr_values = calculate_snr_series(trace)
    
    # Find SNR peaks
    peak_times, peak_snrs = find_snr_peaks(times, snr_values, snr_threshold)
    
    # Calculate SNR at P-pick time
    p_pick_snr = calculate_snr(trace, p_pick_time)
    
    # Find nearest peak to P-pick
    if len(peak_times) > 0:
        time_diffs = np.abs([t.timestamp - p_pick_time.timestamp for t in peak_times])
        nearest_peak_idx = np.argmin(time_diffs)
        nearest_peak_time = peak_times[nearest_peak_idx]
        nearest_peak_snr = peak_snrs[nearest_peak_idx]
        
        # Check if within tolerance
        is_valid = time_diffs[nearest_peak_idx] <= time_tolerance
    else:
        is_valid = False
        nearest_peak_time = None
        nearest_peak_snr = None
    
    return is_valid, p_pick_snr, nearest_peak_time, nearest_peak_snr, times, snr_values, peak_times, peak_snrs

def plot_validation_results(trace, p_pick_time, times, snr_values, peak_times, peak_snrs):
    """Plot trace data, SNR values, and validation results"""
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 8))
    
    # Plot trace data
    trace_times = np.arange(len(trace.data)) / trace.stats.sampling_rate
    ax1.plot(trace_times, trace.data, 'b-', label='Trace Data')
    ax1.axvline(p_pick_time - trace.stats.starttime, color='r', linestyle='--', label='P-Pick')
    ax1.set_title('Seismic Trace')
    ax1.legend()
    
    # Plot SNR values
    if len(times) > 0:  # Only plot if we have SNR values
        ax2.plot(times - trace.stats.starttime, snr_values, 'g-', label='SNR')
        if len(peak_times) > 0:  # Only plot peaks if we found any
            ax2.scatter(peak_times - trace.stats.starttime, peak_snrs, color='r', label='SNR Peaks')
    ax2.axvline(p_pick_time - trace.stats.starttime, color='r', linestyle='--', label='P-Pick')
    ax2.axhline(2.0, color='k', linestyle=':', label='SNR Threshold')
    ax2.set_title('Signal-to-Noise Ratio')
    ax2.legend()
    
    plt.tight_layout()
    return fig

# Main processing loop
mseed_dir = "miniSEED_files"
results = []
total_files = 0
matching_files = 0

# Print all unique filenames in pick_data for debugging
print("Available traces in metadata:")
print(pick_data['trace_name_original_1'].apply(sanitize_filename).unique())

for file_path in Path(mseed_dir).glob("*.MSEED"):
    total_files += 1
    mseed_name = sanitize_filename(file_path.name)
    print(f"\nProcessing file: {file_path.name}")
    print(f"Sanitized name: {mseed_name}")
    
    # Find matching metadata
    matched_rows = pick_data[pick_data['trace_name_original_1'].apply(sanitize_filename) == mseed_name]
    
    if len(matched_rows) == 0:
        print(f"No match found for file: {file_path.name}")
        continue
    
    matching_files += 1
    matched_row = matched_rows.iloc[0]
    
    try:
        p_pick = UTCDateTime(matched_row['trace_p_pick_time'])
        stream = read(file_path)
        
        for trace in stream:
            print(f"Processing trace: {trace.id}")
            
            # Validate P-pick
            is_valid, p_pick_snr, nearest_peak_time, nearest_peak_snr, times, snr_values, peak_times, peak_snrs = validate_p_picks(trace, p_pick)
            
            # Plot results
            fig = plot_validation_results(trace, p_pick, times, snr_values, peak_times, peak_snrs)
            plt.savefig(f"validation_{trace.id}.png")
            plt.close()
            
            # Store results
            results.append({
                'trace_id': trace.id,
                'is_valid': is_valid,
                'p_pick_snr': p_pick_snr,
                'nearest_peak_time': nearest_peak_time,
                'nearest_peak_snr': nearest_peak_snr,
                'time_difference': None if nearest_peak_time is None else abs(nearest_peak_time - p_pick)
            })
            
    except Exception as e:
        print(f"Error processing {file_path.name}: {e}")
        continue

# Create summary DataFrame
results_df = pd.DataFrame(results)
print("\nProcessing Summary:")
print(f"Total files found: {total_files}")
print(f"Files matching metadata: {matching_files}")
print(f"Total traces processed: {len(results_df)}")
print(f"Valid P-picks: {results_df['is_valid'].sum()}")
if len(results_df) > 0:
    print(f"Average P-pick SNR: {results_df['p_pick_snr'].mean():.2f}")
# Out:
# Available traces in metadata:
# ['3469238120230415t131755541619zwspozas2dn1mseed'
#  '3469238120230415t131755542715zwspozas3dn1mseed'
#  '3469238120230415t131755540100zwspozas4dn1mseed'
#  '3469238120230415t131755539436zwspozas5dn1mseed'
#  '3469238120230415t131755539433zwspozas6dn1mseed'
#  '3416151120230221t001234318032zwspozas2dn1mseed'
#  '3416222120230221t010656700647zwspozas2dn1mseed'
#  '3416250120230221t020238098562zwspozas2dn1mseed'
#  '3416157120230221t001439010032zwspozas2dn1mseed'
#  '3416683120230221t124834239517zwspozas2dn1mseed'
#  '3416801120230221t154846241375zwspozas2dn1mseed'
#  '3416989120230221t202555853184zwspozas2dn1mseed'
#  '3416440120230221t071334331365zwspozas2dn1mseed'
#  '3416783120230221t150801281277zwspozas2dn1mseed'
#  '3416341120230221t044909161225zwspozas2dn1mseed'
#  '3416305120230221t034155052397zwspozas2dn1mseed'
#  '3416356120230221t053359899097zwspozas2dn1mseed'
#  '3416202120230221t005656518032zwspozas2dn1mseed'
#  '3416579120230221t103627752007zwspozas2dn1mseed'
#  '3416162120230221t001841858032zwspozas2dn1mseed'
#  '3416489120230221t081939830757zwspozas2dn1mseed'
#  '3416348120230221t051535191097zwspozas2dn1mseed'
#  '3416237120230221t013101420647zwspozas2dn1mseed'
#  '3416243120230221t013115100647zwspozas2dn1mseed'
#  '3416820120230221t161527910842zwspozas2dn1mseed'
#  '3416251120230221t020602978562zwspozas2dn1mseed'
#  '3416301120230221t033230492397zwspozas2dn1mseed'
#  '3416393120230221t063857058640zwspozas2dn1mseed'
#  '3416211120230221t010221832647zwspozas2dn1mseed'
#  '3416179120230221t004023070032zwspozas2dn1mseed'
#  '3416810120230221t155201193375zwspozas2dn1mseed'
#  '3416231120230221t011519400647zwspozas2dn1mseed'
#  '3416274120230221t023954850725zwspozas2dn1mseed'
#  '3416134120230221t000700490032zwspozas2dn1mseed'
#  '3416837120230221t164857010736zwspozas2dn1mseed'
#  '3416801120230221t154846239429zwspozas3dn1mseed'
#  '3416489120230221t081939830367zwspozas3dn1mseed'
#  '3416301120230221t033230490319zwspozas3dn1mseed'
#  '3416810120230221t155201191429zwspozas3dn1mseed'
#  '3416162120230221t001841858024zwspozas3dn1mseed'
#  '3416237120230221t013101419238zwspozas3dn1mseed'
#  '3416579120230221t103627751736zwspozas3dn1mseed'
#  '3416251120230221t020602980243zwspozas3dn1mseed'
#  '3416151120230221t001234318024zwspozas3dn1mseed'
#  '3416250120230221t020238100243zwspozas3dn1mseed'
#  '3416157120230221t001439010024zwspozas3dn1mseed'
#  '3416440120230221t071334333420zwspozas3dn1mseed'
#  '3416274120230221t023954852047zwspozas3dn1mseed'
#  '3416222120230221t010656699238zwspozas3dn1mseed'
#  '3416211120230221t010221831238zwspozas3dn1mseed'
#  '3416202120230221t005656519238zwspozas3dn1mseed'
#  '3416348120230221t051535193431zwspozas3dn1mseed'
#  '3416341120230221t044909161007zwspozas3dn1mseed'
#  '3416989120230221t202555850809zwspozas3dn1mseed'
#  '3416134120230221t000700490024zwspozas3dn1mseed'
#  '3416393120230221t063857058077zwspozas3dn1mseed'
#  '3416356120230221t053359901431zwspozas3dn1mseed'
#  '3416837120230221t164857011567zwspozas3dn1mseed'
#  '3416231120230221t011519399238zwspozas3dn1mseed'
#  '3416820120230221t161527911567zwspozas3dn1mseed'
#  '3416243120230221t013115099238zwspozas3dn1mseed'
#  '3416783120230221t150801279429zwspozas3dn1mseed'
#  '3416683120230221t124834238879zwspozas3dn1mseed'
#  '3416179120230221t004023070024zwspozas3dn1mseed'
#  '3416305120230221t034155050319zwspozas3dn1mseed'
#  '3416231120230221t011519401079zwspozas4dn1mseed'
#  '3416202120230221t005656521079zwspozas4dn1mseed'
#  '3416162120230221t001841858708zwspozas4dn1mseed'
#  '3416274120230221t023954850647zwspozas4dn1mseed'
#  '3416250120230221t020238098725zwspozas4dn1mseed'
#  '3416211120230221t010221833079zwspozas4dn1mseed'
#  '3416579120230221t103627751693zwspozas4dn1mseed'
#  '3416305120230221t034155052276zwspozas4dn1mseed'
#  '3416157120230221t001439010708zwspozas4dn1mseed'
#  '3416151120230221t001234318708zwspozas4dn1mseed'
#  '3416810120230221t155201191421zwspozas4dn1mseed'
#  '3416243120230221t013115101079zwspozas4dn1mseed'
#  '3416801120230221t154846239421zwspozas4dn1mseed'
#  '3416251120230221t020602978725zwspozas4dn1mseed'
#  '3416134120230221t000700490708zwspozas4dn1mseed'
#  '3416301120230221t033230492276zwspozas4dn1mseed'
#  '3416356120230221t053359897899zwspozas4dn1mseed'
#  '3416348120230221t051535189899zwspozas4dn1mseed'
#  '3416393120230221t063857059276zwspozas4dn1mseed'
#  '3416237120230221t013101421079zwspozas4dn1mseed'
#  '3416341120230221t044909159092zwspozas4dn1mseed'
#  '3416683120230221t124834240879zwspozas4dn1mseed'
#  '3416489120230221t081939832827zwspozas4dn1mseed'
#  '3416783120230221t150801279469zwspozas4dn1mseed'
#  '3416179120230221t004023070708zwspozas4dn1mseed'
#  '3416440120230221t071334330804zwspozas4dn1mseed'
#  '3416820120230221t161527910539zwspozas4dn1mseed'
#  '3416837120230221t164857010539zwspozas4dn1mseed'
#  '3416989120230221t202555849985zwspozas4dn1mseed'
#  '3416222120230221t010656701079zwspozas4dn1mseed'
#  '3416231120230221t011519397562zwspozas5dn1mseed'
#  '3416237120230221t013101417675zwspozas5dn1mseed'
#  '3416162120230221t001841857723zwspozas5dn1mseed'
#  '3416489120230221t081939831473zwspozas5dn1mseed'
#  '3416157120230221t001439009723zwspozas5dn1mseed'
#  '3416989120230221t202555849606zwspozas5dn1mseed'
#  '3416348120230221t051535191190zwspozas5dn1mseed'
#  '3416301120230221t033230492143zwspozas5dn1mseed'
#  '3416440120230221t071334331170zwspozas5dn1mseed'
#  '3418100120230223t045532358953zwspozas6dn1mseed'
#  '3483622120230428t205039470291zwspozas2dn1mseed'
#  '3483622120230428t205039470238zwspozas3dn1mseed'
#  '3483622120230428t205039467773zwspozas4dn1mseed'
#  '3483622120230428t205039470042zwspozas5dn1mseed'
#  '3483622120230428t205039468678zwspozas6dn1mseed'
#  '3423455120230303t113550318445zwspozas2dn1mseed'
#  '3423455120230303t113550317154zwspozas3dn1mseed'
#  '3423455120230303t113550318957zwspozas4dn1mseed'
#  '3423455120230303t113550320215zwspozas5dn1mseed'
#  '3423455120230303t113550318308zwspozas6dn1mseed'
#  '3424247120230304t210545590388zwspozas2dn1mseed'
#  '3424202120230304t181002196990zwspozas2dn1mseed'
#  '3424247120230304t210545591228zwspozas3dn1mseed'
#  '3424202120230304t181002196699zwspozas3dn1mseed'
#  '3424202120230304t181002197355zwspozas4dn1mseed'
#  '3424247120230304t210545591254zwspozas4dn1mseed'
#  '3424202120230304t181002199410zwspozas5dn1mseed'
#  '3424247120230304t210545590576zwspozas5dn1mseed'
#  '3424247120230304t210545592002zwspozas6dn1mseed'
#  '3424202120230304t181002196749zwspozas6dn1mseed'
#  '3449141120230328t033154129354zwspozas2dn1mseed'
#  '3449141120230328t033154130204zwspozas3dn1mseed'
#  '3449141120230328t033154128271zwspozas5dn1mseed'
#  '3449141120230328t033154128524zwspozas6dn1mseed'
#  '3430265120230310t023147879947zwspozas2dn1mseed'
#  '3430228120230310t021224011947zwspozas2dn1mseed'
#  '3430228120230310t021224013111zwspozas3dn1mseed'
#  '3430265120230310t023147881105zwspozas3dn1mseed'
#  '3430265120230310t023147878607zwspozas4dn1mseed'
#  '3430228120230310t021224012759zwspozas4dn1mseed'
#  '3430228120230310t021224011676zwspozas5dn1mseed'
#  '3430265120230310t023147879795zwspozas5dn1mseed'
#  '3430228120230310t021224010913zwspozas6dn1mseed'
#  '3430265120230310t023147879017zwspozas6dn1mseed'
#  '3446565120230326t041359980417zwspozas2dn1mseed'
#  '3446492120230326t000658760415zwspozas2dn1mseed'
#  '3446902120230326t115356208154zwspozas2dn1mseed'
#  '3446565120230326t041359981926zwspozas3dn1mseed'
#  '3446902120230326t115356208769zwspozas3dn1mseed'
#  '3446492120230326t000658762119zwspozas3dn1mseed'
#  '3446902120230326t115356208288zwspozas5dn1mseed'
#  '3446565120230326t041359978931zwspozas5dn1mseed'
#  '3446492120230326t000658761423zwspozas5dn1mseed'
#  '3446902120230326t115356207428zwspozas6dn1mseed'
#  '3446565120230326t041359979858zwspozas6dn1mseed'
#  '3446492120230326t000658758495zwspozas6dn1mseed'
#  '3526670120230609t223436212005zwspozas2dn1mseed'
#  '3526670120230609t223436208297zwspozas3dn1mseed'
#  '3526670120230609t223436211277zwspozas4dn1mseed'
#  '3526670120230609t223436210130zwspozas5dn1mseed'
#  '3526670120230609t223436210008zwspozas6dn1mseed'
#  '3454756120230402t225718573506zwspozas2dn1mseed'
#  '3454764120230402t225732441506zwspozas2dn1mseed'
#  '3454764120230402t225732441604zwspozas3dn1mseed'
#  '3454756120230402t225718573604zwspozas3dn1mseed'
#  '3454764120230402t225732438053zwspozas5dn1mseed'
#  '3454756120230402t225718570053zwspozas5dn1mseed'
#  '3454756120230402t225718573150zwspozas6dn1mseed'
#  '3454764120230402t225732441150zwspozas6dn1mseed'
#  '3541944120230630t041040107601zwspozas2dn1mseed'
#  '3541944120230630t041040108841zwspozas3dn1mseed'
#  '3541944120230630t041040109398zwspozas4dn1mseed'
#  '3541944120230630t041040107451zwspozas5dn1mseed'
#  '3541944120230630t041040108520zwspozas6dn1mseed']
#
# Processing file: 34161341_2023-02-21T00.07.00.489723Z_WS.POZA.S5.DN1.MSEED
# Sanitized name: 3416134120230221t000700489723zwspozas5dn1mseed
# Processing trace: WS.POZA.S5.DN1
#
# Processing file: 34161341_2023-02-21T00.07.00.489723Z_WS.POZA.S5.DN2.MSEED
# Sanitized name: 3416134120230221t000700489723zwspozas5dn2mseed
# No match found for file: 34161341_2023-02-21T00.07.00.489723Z_WS.POZA.S5.DN2.MSEED
#
# Processing file: 34161341_2023-02-21T00.07.00.489723Z_WS.POZA.S5.DNZ.MSEED
# Sanitized name: 3416134120230221t000700489723zwspozas5dnzmseed
# No match found for file: 34161341_2023-02-21T00.07.00.489723Z_WS.POZA.S5.DNZ.MSEED
#
# Processing file: 34161341_2023-02-21T00.07.00.490024Z_WS.POZA.S3.DN1.MSEED
# Sanitized name: 3416134120230221t000700490024zwspozas3dn1mseed
# Processing trace: WS.POZA.S3.DN1
#
# Processing file: 34161341_2023-02-21T00.07.00.490024Z_WS.POZA.S3.DN2.MSEED
# Sanitized name: 3416134120230221t000700490024zwspozas3dn2mseed
# No match found for file: 34161341_2023-02-21T00.07.00.490024Z_WS.POZA.S3.DN2.MSEED
#
# Processing file: 34161341_2023-02-21T00.07.00.490024Z_WS.POZA.S3.DNZ.MSEED
# Sanitized name: 3416134120230221t000700490024zwspozas3dnzmseed
# No match found for file: 34161341_2023-02-21T00.07.00.490024Z_WS.POZA.S3.DNZ.MSEED
#
# Processing file: 34161341_2023-02-21T00.07.00.490032Z_WS.POZA.S2.DN1.MSEED
# Sanitized name: 3416134120230221t000700490032zwspozas2dn1mseed
# Processing trace: WS.POZA.S2.DN1
#
# Processing file: 34161341_2023-02-21T00.07.00.490032Z_WS.POZA.S2.DN2.MSEED
# Sanitized name: 3416134120230221t000700490032zwspozas2dn2mseed
# No match found for file: 34161341_2023-02-21T00.07.00.490032Z_WS.POZA.S2.DN2.MSEED
#
# Processing file: 34161341_2023-02-21T00.07.00.490032Z_WS.POZA.S2.DNZ.MSEED
# Sanitized name: 3416134120230221t000700490032zwspozas2dnzmseed
# No match found for file: 34161341_2023-02-21T00.07.00.490032Z_WS.POZA.S2.DNZ.MSEED
#
# Processing file: 34161341_2023-02-21T00.07.00.490708Z_WS.POZA.S4.DN1.MSEED
# Sanitized name: 3416134120230221t000700490708zwspozas4dn1mseed
# Processing trace: WS.POZA.S4.DN1
#
# Processing file: 34161341_2023-02-21T00.07.00.490708Z_WS.POZA.S4.DN2.MSEED
# Sanitized name: 3416134120230221t000700490708zwspozas4dn2mseed
# No match found for file: 34161341_2023-02-21T00.07.00.490708Z_WS.POZA.S4.DN2.MSEED
#
# Processing file: 34161341_2023-02-21T00.07.00.490708Z_WS.POZA.S4.DNZ.MSEED
# Sanitized name: 3416134120230221t000700490708zwspozas4dnzmseed
# No match found for file: 34161341_2023-02-21T00.07.00.490708Z_WS.POZA.S4.DNZ.MSEED
#
# Processing file: 34161341_2023-02-21T00.07.00.493150Z_WS.POZA.S6.DN1.MSEED
# Sanitized name: 3416134120230221t000700493150zwspozas6dn1mseed
# Processing trace: WS.POZA.S6.DN1
#
# Processing file: 34161341_2023-02-21T00.07.00.493150Z_WS.POZA.S6.DN2.MSEED
# Sanitized name: 3416134120230221t000700493150zwspozas6dn2mseed
# No match found for file: 34161341_2023-02-21T00.07.00.493150Z_WS.POZA.S6.DN2.MSEED
#
# Processing file: 34161341_2023-02-21T00.07.00.493150Z_WS.POZA.S6.DNZ.MSEED
# Sanitized name: 3416134120230221t000700493150zwspozas6dnzmseed
# No match found for file: 34161341_2023-02-21T00.07.00.493150Z_WS.POZA.S6.DNZ.MSEED
#
# Processing file: 34161511_2023-02-21T00.12.34.317723Z_WS.POZA.S5.DN1.MSEED
# Sanitized name: 3416151120230221t001234317723zwspozas5dn1mseed
# Error processing 34161511_2023-02-21T00.12.34.317723Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34161511_2023-02-21T00.12.34.317723Z_WS.POZA.S5.DN2.MSEED
# Sanitized name: 3416151120230221t001234317723zwspozas5dn2mseed
# No match found for file: 34161511_2023-02-21T00.12.34.317723Z_WS.POZA.S5.DN2.MSEED
#
# Processing file: 34161511_2023-02-21T00.12.34.317723Z_WS.POZA.S5.DNZ.MSEED
# Sanitized name: 3416151120230221t001234317723zwspozas5dnzmseed
# No match found for file: 34161511_2023-02-21T00.12.34.317723Z_WS.POZA.S5.DNZ.MSEED
#
# Processing file: 34161511_2023-02-21T00.12.34.318024Z_WS.POZA.S3.DN1.MSEED
# Sanitized name: 3416151120230221t001234318024zwspozas3dn1mseed
# Processing trace: WS.POZA.S3.DN1
#
# Processing file: 34161511_2023-02-21T00.12.34.318024Z_WS.POZA.S3.DN2.MSEED
# Sanitized name: 3416151120230221t001234318024zwspozas3dn2mseed
# No match found for file: 34161511_2023-02-21T00.12.34.318024Z_WS.POZA.S3.DN2.MSEED
#
# Processing file: 34161511_2023-02-21T00.12.34.318024Z_WS.POZA.S3.DNZ.MSEED
# Sanitized name: 3416151120230221t001234318024zwspozas3dnzmseed
# No match found for file: 34161511_2023-02-21T00.12.34.318024Z_WS.POZA.S3.DNZ.MSEED
#
# Processing file: 34161511_2023-02-21T00.12.34.318032Z_WS.POZA.S2.DN1.MSEED
# Sanitized name: 3416151120230221t001234318032zwspozas2dn1mseed
# Error processing 34161511_2023-02-21T00.12.34.318032Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34161511_2023-02-21T00.12.34.318032Z_WS.POZA.S2.DN2.MSEED
# Sanitized name: 3416151120230221t001234318032zwspozas2dn2mseed
# No match found for file: 34161511_2023-02-21T00.12.34.318032Z_WS.POZA.S2.DN2.MSEED
#
# Processing file: 34161511_2023-02-21T00.12.34.318032Z_WS.POZA.S2.DNZ.MSEED
# Sanitized name: 3416151120230221t001234318032zwspozas2dnzmseed
# No match found for file: 34161511_2023-02-21T00.12.34.318032Z_WS.POZA.S2.DNZ.MSEED
#
# Processing file: 34161511_2023-02-21T00.12.34.318708Z_WS.POZA.S4.DN1.MSEED
# Sanitized name: 3416151120230221t001234318708zwspozas4dn1mseed
# Error processing 34161511_2023-02-21T00.12.34.318708Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34161511_2023-02-21T00.12.34.318708Z_WS.POZA.S4.DN2.MSEED
# Sanitized name: 3416151120230221t001234318708zwspozas4dn2mseed
# No match found for file: 34161511_2023-02-21T00.12.34.318708Z_WS.POZA.S4.DN2.MSEED
#
# Processing file: 34161511_2023-02-21T00.12.34.318708Z_WS.POZA.S4.DNZ.MSEED
# Sanitized name: 3416151120230221t001234318708zwspozas4dnzmseed
# No match found for file: 34161511_2023-02-21T00.12.34.318708Z_WS.POZA.S4.DNZ.MSEED
#
# Processing file: 34161511_2023-02-21T00.12.34.321150Z_WS.POZA.S6.DN1.MSEED
# Sanitized name: 3416151120230221t001234321150zwspozas6dn1mseed
# Error processing 34161511_2023-02-21T00.12.34.321150Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34161511_2023-02-21T00.12.34.321150Z_WS.POZA.S6.DN2.MSEED
# Sanitized name: 3416151120230221t001234321150zwspozas6dn2mseed
# No match found for file: 34161511_2023-02-21T00.12.34.321150Z_WS.POZA.S6.DN2.MSEED
#
# Processing file: 34161511_2023-02-21T00.12.34.321150Z_WS.POZA.S6.DNZ.MSEED
# Sanitized name: 3416151120230221t001234321150zwspozas6dnzmseed
# No match found for file: 34161511_2023-02-21T00.12.34.321150Z_WS.POZA.S6.DNZ.MSEED
#
# Processing file: 34161571_2023-02-21T00.14.39.009723Z_WS.POZA.S5.DN1.MSEED
# Sanitized name: 3416157120230221t001439009723zwspozas5dn1mseed
# Error processing 34161571_2023-02-21T00.14.39.009723Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34161571_2023-02-21T00.14.39.009723Z_WS.POZA.S5.DN2.MSEED
# Sanitized name: 3416157120230221t001439009723zwspozas5dn2mseed
# No match found for file: 34161571_2023-02-21T00.14.39.009723Z_WS.POZA.S5.DN2.MSEED
#
# Processing file: 34161571_2023-02-21T00.14.39.009723Z_WS.POZA.S5.DNZ.MSEED
# Sanitized name: 3416157120230221t001439009723zwspozas5dnzmseed
# No match found for file: 34161571_2023-02-21T00.14.39.009723Z_WS.POZA.S5.DNZ.MSEED
#
# Processing file: 34161571_2023-02-21T00.14.39.010024Z_WS.POZA.S3.DN1.MSEED
# Sanitized name: 3416157120230221t001439010024zwspozas3dn1mseed
# Error processing 34161571_2023-02-21T00.14.39.010024Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34161571_2023-02-21T00.14.39.010024Z_WS.POZA.S3.DN2.MSEED
# Sanitized name: 3416157120230221t001439010024zwspozas3dn2mseed
# No match found for file: 34161571_2023-02-21T00.14.39.010024Z_WS.POZA.S3.DN2.MSEED
#
# Processing file: 34161571_2023-02-21T00.14.39.010024Z_WS.POZA.S3.DNZ.MSEED
# Sanitized name: 3416157120230221t001439010024zwspozas3dnzmseed
# No match found for file: 34161571_2023-02-21T00.14.39.010024Z_WS.POZA.S3.DNZ.MSEED
#
# Processing file: 34161571_2023-02-21T00.14.39.010032Z_WS.POZA.S2.DN1.MSEED
# Sanitized name: 3416157120230221t001439010032zwspozas2dn1mseed
# Error processing 34161571_2023-02-21T00.14.39.010032Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34161571_2023-02-21T00.14.39.010032Z_WS.POZA.S2.DN2.MSEED
# Sanitized name: 3416157120230221t001439010032zwspozas2dn2mseed
# No match found for file: 34161571_2023-02-21T00.14.39.010032Z_WS.POZA.S2.DN2.MSEED
#
# Processing file: 34161571_2023-02-21T00.14.39.010032Z_WS.POZA.S2.DNZ.MSEED
# Sanitized name: 3416157120230221t001439010032zwspozas2dnzmseed
# No match found for file: 34161571_2023-02-21T00.14.39.010032Z_WS.POZA.S2.DNZ.MSEED
#
# Processing file: 34161571_2023-02-21T00.14.39.010708Z_WS.POZA.S4.DN1.MSEED
# Sanitized name: 3416157120230221t001439010708zwspozas4dn1mseed
# Error processing 34161571_2023-02-21T00.14.39.010708Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34161571_2023-02-21T00.14.39.010708Z_WS.POZA.S4.DN2.MSEED
# Sanitized name: 3416157120230221t001439010708zwspozas4dn2mseed
# No match found for file: 34161571_2023-02-21T00.14.39.010708Z_WS.POZA.S4.DN2.MSEED
#
# Processing file: 34161571_2023-02-21T00.14.39.010708Z_WS.POZA.S4.DNZ.MSEED
# Sanitized name: 3416157120230221t001439010708zwspozas4dnzmseed
# No match found for file: 34161571_2023-02-21T00.14.39.010708Z_WS.POZA.S4.DNZ.MSEED
#
# Processing file: 34161571_2023-02-21T00.14.39.013150Z_WS.POZA.S6.DN1.MSEED
# Sanitized name: 3416157120230221t001439013150zwspozas6dn1mseed
# Error processing 34161571_2023-02-21T00.14.39.013150Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34161571_2023-02-21T00.14.39.013150Z_WS.POZA.S6.DN2.MSEED
# Sanitized name: 3416157120230221t001439013150zwspozas6dn2mseed
# No match found for file: 34161571_2023-02-21T00.14.39.013150Z_WS.POZA.S6.DN2.MSEED
#
# Processing file: 34161571_2023-02-21T00.14.39.013150Z_WS.POZA.S6.DNZ.MSEED
# Sanitized name: 3416157120230221t001439013150zwspozas6dnzmseed
# No match found for file: 34161571_2023-02-21T00.14.39.013150Z_WS.POZA.S6.DNZ.MSEED
#
# Processing file: 34161621_2023-02-21T00.18.41.857723Z_WS.POZA.S5.DN1.MSEED
# Sanitized name: 3416162120230221t001841857723zwspozas5dn1mseed
# Error processing 34161621_2023-02-21T00.18.41.857723Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34161621_2023-02-21T00.18.41.857723Z_WS.POZA.S5.DN2.MSEED
# Sanitized name: 3416162120230221t001841857723zwspozas5dn2mseed
# No match found for file: 34161621_2023-02-21T00.18.41.857723Z_WS.POZA.S5.DN2.MSEED
#
# Processing file: 34161621_2023-02-21T00.18.41.857723Z_WS.POZA.S5.DNZ.MSEED
# Sanitized name: 3416162120230221t001841857723zwspozas5dnzmseed
# No match found for file: 34161621_2023-02-21T00.18.41.857723Z_WS.POZA.S5.DNZ.MSEED
#
# Processing file: 34161621_2023-02-21T00.18.41.858024Z_WS.POZA.S3.DN1.MSEED
# Sanitized name: 3416162120230221t001841858024zwspozas3dn1mseed
# Error processing 34161621_2023-02-21T00.18.41.858024Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34161621_2023-02-21T00.18.41.858024Z_WS.POZA.S3.DN2.MSEED
# Sanitized name: 3416162120230221t001841858024zwspozas3dn2mseed
# No match found for file: 34161621_2023-02-21T00.18.41.858024Z_WS.POZA.S3.DN2.MSEED
#
# Processing file: 34161621_2023-02-21T00.18.41.858024Z_WS.POZA.S3.DNZ.MSEED
# Sanitized name: 3416162120230221t001841858024zwspozas3dnzmseed
# No match found for file: 34161621_2023-02-21T00.18.41.858024Z_WS.POZA.S3.DNZ.MSEED
#
# Processing file: 34161621_2023-02-21T00.18.41.858032Z_WS.POZA.S2.DN1.MSEED
# Sanitized name: 3416162120230221t001841858032zwspozas2dn1mseed
# Error processing 34161621_2023-02-21T00.18.41.858032Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34161621_2023-02-21T00.18.41.858032Z_WS.POZA.S2.DN2.MSEED
# Sanitized name: 3416162120230221t001841858032zwspozas2dn2mseed
# No match found for file: 34161621_2023-02-21T00.18.41.858032Z_WS.POZA.S2.DN2.MSEED
#
# Processing file: 34161621_2023-02-21T00.18.41.858032Z_WS.POZA.S2.DNZ.MSEED
# Sanitized name: 3416162120230221t001841858032zwspozas2dnzmseed
# No match found for file: 34161621_2023-02-21T00.18.41.858032Z_WS.POZA.S2.DNZ.MSEED
#
# Processing file: 34161621_2023-02-21T00.18.41.858708Z_WS.POZA.S4.DN1.MSEED
# Sanitized name: 3416162120230221t001841858708zwspozas4dn1mseed
# Error processing 34161621_2023-02-21T00.18.41.858708Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34161621_2023-02-21T00.18.41.858708Z_WS.POZA.S4.DN2.MSEED
# Sanitized name: 3416162120230221t001841858708zwspozas4dn2mseed
# No match found for file: 34161621_2023-02-21T00.18.41.858708Z_WS.POZA.S4.DN2.MSEED
#
# Processing file: 34161621_2023-02-21T00.18.41.858708Z_WS.POZA.S4.DNZ.MSEED
# Sanitized name: 3416162120230221t001841858708zwspozas4dnzmseed
# No match found for file: 34161621_2023-02-21T00.18.41.858708Z_WS.POZA.S4.DNZ.MSEED
#
# Processing file: 34161621_2023-02-21T00.18.41.861150Z_WS.POZA.S6.DN1.MSEED
# Sanitized name: 3416162120230221t001841861150zwspozas6dn1mseed
# Error processing 34161621_2023-02-21T00.18.41.861150Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34161621_2023-02-21T00.18.41.861150Z_WS.POZA.S6.DN2.MSEED
# Sanitized name: 3416162120230221t001841861150zwspozas6dn2mseed
# No match found for file: 34161621_2023-02-21T00.18.41.861150Z_WS.POZA.S6.DN2.MSEED
#
# Processing file: 34161621_2023-02-21T00.18.41.861150Z_WS.POZA.S6.DNZ.MSEED
# Sanitized name: 3416162120230221t001841861150zwspozas6dnzmseed
# No match found for file: 34161621_2023-02-21T00.18.41.861150Z_WS.POZA.S6.DNZ.MSEED
#
# Processing file: 34161791_2023-02-21T00.40.23.069600Z_WS.POZA.S5.DN1.MSEED
# Sanitized name: 3416179120230221t004023069600zwspozas5dn1mseed
# Processing trace: WS.POZA.S5.DN1
#
# Processing file: 34161791_2023-02-21T00.40.23.069600Z_WS.POZA.S5.DN2.MSEED
# Sanitized name: 3416179120230221t004023069600zwspozas5dn2mseed
# No match found for file: 34161791_2023-02-21T00.40.23.069600Z_WS.POZA.S5.DN2.MSEED
#
# Processing file: 34161791_2023-02-21T00.40.23.069600Z_WS.POZA.S5.DNZ.MSEED
# Sanitized name: 3416179120230221t004023069600zwspozas5dnzmseed
# No match found for file: 34161791_2023-02-21T00.40.23.069600Z_WS.POZA.S5.DNZ.MSEED
#
# Processing file: 34161791_2023-02-21T00.40.23.070024Z_WS.POZA.S3.DN1.MSEED
# Sanitized name: 3416179120230221t004023070024zwspozas3dn1mseed
# Processing trace: WS.POZA.S3.DN1
#
# Processing file: 34161791_2023-02-21T00.40.23.070024Z_WS.POZA.S3.DN2.MSEED
# Sanitized name: 3416179120230221t004023070024zwspozas3dn2mseed
# No match found for file: 34161791_2023-02-21T00.40.23.070024Z_WS.POZA.S3.DN2.MSEED
#
# Processing file: 34161791_2023-02-21T00.40.23.070024Z_WS.POZA.S3.DNZ.MSEED
# Sanitized name: 3416179120230221t004023070024zwspozas3dnzmseed
# No match found for file: 34161791_2023-02-21T00.40.23.070024Z_WS.POZA.S3.DNZ.MSEED
#
# Processing file: 34161791_2023-02-21T00.40.23.070032Z_WS.POZA.S2.DN1.MSEED
# Sanitized name: 3416179120230221t004023070032zwspozas2dn1mseed
# Processing trace: WS.POZA.S2.DN1
#
# Processing file: 34161791_2023-02-21T00.40.23.070032Z_WS.POZA.S2.DN2.MSEED
# Sanitized name: 3416179120230221t004023070032zwspozas2dn2mseed
# No match found for file: 34161791_2023-02-21T00.40.23.070032Z_WS.POZA.S2.DN2.MSEED
#
# Processing file: 34161791_2023-02-21T00.40.23.070032Z_WS.POZA.S2.DNZ.MSEED
# Sanitized name: 3416179120230221t004023070032zwspozas2dnzmseed
# No match found for file: 34161791_2023-02-21T00.40.23.070032Z_WS.POZA.S2.DNZ.MSEED
#
# Processing file: 34161791_2023-02-21T00.40.23.070708Z_WS.POZA.S4.DN1.MSEED
# Sanitized name: 3416179120230221t004023070708zwspozas4dn1mseed
# Processing trace: WS.POZA.S4.DN1
#
# Processing file: 34161791_2023-02-21T00.40.23.070708Z_WS.POZA.S4.DN2.MSEED
# Sanitized name: 3416179120230221t004023070708zwspozas4dn2mseed
# No match found for file: 34161791_2023-02-21T00.40.23.070708Z_WS.POZA.S4.DN2.MSEED
#
# Processing file: 34161791_2023-02-21T00.40.23.070708Z_WS.POZA.S4.DNZ.MSEED
# Sanitized name: 3416179120230221t004023070708zwspozas4dnzmseed
# No match found for file: 34161791_2023-02-21T00.40.23.070708Z_WS.POZA.S4.DNZ.MSEED
#
# Processing file: 34161791_2023-02-21T00.40.23.072380Z_WS.POZA.S6.DN1.MSEED
# Sanitized name: 3416179120230221t004023072380zwspozas6dn1mseed
# Processing trace: WS.POZA.S6.DN1
#
# Processing file: 34161791_2023-02-21T00.40.23.072380Z_WS.POZA.S6.DN2.MSEED
# Sanitized name: 3416179120230221t004023072380zwspozas6dn2mseed
# No match found for file: 34161791_2023-02-21T00.40.23.072380Z_WS.POZA.S6.DN2.MSEED
#
# Processing file: 34161791_2023-02-21T00.40.23.072380Z_WS.POZA.S6.DNZ.MSEED
# Sanitized name: 3416179120230221t004023072380zwspozas6dnzmseed
# No match found for file: 34161791_2023-02-21T00.40.23.072380Z_WS.POZA.S6.DNZ.MSEED
#
# Processing file: 34162021_2023-02-21T00.56.56.517600Z_WS.POZA.S5.DN1.MSEED
# Sanitized name: 3416202120230221t005656517600zwspozas5dn1mseed
# Error processing 34162021_2023-02-21T00.56.56.517600Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34162021_2023-02-21T00.56.56.517600Z_WS.POZA.S5.DN2.MSEED
# Sanitized name: 3416202120230221t005656517600zwspozas5dn2mseed
# No match found for file: 34162021_2023-02-21T00.56.56.517600Z_WS.POZA.S5.DN2.MSEED
#
# Processing file: 34162021_2023-02-21T00.56.56.517600Z_WS.POZA.S5.DNZ.MSEED
# Sanitized name: 3416202120230221t005656517600zwspozas5dnzmseed
# No match found for file: 34162021_2023-02-21T00.56.56.517600Z_WS.POZA.S5.DNZ.MSEED
#
# Processing file: 34162021_2023-02-21T00.56.56.518032Z_WS.POZA.S2.DN1.MSEED
# Sanitized name: 3416202120230221t005656518032zwspozas2dn1mseed
# Error processing 34162021_2023-02-21T00.56.56.518032Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34162021_2023-02-21T00.56.56.518032Z_WS.POZA.S2.DN2.MSEED
# Sanitized name: 3416202120230221t005656518032zwspozas2dn2mseed
# No match found for file: 34162021_2023-02-21T00.56.56.518032Z_WS.POZA.S2.DN2.MSEED
#
# Processing file: 34162021_2023-02-21T00.56.56.518032Z_WS.POZA.S2.DNZ.MSEED
# Sanitized name: 3416202120230221t005656518032zwspozas2dnzmseed
# No match found for file: 34162021_2023-02-21T00.56.56.518032Z_WS.POZA.S2.DNZ.MSEED
#
# Processing file: 34162021_2023-02-21T00.56.56.519238Z_WS.POZA.S3.DN1.MSEED
# Sanitized name: 3416202120230221t005656519238zwspozas3dn1mseed
# Error processing 34162021_2023-02-21T00.56.56.519238Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34162021_2023-02-21T00.56.56.519238Z_WS.POZA.S3.DN2.MSEED
# Sanitized name: 3416202120230221t005656519238zwspozas3dn2mseed
# No match found for file: 34162021_2023-02-21T00.56.56.519238Z_WS.POZA.S3.DN2.MSEED
#
# Processing file: 34162021_2023-02-21T00.56.56.519238Z_WS.POZA.S3.DNZ.MSEED
# Sanitized name: 3416202120230221t005656519238zwspozas3dnzmseed
# No match found for file: 34162021_2023-02-21T00.56.56.519238Z_WS.POZA.S3.DNZ.MSEED
#
# Processing file: 34162021_2023-02-21T00.56.56.520384Z_WS.POZA.S6.DN1.MSEED
# Sanitized name: 3416202120230221t005656520384zwspozas6dn1mseed
# Error processing 34162021_2023-02-21T00.56.56.520384Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34162021_2023-02-21T00.56.56.520384Z_WS.POZA.S6.DN2.MSEED
# Sanitized name: 3416202120230221t005656520384zwspozas6dn2mseed
# No match found for file: 34162021_2023-02-21T00.56.56.520384Z_WS.POZA.S6.DN2.MSEED
#
# Processing file: 34162021_2023-02-21T00.56.56.520384Z_WS.POZA.S6.DNZ.MSEED
# Sanitized name: 3416202120230221t005656520384zwspozas6dnzmseed
# No match found for file: 34162021_2023-02-21T00.56.56.520384Z_WS.POZA.S6.DNZ.MSEED
#
# Processing file: 34162021_2023-02-21T00.56.56.521079Z_WS.POZA.S4.DN1.MSEED
# Sanitized name: 3416202120230221t005656521079zwspozas4dn1mseed
# Error processing 34162021_2023-02-21T00.56.56.521079Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34162021_2023-02-21T00.56.56.521079Z_WS.POZA.S4.DN2.MSEED
# Sanitized name: 3416202120230221t005656521079zwspozas4dn2mseed
# No match found for file: 34162021_2023-02-21T00.56.56.521079Z_WS.POZA.S4.DN2.MSEED
#
# Processing file: 34162021_2023-02-21T00.56.56.521079Z_WS.POZA.S4.DNZ.MSEED
# Sanitized name: 3416202120230221t005656521079zwspozas4dnzmseed
# No match found for file: 34162021_2023-02-21T00.56.56.521079Z_WS.POZA.S4.DNZ.MSEED
#
# Processing file: 34162111_2023-02-21T01.02.21.829562Z_WS.POZA.S5.DN1.MSEED
# Sanitized name: 3416211120230221t010221829562zwspozas5dn1mseed
# Error processing 34162111_2023-02-21T01.02.21.829562Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34162111_2023-02-21T01.02.21.829562Z_WS.POZA.S5.DN2.MSEED
# Sanitized name: 3416211120230221t010221829562zwspozas5dn2mseed
# No match found for file: 34162111_2023-02-21T01.02.21.829562Z_WS.POZA.S5.DN2.MSEED
#
# Processing file: 34162111_2023-02-21T01.02.21.829562Z_WS.POZA.S5.DNZ.MSEED
# Sanitized name: 3416211120230221t010221829562zwspozas5dnzmseed
# No match found for file: 34162111_2023-02-21T01.02.21.829562Z_WS.POZA.S5.DNZ.MSEED
#
# Processing file: 34162111_2023-02-21T01.02.21.831238Z_WS.POZA.S3.DN1.MSEED
# Sanitized name: 3416211120230221t010221831238zwspozas3dn1mseed
# Error processing 34162111_2023-02-21T01.02.21.831238Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34162111_2023-02-21T01.02.21.831238Z_WS.POZA.S3.DN2.MSEED
# Sanitized name: 3416211120230221t010221831238zwspozas3dn2mseed
# No match found for file: 34162111_2023-02-21T01.02.21.831238Z_WS.POZA.S3.DN2.MSEED
#
# Processing file: 34162111_2023-02-21T01.02.21.831238Z_WS.POZA.S3.DNZ.MSEED
# Sanitized name: 3416211120230221t010221831238zwspozas3dnzmseed
# No match found for file: 34162111_2023-02-21T01.02.21.831238Z_WS.POZA.S3.DNZ.MSEED
#
# Processing file: 34162111_2023-02-21T01.02.21.832384Z_WS.POZA.S6.DN1.MSEED
# Sanitized name: 3416211120230221t010221832384zwspozas6dn1mseed
# Error processing 34162111_2023-02-21T01.02.21.832384Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34162111_2023-02-21T01.02.21.832384Z_WS.POZA.S6.DN2.MSEED
# Sanitized name: 3416211120230221t010221832384zwspozas6dn2mseed
# No match found for file: 34162111_2023-02-21T01.02.21.832384Z_WS.POZA.S6.DN2.MSEED
#
# Processing file: 34162111_2023-02-21T01.02.21.832384Z_WS.POZA.S6.DNZ.MSEED
# Sanitized name: 3416211120230221t010221832384zwspozas6dnzmseed
# No match found for file: 34162111_2023-02-21T01.02.21.832384Z_WS.POZA.S6.DNZ.MSEED
#
# Processing file: 34162111_2023-02-21T01.02.21.832647Z_WS.POZA.S2.DN1.MSEED
# Sanitized name: 3416211120230221t010221832647zwspozas2dn1mseed
# Error processing 34162111_2023-02-21T01.02.21.832647Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34162111_2023-02-21T01.02.21.832647Z_WS.POZA.S2.DN2.MSEED
# Sanitized name: 3416211120230221t010221832647zwspozas2dn2mseed
# No match found for file: 34162111_2023-02-21T01.02.21.832647Z_WS.POZA.S2.DN2.MSEED
#
# Processing file: 34162111_2023-02-21T01.02.21.832647Z_WS.POZA.S2.DNZ.MSEED
# Sanitized name: 3416211120230221t010221832647zwspozas2dnzmseed
# No match found for file: 34162111_2023-02-21T01.02.21.832647Z_WS.POZA.S2.DNZ.MSEED
#
# Processing file: 34162111_2023-02-21T01.02.21.833079Z_WS.POZA.S4.DN1.MSEED
# Sanitized name: 3416211120230221t010221833079zwspozas4dn1mseed
# Error processing 34162111_2023-02-21T01.02.21.833079Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34162111_2023-02-21T01.02.21.833079Z_WS.POZA.S4.DN2.MSEED
# Sanitized name: 3416211120230221t010221833079zwspozas4dn2mseed
# No match found for file: 34162111_2023-02-21T01.02.21.833079Z_WS.POZA.S4.DN2.MSEED
#
# Processing file: 34162111_2023-02-21T01.02.21.833079Z_WS.POZA.S4.DNZ.MSEED
# Sanitized name: 3416211120230221t010221833079zwspozas4dnzmseed
# No match found for file: 34162111_2023-02-21T01.02.21.833079Z_WS.POZA.S4.DNZ.MSEED
#
# Processing file: 34162221_2023-02-21T01.06.56.697562Z_WS.POZA.S5.DN1.MSEED
# Sanitized name: 3416222120230221t010656697562zwspozas5dn1mseed
# Error processing 34162221_2023-02-21T01.06.56.697562Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34162221_2023-02-21T01.06.56.697562Z_WS.POZA.S5.DN2.MSEED
# Sanitized name: 3416222120230221t010656697562zwspozas5dn2mseed
# No match found for file: 34162221_2023-02-21T01.06.56.697562Z_WS.POZA.S5.DN2.MSEED
#
# Processing file: 34162221_2023-02-21T01.06.56.697562Z_WS.POZA.S5.DNZ.MSEED
# Sanitized name: 3416222120230221t010656697562zwspozas5dnzmseed
# No match found for file: 34162221_2023-02-21T01.06.56.697562Z_WS.POZA.S5.DNZ.MSEED
#
# Processing file: 34162221_2023-02-21T01.06.56.698149Z_WS.POZA.S6.DN1.MSEED
# Sanitized name: 3416222120230221t010656698149zwspozas6dn1mseed
# Error processing 34162221_2023-02-21T01.06.56.698149Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34162221_2023-02-21T01.06.56.698149Z_WS.POZA.S6.DN2.MSEED
# Sanitized name: 3416222120230221t010656698149zwspozas6dn2mseed
# No match found for file: 34162221_2023-02-21T01.06.56.698149Z_WS.POZA.S6.DN2.MSEED
#
# Processing file: 34162221_2023-02-21T01.06.56.698149Z_WS.POZA.S6.DNZ.MSEED
# Sanitized name: 3416222120230221t010656698149zwspozas6dnzmseed
# No match found for file: 34162221_2023-02-21T01.06.56.698149Z_WS.POZA.S6.DNZ.MSEED
#
# Processing file: 34162221_2023-02-21T01.06.56.699238Z_WS.POZA.S3.DN1.MSEED
# Sanitized name: 3416222120230221t010656699238zwspozas3dn1mseed
# Processing trace: WS.POZA.S3.DN1
#
# Processing file: 34162221_2023-02-21T01.06.56.699238Z_WS.POZA.S3.DN2.MSEED
# Sanitized name: 3416222120230221t010656699238zwspozas3dn2mseed
# No match found for file: 34162221_2023-02-21T01.06.56.699238Z_WS.POZA.S3.DN2.MSEED
#
# Processing file: 34162221_2023-02-21T01.06.56.699238Z_WS.POZA.S3.DNZ.MSEED
# Sanitized name: 3416222120230221t010656699238zwspozas3dnzmseed
# No match found for file: 34162221_2023-02-21T01.06.56.699238Z_WS.POZA.S3.DNZ.MSEED
#
# Processing file: 34162221_2023-02-21T01.06.56.700647Z_WS.POZA.S2.DN1.MSEED
# Sanitized name: 3416222120230221t010656700647zwspozas2dn1mseed
# Error processing 34162221_2023-02-21T01.06.56.700647Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34162221_2023-02-21T01.06.56.700647Z_WS.POZA.S2.DN2.MSEED
# Sanitized name: 3416222120230221t010656700647zwspozas2dn2mseed
# No match found for file: 34162221_2023-02-21T01.06.56.700647Z_WS.POZA.S2.DN2.MSEED
#
# Processing file: 34162221_2023-02-21T01.06.56.700647Z_WS.POZA.S2.DNZ.MSEED
# Sanitized name: 3416222120230221t010656700647zwspozas2dnzmseed
# No match found for file: 34162221_2023-02-21T01.06.56.700647Z_WS.POZA.S2.DNZ.MSEED
#
# Processing file: 34162221_2023-02-21T01.06.56.701079Z_WS.POZA.S4.DN1.MSEED
# Sanitized name: 3416222120230221t010656701079zwspozas4dn1mseed
# Error processing 34162221_2023-02-21T01.06.56.701079Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34162221_2023-02-21T01.06.56.701079Z_WS.POZA.S4.DN2.MSEED
# Sanitized name: 3416222120230221t010656701079zwspozas4dn2mseed
# No match found for file: 34162221_2023-02-21T01.06.56.701079Z_WS.POZA.S4.DN2.MSEED
#
# Processing file: 34162221_2023-02-21T01.06.56.701079Z_WS.POZA.S4.DNZ.MSEED
# Sanitized name: 3416222120230221t010656701079zwspozas4dnzmseed
# No match found for file: 34162221_2023-02-21T01.06.56.701079Z_WS.POZA.S4.DNZ.MSEED
#
# Processing file: 34162311_2023-02-21T01.15.19.397562Z_WS.POZA.S5.DN1.MSEED
# Sanitized name: 3416231120230221t011519397562zwspozas5dn1mseed
# Error processing 34162311_2023-02-21T01.15.19.397562Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34162311_2023-02-21T01.15.19.397562Z_WS.POZA.S5.DN2.MSEED
# Sanitized name: 3416231120230221t011519397562zwspozas5dn2mseed
# No match found for file: 34162311_2023-02-21T01.15.19.397562Z_WS.POZA.S5.DN2.MSEED
#
# Processing file: 34162311_2023-02-21T01.15.19.397562Z_WS.POZA.S5.DNZ.MSEED
# Sanitized name: 3416231120230221t011519397562zwspozas5dnzmseed
# No match found for file: 34162311_2023-02-21T01.15.19.397562Z_WS.POZA.S5.DNZ.MSEED
#
# Processing file: 34162311_2023-02-21T01.15.19.398149Z_WS.POZA.S6.DN1.MSEED
# Sanitized name: 3416231120230221t011519398149zwspozas6dn1mseed
# Error processing 34162311_2023-02-21T01.15.19.398149Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34162311_2023-02-21T01.15.19.398149Z_WS.POZA.S6.DN2.MSEED
# Sanitized name: 3416231120230221t011519398149zwspozas6dn2mseed
# No match found for file: 34162311_2023-02-21T01.15.19.398149Z_WS.POZA.S6.DN2.MSEED
#
# Processing file: 34162311_2023-02-21T01.15.19.398149Z_WS.POZA.S6.DNZ.MSEED
# Sanitized name: 3416231120230221t011519398149zwspozas6dnzmseed
# No match found for file: 34162311_2023-02-21T01.15.19.398149Z_WS.POZA.S6.DNZ.MSEED
#
# Processing file: 34162311_2023-02-21T01.15.19.399238Z_WS.POZA.S3.DN1.MSEED
# Sanitized name: 3416231120230221t011519399238zwspozas3dn1mseed
# Error processing 34162311_2023-02-21T01.15.19.399238Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34162311_2023-02-21T01.15.19.399238Z_WS.POZA.S3.DN2.MSEED
# Sanitized name: 3416231120230221t011519399238zwspozas3dn2mseed
# No match found for file: 34162311_2023-02-21T01.15.19.399238Z_WS.POZA.S3.DN2.MSEED
#
# Processing file: 34162311_2023-02-21T01.15.19.399238Z_WS.POZA.S3.DNZ.MSEED
# Sanitized name: 3416231120230221t011519399238zwspozas3dnzmseed
# No match found for file: 34162311_2023-02-21T01.15.19.399238Z_WS.POZA.S3.DNZ.MSEED
#
# Processing file: 34162311_2023-02-21T01.15.19.400647Z_WS.POZA.S2.DN1.MSEED
# Sanitized name: 3416231120230221t011519400647zwspozas2dn1mseed
# Error processing 34162311_2023-02-21T01.15.19.400647Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34162311_2023-02-21T01.15.19.400647Z_WS.POZA.S2.DN2.MSEED
# Sanitized name: 3416231120230221t011519400647zwspozas2dn2mseed
# No match found for file: 34162311_2023-02-21T01.15.19.400647Z_WS.POZA.S2.DN2.MSEED
#
# Processing file: 34162311_2023-02-21T01.15.19.400647Z_WS.POZA.S2.DNZ.MSEED
# Sanitized name: 3416231120230221t011519400647zwspozas2dnzmseed
# No match found for file: 34162311_2023-02-21T01.15.19.400647Z_WS.POZA.S2.DNZ.MSEED
#
# Processing file: 34162311_2023-02-21T01.15.19.401079Z_WS.POZA.S4.DN1.MSEED
# Sanitized name: 3416231120230221t011519401079zwspozas4dn1mseed
# Error processing 34162311_2023-02-21T01.15.19.401079Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34162311_2023-02-21T01.15.19.401079Z_WS.POZA.S4.DN2.MSEED
# Sanitized name: 3416231120230221t011519401079zwspozas4dn2mseed
# No match found for file: 34162311_2023-02-21T01.15.19.401079Z_WS.POZA.S4.DN2.MSEED
#
# Processing file: 34162311_2023-02-21T01.15.19.401079Z_WS.POZA.S4.DNZ.MSEED
# Sanitized name: 3416231120230221t011519401079zwspozas4dnzmseed
# No match found for file: 34162311_2023-02-21T01.15.19.401079Z_WS.POZA.S4.DNZ.MSEED
#
# Processing file: 34162371_2023-02-21T01.31.01.417675Z_WS.POZA.S5.DN1.MSEED
# Sanitized name: 3416237120230221t013101417675zwspozas5dn1mseed
# Error processing 34162371_2023-02-21T01.31.01.417675Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34162371_2023-02-21T01.31.01.417675Z_WS.POZA.S5.DN2.MSEED
# Sanitized name: 3416237120230221t013101417675zwspozas5dn2mseed
# No match found for file: 34162371_2023-02-21T01.31.01.417675Z_WS.POZA.S5.DN2.MSEED
#
# Processing file: 34162371_2023-02-21T01.31.01.417675Z_WS.POZA.S5.DNZ.MSEED
# Sanitized name: 3416237120230221t013101417675zwspozas5dnzmseed
# No match found for file: 34162371_2023-02-21T01.31.01.417675Z_WS.POZA.S5.DNZ.MSEED
#
# ...
# Sanitized name: 3482154120230427t120816710163zwspozas4dn2mseed
# No match found for file: 34821541_2023-04-27T12.08.16.710163Z_WS.POZA.S4.DN2.MSEED
#
# Processing file: 34821541_2023-04-27T12.08.16.710163Z_WS.POZA.S4.DNZ.MSEED
# Sanitized name: 3482154120230427t120816710163zwspozas4dnzmseed
# No match found for file: 34821541_2023-04-27T12.08.16.710163Z_WS.POZA.S4.DNZ.MSEED
#
# Processing file: 34821541_2023-04-27T12.08.16.710305Z_WS.POZA.S3.DN1.MSEED
# Sanitized name: 3482154120230427t120816710305zwspozas3dn1mseed
# Error processing 34821541_2023-04-27T12.08.16.710305Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34821541_2023-04-27T12.08.16.710305Z_WS.POZA.S3.DN2.MSEED
# Sanitized name: 3482154120230427t120816710305zwspozas3dn2mseed
# No match found for file: 34821541_2023-04-27T12.08.16.710305Z_WS.POZA.S3.DN2.MSEED
#
# Processing file: 34821541_2023-04-27T12.08.16.710305Z_WS.POZA.S3.DNZ.MSEED
# Sanitized name: 3482154120230427t120816710305zwspozas3dnzmseed
# No match found for file: 34821541_2023-04-27T12.08.16.710305Z_WS.POZA.S3.DNZ.MSEED
#
# Processing file: 34821541_2023-04-27T12.08.16.711033Z_WS.POZA.S6.DN1.MSEED
# Sanitized name: 3482154120230427t120816711033zwspozas6dn1mseed
# Error processing 34821541_2023-04-27T12.08.16.711033Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34821541_2023-04-27T12.08.16.711033Z_WS.POZA.S6.DN2.MSEED
# Sanitized name: 3482154120230427t120816711033zwspozas6dn2mseed
# No match found for file: 34821541_2023-04-27T12.08.16.711033Z_WS.POZA.S6.DN2.MSEED
#
# Processing file: 34821541_2023-04-27T12.08.16.711033Z_WS.POZA.S6.DNZ.MSEED
# Sanitized name: 3482154120230427t120816711033zwspozas6dnzmseed
# No match found for file: 34821541_2023-04-27T12.08.16.711033Z_WS.POZA.S6.DNZ.MSEED
#
# Processing file: 34821541_2023-04-27T12.08.16.712359Z_WS.POZA.S5.DN1.MSEED
# Sanitized name: 3482154120230427t120816712359zwspozas5dn1mseed
# Error processing 34821541_2023-04-27T12.08.16.712359Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34821541_2023-04-27T12.08.16.712359Z_WS.POZA.S5.DN2.MSEED
# Sanitized name: 3482154120230427t120816712359zwspozas5dn2mseed
# No match found for file: 34821541_2023-04-27T12.08.16.712359Z_WS.POZA.S5.DN2.MSEED
#
# Processing file: 34821541_2023-04-27T12.08.16.712359Z_WS.POZA.S5.DNZ.MSEED
# Sanitized name: 3482154120230427t120816712359zwspozas5dnzmseed
# No match found for file: 34821541_2023-04-27T12.08.16.712359Z_WS.POZA.S5.DNZ.MSEED
#
# Processing file: 34821541_2023-04-27T12.08.16.712806Z_WS.POZA.S2.DN1.MSEED
# Sanitized name: 3482154120230427t120816712806zwspozas2dn1mseed
# Error processing 34821541_2023-04-27T12.08.16.712806Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34821541_2023-04-27T12.08.16.712806Z_WS.POZA.S2.DN2.MSEED
# Sanitized name: 3482154120230427t120816712806zwspozas2dn2mseed
# No match found for file: 34821541_2023-04-27T12.08.16.712806Z_WS.POZA.S2.DN2.MSEED
#
# Processing file: 34821541_2023-04-27T12.08.16.712806Z_WS.POZA.S2.DNZ.MSEED
# Sanitized name: 3482154120230427t120816712806zwspozas2dnzmseed
# No match found for file: 34821541_2023-04-27T12.08.16.712806Z_WS.POZA.S2.DNZ.MSEED
#
# Processing file: 34836221_2023-04-28T20.50.39.467773Z_WS.POZA.S4.DN1.MSEED
# Sanitized name: 3483622120230428t205039467773zwspozas4dn1mseed
# Processing trace: WS.POZA.S4.DN1
#
# Processing file: 34836221_2023-04-28T20.50.39.467773Z_WS.POZA.S4.DN2.MSEED
# Sanitized name: 3483622120230428t205039467773zwspozas4dn2mseed
# No match found for file: 34836221_2023-04-28T20.50.39.467773Z_WS.POZA.S4.DN2.MSEED
#
# Processing file: 34836221_2023-04-28T20.50.39.467773Z_WS.POZA.S4.DNZ.MSEED
# Sanitized name: 3483622120230428t205039467773zwspozas4dnzmseed
# No match found for file: 34836221_2023-04-28T20.50.39.467773Z_WS.POZA.S4.DNZ.MSEED
#
# Processing file: 34836221_2023-04-28T20.50.39.468678Z_WS.POZA.S6.DN1.MSEED
# Sanitized name: 3483622120230428t205039468678zwspozas6dn1mseed
# Error processing 34836221_2023-04-28T20.50.39.468678Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34836221_2023-04-28T20.50.39.468678Z_WS.POZA.S6.DN2.MSEED
# Sanitized name: 3483622120230428t205039468678zwspozas6dn2mseed
# No match found for file: 34836221_2023-04-28T20.50.39.468678Z_WS.POZA.S6.DN2.MSEED
#
# Processing file: 34836221_2023-04-28T20.50.39.468678Z_WS.POZA.S6.DNZ.MSEED
# Sanitized name: 3483622120230428t205039468678zwspozas6dnzmseed
# No match found for file: 34836221_2023-04-28T20.50.39.468678Z_WS.POZA.S6.DNZ.MSEED
#
# Processing file: 34836221_2023-04-28T20.50.39.470042Z_WS.POZA.S5.DN1.MSEED
# Sanitized name: 3483622120230428t205039470042zwspozas5dn1mseed
# Processing trace: WS.POZA.S5.DN1
#
# Processing file: 34836221_2023-04-28T20.50.39.470042Z_WS.POZA.S5.DN2.MSEED
# Sanitized name: 3483622120230428t205039470042zwspozas5dn2mseed
# No match found for file: 34836221_2023-04-28T20.50.39.470042Z_WS.POZA.S5.DN2.MSEED
#
# Processing file: 34836221_2023-04-28T20.50.39.470042Z_WS.POZA.S5.DNZ.MSEED
# Sanitized name: 3483622120230428t205039470042zwspozas5dnzmseed
# No match found for file: 34836221_2023-04-28T20.50.39.470042Z_WS.POZA.S5.DNZ.MSEED
#
# Processing file: 34836221_2023-04-28T20.50.39.470238Z_WS.POZA.S3.DN1.MSEED
# Sanitized name: 3483622120230428t205039470238zwspozas3dn1mseed
# Processing trace: WS.POZA.S3.DN1
#
# Processing file: 34836221_2023-04-28T20.50.39.470238Z_WS.POZA.S3.DN2.MSEED
# Sanitized name: 3483622120230428t205039470238zwspozas3dn2mseed
# No match found for file: 34836221_2023-04-28T20.50.39.470238Z_WS.POZA.S3.DN2.MSEED
#
# Processing file: 34836221_2023-04-28T20.50.39.470238Z_WS.POZA.S3.DNZ.MSEED
# Sanitized name: 3483622120230428t205039470238zwspozas3dnzmseed
# No match found for file: 34836221_2023-04-28T20.50.39.470238Z_WS.POZA.S3.DNZ.MSEED
#
# Processing file: 34836221_2023-04-28T20.50.39.470291Z_WS.POZA.S2.DN1.MSEED
# Sanitized name: 3483622120230428t205039470291zwspozas2dn1mseed
# Processing trace: WS.POZA.S2.DN1
#
# Processing file: 34836221_2023-04-28T20.50.39.470291Z_WS.POZA.S2.DN2.MSEED
# Sanitized name: 3483622120230428t205039470291zwspozas2dn2mseed
# No match found for file: 34836221_2023-04-28T20.50.39.470291Z_WS.POZA.S2.DN2.MSEED
#
# Processing file: 34836221_2023-04-28T20.50.39.470291Z_WS.POZA.S2.DNZ.MSEED
# Sanitized name: 3483622120230428t205039470291zwspozas2dnzmseed
# No match found for file: 34836221_2023-04-28T20.50.39.470291Z_WS.POZA.S2.DNZ.MSEED
#
# Processing file: 34956701_2023-05-11T23.41.38.889527Z_WS.POZA.S5.DN1.MSEED
# Sanitized name: 3495670120230511t234138889527zwspozas5dn1mseed
# Error processing 34956701_2023-05-11T23.41.38.889527Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34956701_2023-05-11T23.41.38.889527Z_WS.POZA.S5.DN2.MSEED
# Sanitized name: 3495670120230511t234138889527zwspozas5dn2mseed
# No match found for file: 34956701_2023-05-11T23.41.38.889527Z_WS.POZA.S5.DN2.MSEED
#
# Processing file: 34956701_2023-05-11T23.41.38.889527Z_WS.POZA.S5.DNZ.MSEED
# Sanitized name: 3495670120230511t234138889527zwspozas5dnzmseed
# No match found for file: 34956701_2023-05-11T23.41.38.889527Z_WS.POZA.S5.DNZ.MSEED
#
# Processing file: 34956701_2023-05-11T23.41.38.889759Z_WS.POZA.S2.DN1.MSEED
# Sanitized name: 3495670120230511t234138889759zwspozas2dn1mseed
# Error processing 34956701_2023-05-11T23.41.38.889759Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34956701_2023-05-11T23.41.38.889759Z_WS.POZA.S2.DN2.MSEED
# Sanitized name: 3495670120230511t234138889759zwspozas2dn2mseed
# No match found for file: 34956701_2023-05-11T23.41.38.889759Z_WS.POZA.S2.DN2.MSEED
#
# Processing file: 34956701_2023-05-11T23.41.38.889759Z_WS.POZA.S2.DNZ.MSEED
# Sanitized name: 3495670120230511t234138889759zwspozas2dnzmseed
# No match found for file: 34956701_2023-05-11T23.41.38.889759Z_WS.POZA.S2.DNZ.MSEED
#
# Processing file: 34956701_2023-05-11T23.41.38.891323Z_WS.POZA.S3.DN1.MSEED
# Sanitized name: 3495670120230511t234138891323zwspozas3dn1mseed
# Error processing 34956701_2023-05-11T23.41.38.891323Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34956701_2023-05-11T23.41.38.891323Z_WS.POZA.S3.DN2.MSEED
# Sanitized name: 3495670120230511t234138891323zwspozas3dn2mseed
# No match found for file: 34956701_2023-05-11T23.41.38.891323Z_WS.POZA.S3.DN2.MSEED
#
# Processing file: 34956701_2023-05-11T23.41.38.891323Z_WS.POZA.S3.DNZ.MSEED
# Sanitized name: 3495670120230511t234138891323zwspozas3dnzmseed
# No match found for file: 34956701_2023-05-11T23.41.38.891323Z_WS.POZA.S3.DNZ.MSEED
#
# Processing file: 34956701_2023-05-11T23.41.38.892111Z_WS.POZA.S6.DN1.MSEED
# Sanitized name: 3495670120230511t234138892111zwspozas6dn1mseed
# Error processing 34956701_2023-05-11T23.41.38.892111Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 34956701_2023-05-11T23.41.38.892111Z_WS.POZA.S6.DN2.MSEED
# Sanitized name: 3495670120230511t234138892111zwspozas6dn2mseed
# No match found for file: 34956701_2023-05-11T23.41.38.892111Z_WS.POZA.S6.DN2.MSEED
#
# Processing file: 34956701_2023-05-11T23.41.38.892111Z_WS.POZA.S6.DNZ.MSEED
# Sanitized name: 3495670120230511t234138892111zwspozas6dnzmseed
# No match found for file: 34956701_2023-05-11T23.41.38.892111Z_WS.POZA.S6.DNZ.MSEED
#
# Processing file: 35266701_2023-06-09T22.34.36.208297Z_WS.POZA.S3.DN1.MSEED
# Sanitized name: 3526670120230609t223436208297zwspozas3dn1mseed
# Error processing 35266701_2023-06-09T22.34.36.208297Z_WS.POZA.S3.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 35266701_2023-06-09T22.34.36.208297Z_WS.POZA.S3.DN2.MSEED
# Sanitized name: 3526670120230609t223436208297zwspozas3dn2mseed
# No match found for file: 35266701_2023-06-09T22.34.36.208297Z_WS.POZA.S3.DN2.MSEED
#
# Processing file: 35266701_2023-06-09T22.34.36.208297Z_WS.POZA.S3.DNZ.MSEED
# Sanitized name: 3526670120230609t223436208297zwspozas3dnzmseed
# No match found for file: 35266701_2023-06-09T22.34.36.208297Z_WS.POZA.S3.DNZ.MSEED
#
# Processing file: 35266701_2023-06-09T22.34.36.210008Z_WS.POZA.S6.DN1.MSEED
# Sanitized name: 3526670120230609t223436210008zwspozas6dn1mseed
# Error processing 35266701_2023-06-09T22.34.36.210008Z_WS.POZA.S6.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 35266701_2023-06-09T22.34.36.210008Z_WS.POZA.S6.DN2.MSEED
# Sanitized name: 3526670120230609t223436210008zwspozas6dn2mseed
# No match found for file: 35266701_2023-06-09T22.34.36.210008Z_WS.POZA.S6.DN2.MSEED
#
# Processing file: 35266701_2023-06-09T22.34.36.210008Z_WS.POZA.S6.DNZ.MSEED
# Sanitized name: 3526670120230609t223436210008zwspozas6dnzmseed
# No match found for file: 35266701_2023-06-09T22.34.36.210008Z_WS.POZA.S6.DNZ.MSEED
#
# Processing file: 35266701_2023-06-09T22.34.36.210130Z_WS.POZA.S5.DN1.MSEED
# Sanitized name: 3526670120230609t223436210130zwspozas5dn1mseed
# Error processing 35266701_2023-06-09T22.34.36.210130Z_WS.POZA.S5.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 35266701_2023-06-09T22.34.36.210130Z_WS.POZA.S5.DN2.MSEED
# Sanitized name: 3526670120230609t223436210130zwspozas5dn2mseed
# No match found for file: 35266701_2023-06-09T22.34.36.210130Z_WS.POZA.S5.DN2.MSEED
#
# Processing file: 35266701_2023-06-09T22.34.36.210130Z_WS.POZA.S5.DNZ.MSEED
# Sanitized name: 3526670120230609t223436210130zwspozas5dnzmseed
# No match found for file: 35266701_2023-06-09T22.34.36.210130Z_WS.POZA.S5.DNZ.MSEED
#
# Processing file: 35266701_2023-06-09T22.34.36.211277Z_WS.POZA.S4.DN1.MSEED
# Sanitized name: 3526670120230609t223436211277zwspozas4dn1mseed
# Error processing 35266701_2023-06-09T22.34.36.211277Z_WS.POZA.S4.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 35266701_2023-06-09T22.34.36.211277Z_WS.POZA.S4.DN2.MSEED
# Sanitized name: 3526670120230609t223436211277zwspozas4dn2mseed
# No match found for file: 35266701_2023-06-09T22.34.36.211277Z_WS.POZA.S4.DN2.MSEED
#
# Processing file: 35266701_2023-06-09T22.34.36.211277Z_WS.POZA.S4.DNZ.MSEED
# Sanitized name: 3526670120230609t223436211277zwspozas4dnzmseed
# No match found for file: 35266701_2023-06-09T22.34.36.211277Z_WS.POZA.S4.DNZ.MSEED
#
# Processing file: 35266701_2023-06-09T22.34.36.212005Z_WS.POZA.S2.DN1.MSEED
# Sanitized name: 3526670120230609t223436212005zwspozas2dn1mseed
# Error processing 35266701_2023-06-09T22.34.36.212005Z_WS.POZA.S2.DN1.MSEED: 'float' object cannot be interpreted as an integer
#
# Processing file: 35266701_2023-06-09T22.34.36.212005Z_WS.POZA.S2.DN2.MSEED
# Sanitized name: 3526670120230609t223436212005zwspozas2dn2mseed
# No match found for file: 35266701_2023-06-09T22.34.36.212005Z_WS.POZA.S2.DN2.MSEED
#
# Processing file: 35266701_2023-06-09T22.34.36.212005Z_WS.POZA.S2.DNZ.MSEED
# Sanitized name: 3526670120230609t223436212005zwspozas2dnzmseed
# No match found for file: 35266701_2023-06-09T22.34.36.212005Z_WS.POZA.S2.DNZ.MSEED
#
# Processing file: 35419441_2023-06-30T04.10.40.107451Z_WS.POZA.S5.DN1.MSEED
# Sanitized name: 3541944120230630t041040107451zwspozas5dn1mseed
# Processing trace: WS.POZA.S5.DN1
#
# Processing file: 35419441_2023-06-30T04.10.40.107451Z_WS.POZA.S5.DN2.MSEED
# Sanitized name: 3541944120230630t041040107451zwspozas5dn2mseed
# No match found for file: 35419441_2023-06-30T04.10.40.107451Z_WS.POZA.S5.DN2.MSEED
#
# Processing file: 35419441_2023-06-30T04.10.40.107451Z_WS.POZA.S5.DNZ.MSEED
# Sanitized name: 3541944120230630t041040107451zwspozas5dnzmseed
# No match found for file: 35419441_2023-06-30T04.10.40.107451Z_WS.POZA.S5.DNZ.MSEED
#
# Processing file: 35419441_2023-06-30T04.10.40.107601Z_WS.POZA.S2.DN1.MSEED
# Sanitized name: 3541944120230630t041040107601zwspozas2dn1mseed
# Processing trace: WS.POZA.S2.DN1
#
# Processing file: 35419441_2023-06-30T04.10.40.107601Z_WS.POZA.S2.DN2.MSEED
# Sanitized name: 3541944120230630t041040107601zwspozas2dn2mseed
# No match found for file: 35419441_2023-06-30T04.10.40.107601Z_WS.POZA.S2.DN2.MSEED
#
# Processing file: 35419441_2023-06-30T04.10.40.107601Z_WS.POZA.S2.DNZ.MSEED
# Sanitized name: 3541944120230630t041040107601zwspozas2dnzmseed
# No match found for file: 35419441_2023-06-30T04.10.40.107601Z_WS.POZA.S2.DNZ.MSEED
#
# Processing file: 35419441_2023-06-30T04.10.40.108520Z_WS.POZA.S6.DN1.MSEED
# Sanitized name: 3541944120230630t041040108520zwspozas6dn1mseed
# Processing trace: WS.POZA.S6.DN1
#
# Processing file: 35419441_2023-06-30T04.10.40.108520Z_WS.POZA.S6.DN2.MSEED
# Sanitized name: 3541944120230630t041040108520zwspozas6dn2mseed
# No match found for file: 35419441_2023-06-30T04.10.40.108520Z_WS.POZA.S6.DN2.MSEED
#
# Processing file: 35419441_2023-06-30T04.10.40.108520Z_WS.POZA.S6.DNZ.MSEED
# Sanitized name: 3541944120230630t041040108520zwspozas6dnzmseed
# No match found for file: 35419441_2023-06-30T04.10.40.108520Z_WS.POZA.S6.DNZ.MSEED
#
# Processing file: 35419441_2023-06-30T04.10.40.108841Z_WS.POZA.S3.DN1.MSEED
# Sanitized name: 3541944120230630t041040108841zwspozas3dn1mseed
# Processing trace: WS.POZA.S3.DN1
#
# Processing file: 35419441_2023-06-30T04.10.40.108841Z_WS.POZA.S3.DN2.MSEED
# Sanitized name: 3541944120230630t041040108841zwspozas3dn2mseed
# No match found for file: 35419441_2023-06-30T04.10.40.108841Z_WS.POZA.S3.DN2.MSEED
#
# Processing file: 35419441_2023-06-30T04.10.40.108841Z_WS.POZA.S3.DNZ.MSEED
# Sanitized name: 3541944120230630t041040108841zwspozas3dnzmseed
# No match found for file: 35419441_2023-06-30T04.10.40.108841Z_WS.POZA.S3.DNZ.MSEED
#
# Processing file: 35419441_2023-06-30T04.10.40.109398Z_WS.POZA.S4.DN1.MSEED
# Sanitized name: 3541944120230630t041040109398zwspozas4dn1mseed
# Processing trace: WS.POZA.S4.DN1
#
# Processing file: 35419441_2023-06-30T04.10.40.109398Z_WS.POZA.S4.DN2.MSEED
# Sanitized name: 3541944120230630t041040109398zwspozas4dn2mseed
# No match found for file: 35419441_2023-06-30T04.10.40.109398Z_WS.POZA.S4.DN2.MSEED
#
# Processing file: 35419441_2023-06-30T04.10.40.109398Z_WS.POZA.S4.DNZ.MSEED
# Sanitized name: 3541944120230630t041040109398zwspozas4dnzmseed
# No match found for file: 35419441_2023-06-30T04.10.40.109398Z_WS.POZA.S4.DNZ.MSEED
#
# Processing Summary:
# Total files found: 984
# Files matching metadata: 328
# Total traces processed: 128
# Valid P-picks: 72
# Average P-pick SNR: 6.42
